# %%
import radosgw

# %%
access_key = '6LDLPN722I69N3AY9B95'
secret_key = 'nyPiW6pGu9sOEWlCTexOgXu54UMvMBm1zGzqyv3W'

rgwadmin = radosgw.connection.RadosGWAdminConnection(host='192.168.35.41', 
                                                     is_secure=False,
                                                     access_key=access_key,
                                                     secret_key=secret_key)



testuser1 = rgwadmin.get_user('mania')

bucket_info = rgwadmin.get_bucket('data', stats=True)
for key in bucket_info._object:
    print(key, '\t', bucket_info._object[key])
# Out:
# bucket 	 data
# zonegroup 	 56960513-3595-4337-9d8a-8b6b68cd76bb
# placement_rule 	 default-placement
# explicit_placement 	 {'data_pool': '', 'data_extra_pool': '', 'index_pool': ''}
# id 	 3ba5b0d9-ab69-488c-909d-7cb0237cafba.9286704.1
# marker 	 3ba5b0d9-ab69-488c-909d-7cb0237cafba.9286704.1
# index_type 	 Normal
# owner 	 testuser
# ver 	 0#644
# master_ver 	 0#0
# mtime 	 2020-04-26 14:10:26.621579
# max_marker 	 0#
# usage 	 {'rgw.main': {'size': 35271645920, 'size_actual': 35271720960, 'size_utilized': 35271645920, 'size_kb': 34444967, 'size_kb_actual': 34445040, 'size_kb_utilized': 34444967, 'num_objects': 36}}
# bucket_quota 	 {'enabled': False, 'check_on_raw': True, 'max_size': -1, 'max_size_kb': 0, 'max_objects': -1}

# %%
import swiftclient
import json 

user = 'testuser:swift'
key = '7Xqb6gdsCE5Vu0clmk2qL0yjjy1NCNiFuaPlGQvJ'

metadata = {}

conn = swiftclient.Connection(
        user=user,
        key=key,
        authurl='http://192.168.35.41:80/auth/1.0')

container_name = 'data'

metadata_swift =  conn.get_container(container_name)[1]

def add_to_metadata_tree(name, size):
    global metadata
    path_element = name.split('/')
    
    meta_ptr = metadata
    for element in path_element:
        if element not in meta_ptr:
            meta_ptr[element] = {'objs': {}, 'size': 0 }
        meta_ptr[element]['size'] += size
        meta_ptr = meta_ptr[element]['objs']
        


for data in conn.get_container(container_name)[1]:
    full_name = data['name'];
    
    if full_name.endswith('_SUCCESS') : continue;
    add_to_metadata_tree(data['name'], data['bytes'])
    #break
    print(data['name'])
    

#print(json.dumps(metadata, indent = 4))
# Out:
# HiBench/Wordcount/Input/part-m-00000
# HiBench/Wordcount/Input/part-m-00001
# HiBench/Wordcount/Input/part-m-00002
# HiBench/Wordcount/Input/part-m-00003
# HiBench/Wordcount/Input/part-m-00004
# HiBench/Wordcount/Input/part-m-00005
# HiBench/Wordcount/Input/part-m-00006
# HiBench/Wordcount/Input/part-m-00007
# HiBench/Wordcount/Input/part-m-00008
# HiBench/Wordcount/Input/part-m-00009
# HiBench/Wordcount/Input/part-m-00010
# HiBench/Wordcount/Input/part-m-00011
# HiBench/Wordcount/Input/part-m-00012
# HiBench/Wordcount/Input/part-m-00013
# HiBench/Wordcount/Input/part-m-00014
# HiBench/Wordcount/Input/part-m-00015
# HiBench/Wordcount/Input/part-m-00016
# HiBench/Wordcount/Input/part-m-00017
# HiBench/Wordcount/Input/part-m-00018
# HiBench/Wordcount/Input/part-m-00019
# HiBench/Wordcount/Input/part-m-00020
# HiBench/Wordcount/Input/part-m-00021
# HiBench/Wordcount/Input/part-m-00022
# HiBench/Wordcount/Input/part-m-00023
# HiBench/Wordcount/Input/part-m-00024
# HiBench/Wordcount/Input/part-m-00025
# HiBench/Wordcount/Input/part-m-00026
# HiBench/Wordcount/Input/part-m-00027
# HiBench/Wordcount/Input/part-m-00028
# HiBench/Wordcount/Input/part-m-00029
# HiBench/Wordcount/Input/part-m-00030
# HiBench/Wordcount/Input/part-m-00031
# HiBench/Wordcount/Output/part-r-00000
# resize_fs.sh

# %%
import math
import requests
import swiftclient
import json 


user = 'testuser:swift'
key = '7Xqb6gdsCE5Vu0clmk2qL0yjjy1NCNiFuaPlGQvJ'


def fetch_object(token, bucket_name, obj_name, ofs_s, ofs_e):
    print(bucket_name, obj_name)
    
    url = 'http://192.168.35.41:80/swift/v1/%s/%s'%(bucket_name, obj_name)
    headers = {"range":"bytes=%d-%d"%(ofs_s, ofs_e),
              "X-Auth-Token": token}
    
    print(url, headers)
    
    
    r=requests.get(url, headers=headers)
    
    print(len(r.content), ofs_e - ofs_s)
    '''
    local_p = subprocess.Popen(["curl -i http://%s:%d/swift/v1/%s/%s -X GET -H \"range: bytes=%d-%d\" -H \"KARIZ_PREFETCH: 1\" -H \"X-Auth-Token: %s\" -o /dev/null 2>&1 | tee %soutput-%s.txt" %(cfg.d3n_host, cfg.d3n_port, bucket_name, obj_name, s_off, e_off, token, './', obj_name)], shell=True)
    local_p.wait()
    '''



def prefetch_dataset(path, wave=-1, stride=0):
    # stride = -1 means prefetch the full object
    # wave = -1 means follow the partitions schema of original dataset
    cache_block_size = 4194304 # 4 MB
    
    path_element = path.split('/')
    
    meta_ptr = metadata
    for element in path_element:
        if element not in meta_ptr:
            return -1; # means could not prefetch this input
        meta_ptr = meta_ptr[element]['objs']
        
    for obj in meta_ptr:
        n_cache_blocks = meta_ptr[obj]['size']//cache_block_size
        
        
        ofs_s = (n_cache_blocks - stride)*cache_block_size if (stride) else 0 
        ofs_e = meta_ptr[obj]['size']
        
        fetch_object(token=token, bucket_name='data', obj_name=path+'/'+obj, ofs_s = ofs_s, ofs_e = ofs_e)
        
        # add to thread pool 
        
        
    
    #print(json.dumps(meta_ptr, indent = 4))

conn = swiftclient.Connection(
        user=user,
        key=key,
        authurl='http://192.168.35.41:80/auth/1.0')

token = conn.get_auth()[1]
print(token)
    
dpath = 'HiBench/Wordcount/Input'
prefetch_dataset(dpath, stride=176)
# Out:
# AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9
# data HiBench/Wordcount/Input/part-m-00000
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00000 {'range': 'bytes=293601280-1102234211', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808632931 808632931
# data HiBench/Wordcount/Input/part-m-00001
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00001 {'range': 'bytes=293601280-1102230641', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808629361 808629361
# data HiBench/Wordcount/Input/part-m-00002
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00002 {'range': 'bytes=293601280-1102224903', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808623623 808623623
# data HiBench/Wordcount/Input/part-m-00003
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00003 {'range': 'bytes=293601280-1102246001', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808644721 808644721
# data HiBench/Wordcount/Input/part-m-00004
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00004 {'range': 'bytes=293601280-1102242605', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808641325 808641325
# data HiBench/Wordcount/Input/part-m-00005
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00005 {'range': 'bytes=293601280-1102235336', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808634056 808634056
# data HiBench/Wordcount/Input/part-m-00006
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00006 {'range': 'bytes=293601280-1102232388', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808631108 808631108
# data HiBench/Wordcount/Input/part-m-00007
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00007 {'range': 'bytes=293601280-1102242305', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808641025 808641025
# data HiBench/Wordcount/Input/part-m-00008
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00008 {'range': 'bytes=293601280-1102243273', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808641993 808641993
# data HiBench/Wordcount/Input/part-m-00009
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00009 {'range': 'bytes=293601280-1102226039', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808624759 808624759
# data HiBench/Wordcount/Input/part-m-00010
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00010 {'range': 'bytes=293601280-1102240788', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808639508 808639508
# data HiBench/Wordcount/Input/part-m-00011
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00011 {'range': 'bytes=293601280-1102236450', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808635170 808635170
# data HiBench/Wordcount/Input/part-m-00012
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00012 {'range': 'bytes=293601280-1102235825', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808634545 808634545
# data HiBench/Wordcount/Input/part-m-00013
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00013 {'range': 'bytes=293601280-1102236758', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808635478 808635478
# data HiBench/Wordcount/Input/part-m-00014
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00014 {'range': 'bytes=293601280-1102230626', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808629346 808629346
# data HiBench/Wordcount/Input/part-m-00015
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00015 {'range': 'bytes=293601280-1102235716', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808634436 808634436
# data HiBench/Wordcount/Input/part-m-00016
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00016 {'range': 'bytes=293601280-1102231274', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808629994 808629994
# data HiBench/Wordcount/Input/part-m-00017
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00017 {'range': 'bytes=293601280-1102242569', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808641289 808641289
# data HiBench/Wordcount/Input/part-m-00018
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00018 {'range': 'bytes=293601280-1102236580', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808635300 808635300
# data HiBench/Wordcount/Input/part-m-00019
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00019 {'range': 'bytes=293601280-1102247090', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808645810 808645810
# data HiBench/Wordcount/Input/part-m-00020
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00020 {'range': 'bytes=293601280-1102242858', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808641578 808641578
# data HiBench/Wordcount/Input/part-m-00021
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00021 {'range': 'bytes=293601280-1102247127', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808645847 808645847
# data HiBench/Wordcount/Input/part-m-00022
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00022 {'range': 'bytes=293601280-1102248056', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808646776 808646776
# data HiBench/Wordcount/Input/part-m-00023
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00023 {'range': 'bytes=293601280-1102242431', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808641151 808641151
# data HiBench/Wordcount/Input/part-m-00024
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00024 {'range': 'bytes=293601280-1102247402', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808646122 808646122
# data HiBench/Wordcount/Input/part-m-00025
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00025 {'range': 'bytes=293601280-1102232215', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808630935 808630935
# data HiBench/Wordcount/Input/part-m-00026
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00026 {'range': 'bytes=293601280-1102245692', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808644412 808644412
# data HiBench/Wordcount/Input/part-m-00027
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00027 {'range': 'bytes=293601280-1102239104', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808637824 808637824
# data HiBench/Wordcount/Input/part-m-00028
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00028 {'range': 'bytes=293601280-1102241471', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808640191 808640191
# data HiBench/Wordcount/Input/part-m-00029
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00029 {'range': 'bytes=293601280-1102237361', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808636081 808636081
# data HiBench/Wordcount/Input/part-m-00030
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00030 {'range': 'bytes=293601280-1102232812', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808631532 808631532
# data HiBench/Wordcount/Input/part-m-00031
# http://192.168.35.41:80/swift/v1/data/HiBench/Wordcount/Input/part-m-00031 {'range': 'bytes=293601280-1102234965', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a737769667495257b26ed464955a822aa5ec1e5433430b46726d4cbbdd7a7108a4b7222016fb26e41f9'}
# 808633685 808633685

# %%
token = conn.get_auth()[1]
print(token)


url = 'http://192.168.35.41:80/swift/v1/'
headers = {"KARIZ_FLUSH_CACHE":"1",
          "X-Auth-Token": token}

print(url, headers)


r=requests.delete(url, headers=headers)
print(r.text)



#curl -i http://192.168.35.41:80/swift/v1/ -X DELETE -H "KARIZ_FLUSH_CACHE" -H "X-Auth-Token: $OS_AUTH_TOKEN"
# Out:
# AUTH_rgwtk0e00000074657374757365723a7377696674502ba352b20b10dccb28aa5ee328cd386e39197cd2cea7b6a803a72b9db57e7595704d6d
# http://192.168.35.41:80/swift/v1/ {'KARIZ_FLUSH_CACHE': '1', 'X-Auth-Token': 'AUTH_rgwtk0e00000074657374757365723a7377696674502ba352b20b10dccb28aa5ee328cd386e39197cd2cea7b6a803a72b9db57e7595704d6d'}
# ---------------------------------------------------------------------------
# BadStatusLine                             Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1355             try:
# -> 1356                 response.begin()
#    1357             except ConnectionError:
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     288             self._close_conn()
# --> 289             raise BadStatusLine(line)
#     290
#
# BadStatusLine: Date: Wed, 29 Apr 2020 01:24:31 GMT
#
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /usr/lib/python3/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# /usr/local/lib/python3.6/dist-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
# --> 702                 raise value.with_traceback(tb)
#     703             raise value
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1355             try:
# -> 1356                 response.begin()
#    1357             except ConnectionError:
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     288             self._close_conn()
# --> 289             raise BadStatusLine(line)
#     290
#
# ProtocolError: ('Connection aborted.', BadStatusLine('Date: Wed, 29 Apr 2020 01:24:31 GMT\r\n',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-157-66d1e0f3a6b5> in <module>
#      10
#      11
# ---> 12 r=requests.delete(url, headers=headers)
#      13 print(r.text)
#      14
#
# /usr/lib/python3/dist-packages/requests/api.py in delete(url, **kwargs)
#     150     """
#     151
# --> 152     return request('delete', url, **kwargs)
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     518         }
#     519         send_kwargs.update(settings)
# --> 520         resp = self.send(prep, **send_kwargs)
#     521
#     522         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     628
#     629         # Send the request
# --> 630         r = adapter.send(request, **kwargs)
#     631
#     632         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488
#     489         except (ProtocolError, socket.error) as err:
# --> 490             raise ConnectionError(err, request=request)
#     491
#     492         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', BadStatusLine('Date: Wed, 29 Apr 2020 01:24:31 GMT\r\n',))
