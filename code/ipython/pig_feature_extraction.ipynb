# %%
# process logs

data =  b'Running Pig Query Q8\nGoing to run:\n/opt/pig-0.17.0//bin/pig -D mapred.min.split.size=536870912 -param input=s3a://data/pig-tpch/20G -param output=/tpch/output -param reducers=1 -f queries/Q8.pig\n\n41   [main] INFO  org.apache.pig.Main  - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58\n41   [main] INFO  org.apache.pig.Main  - Logging error messages to: /local0/pig-err.log\n670  [main] INFO  org.apache.pig.impl.util.Utils  - Default bootup file /root/.pigbootup not found\n766  [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine  - Connecting to hadoop file system at: hdfs://neu-3-1:9000\n1224 [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine  - Connecting to map-reduce job tracker at: yarn\n1243 [main] INFO  org.apache.pig.PigServer  - Pig Script ID for the session: PIG-Q8.pig-8919b802-1133-4109-8547-08574d1616ce\n1243 [main] WARN  org.apache.pig.PigServer  - ATS is disabled since yarn.timeline-service.enabled set to false\n5675 [main] WARN  org.apache.pig.newplan.BaseOperatorPlan  - Encountered Warning IMPLICIT_CAST_TO_DOUBLE 2 time(s).\n5703 [main] INFO  org.apache.pig.tools.pigstats.ScriptState  - Pig features used in the script: REPLICATED_JOIN,HASH_JOIN,GROUP_BY,ORDER_BY,FILTER\n5731 [main] INFO  org.apache.pig.data.SchemaTupleBackend  - Key [pig.schematuple] was not set... will not generate code.\n5890 [main] INFO  org.apache.pig.newplan.logical.optimizer.LogicalPlanOptimizer  - {RULES_ENABLED=[AddForEach, ColumnMapKeyPrune, ConstantCalculator, GroupByConstParallelSetter, LimitOptimizer, LoadTypeCastInserter, MergeFilter, MergeForEach, NestedLimitOptimizer, PartitionFilterOptimizer, PredicatePushdownOptimizer, PushDownForEachFlatten, PushUpFilter, SplitFilter, StreamTypeCastInserter]}\n5921 [main] INFO  org.apache.pig.impl.util.SpillableMemoryManager  - Selected heap (PS Old Gen) of size 699400192 to monitor. collectionUsageThreshold = 489580128, usageThreshold = 489580128\n5999 [main] INFO  org.apache.pig.newplan.logical.rules.ColumnPruneVisitor  - Columns pruned for orders: $2, $3, $5, $6, $7, $8\n6001 [main] INFO  org.apache.pig.newplan.logical.rules.ColumnPruneVisitor  - Columns pruned for supplier: $1, $2, $4, $5, $6\n6001 [main] INFO  org.apache.pig.newplan.logical.rules.ColumnPruneVisitor  - Columns pruned for nation: $3\n6001 [main] INFO  org.apache.pig.newplan.logical.rules.ColumnPruneVisitor  - Columns pruned for customer: $1, $2, $4, $5, $6, $7\n6002 [main] INFO  org.apache.pig.newplan.logical.rules.ColumnPruneVisitor  - Columns pruned for part: $1, $2, $3, $5, $6, $7, $8\n6002 [main] INFO  org.apache.pig.newplan.logical.rules.ColumnPruneVisitor  - Columns pruned for lineitem: $3, $4, $7, $8, $9, $10, $11, $12, $13, $14, $15\n6002 [main] INFO  org.apache.pig.newplan.logical.rules.ColumnPruneVisitor  - Columns pruned for region: $2\n6097 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler  - File concatenation threshold: 100 optimistic? false\n6111 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler  - number of input files: 0\n6114 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler  - number of input files: 100\n6115 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler  - Insert a file-concatenation job\n6121 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler  - number of input files: 0\n6121 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler  - number of input files: 0\n6140 [main] INFO  org.apache.pig.backend.hadoop.executionengine.util.CombinerOptimizerUtil  - Choosing to move algebraic foreach to combiner\n6162 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.SecondaryKeyOptimizerMR  - Using Secondary Key Optimization for MapReduce node scope-288\n6166 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler$LastInputStreamingOptimizer  - Rewrite: POPackage->POForEach to POPackage(JoinPackager)\n6166 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler$LastInputStreamingOptimizer  - Rewrite: POPackage->POForEach to POPackage(JoinPackager)\n6166 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler$LastInputStreamingOptimizer  - Rewrite: POPackage->POForEach to POPackage(JoinPackager)\n6166 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler$LastInputStreamingOptimizer  - Rewrite: POPackage->POForEach to POPackage(JoinPackager)\n6173 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer  - MR plan size before optimization: 12\n6174 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer  - Merged 1 map-only splittees.\n6174 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer  - Merged 1 out of total 3 MR operators.\n6174 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer  - MR plan size after optimization: 11\n6393 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n6396 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n6399 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n6546 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp226821771/pig-0.17.0-core-h2.jar\n6569 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp-1405572375/automaton-1.11-8.jar\n6596 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp-611894699/antlr-runtime-3.4.jar\n6618 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp-1848536936/joda-time-2.9.4.jar\n6636 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up single store job\n6642 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n6642 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n6642 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n6684 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n6685 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n6686 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Reduce phase detected, estimating # of required reducers.\n6686 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting Parallelism to 1\n6686 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n6726 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp-1744004808/pig-0.17.0-core-h2.jar\n6745 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp1711500/automaton-1.11-8.jar\n6765 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp1479605016/antlr-runtime-3.4.jar\n6787 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp-1468399741/joda-time-2.9.4.jar\n6791 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up single store job\n6792 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n6793 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n6793 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n6839 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n6840 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n6840 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n6869 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp181995956/pig-0.17.0-core-h2.jar\n6881 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp917983854/automaton-1.11-8.jar\n6893 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp-1266844442/antlr-runtime-3.4.jar\n6911 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp-2145459041/joda-time-2.9.4.jar\n6914 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up multi store job\n6916 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n6916 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n6916 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n6929 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 3 map-reduce job(s) waiting for submission.\n7012 [JobControl] INFO  org.apache.pig.builtin.PigStorage  - Using PigTextInputFormat\n7209 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 1\n7222 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n7603 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2446\n7604 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases fregion,region\n7604 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M: region[14,9],region[-1,-1],fregion[17,10],fregion[-1,-1] C:  R: \n7631 [JobControl] INFO  org.apache.pig.builtin.PigStorage  - Using PigTextInputFormat\n7792 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 40\n7798 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 20\n7800 [JobControl] INFO  org.apache.pig.builtin.PigStorage  - Using PigTextInputFormat\n7955 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 40\n7958 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 40\n8075 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2447\n8075 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases fpart,lineitem,p1,part\n8075 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M: lineitem[8,11],lineitem[-1,-1],p1[33,5],part[16,7],part[-1,-1],fpart[19,8],fpart[-1,-1],p1[33,5] C:  R: p1[-1,-1]\n8093 [JobControl] INFO  org.apache.pig.builtin.PigStorage  - Using PigTextInputFormat\n8273 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 1\n8274 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n8373 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2448\n8374 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases nation\n8374 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M: nation[12,9],nation[-1,-1],nation[-1,-1] C:  R: \n8391 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 0% complete\n8391 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2446,job_1598736990125_2447,job_1598736990125_2448]\n18529 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 4% complete\n18530 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2446,job_1598736990125_2447,job_1598736990125_2448]\n20537 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 9% complete\n20537 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2446,job_1598736990125_2447,job_1598736990125_2448]\n23544 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 18% complete\n23544 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2447]\n45953 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 22% complete\n45953 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2447]\n165581 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 26% complete\n165582 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2447]\n213837 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n213838 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n213840 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Reduce phase detected, estimating # of required reducers.\n213840 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting Parallelism to 1\n213840 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n213878 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp-944898006/pig-0.17.0-core-h2.jar\n213893 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp63764625/automaton-1.11-8.jar\n213908 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp359645022/antlr-runtime-3.4.jar\n213926 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp-513204514/joda-time-2.9.4.jar\n213929 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up single store job\n213942 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n213942 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n213942 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n213955 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n213955 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n213956 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n213994 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp785213563/pig-0.17.0-core-h2.jar\n214013 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp1626869839/automaton-1.11-8.jar\n214034 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp2100645147/antlr-runtime-3.4.jar\n214055 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp623110363/joda-time-2.9.4.jar\n214058 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up single store job\n214061 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n214061 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n214061 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n214074 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 2 map-reduce job(s) waiting for submission.\n214113 [JobControl] INFO  org.apache.pig.builtin.PigStorage  - Using PigTextInputFormat\n214268 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 40\n214271 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n214279 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 1\n214279 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n214402 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 1\n214402 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n214575 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2449\n214576 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases n2,s1,supplier\n214576 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M: supplier[10,11],supplier[-1,-1],n2[30,5],n2[-1,-1],s1[35,5],s1[35,5] C:  R: s1[-1,-1]\n214579 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2450\n214580 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases n1,nation,seln1\n214580 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M: nation[-1,-1],n1[21,5],seln1[22,8] C:  R: \n224612 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 31% complete\n224613 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2449,job_1598736990125_2450]\n229625 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 40% complete\n229625 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2449]\n239778 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 45% complete\n239778 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2449]\n244927 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n244927 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n244928 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n244973 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp1254245343/pig-0.17.0-core-h2.jar\n244993 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp644381832/automaton-1.11-8.jar\n245010 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp495556446/antlr-runtime-3.4.jar\n245031 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp751708650/joda-time-2.9.4.jar\n245033 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up single store job\n245034 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n245034 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n245034 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n245045 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 1 map-reduce job(s) waiting for submission.\n245075 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 1\n245076 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n245547 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2451\n245547 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases \n245547 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M:  C:  R: \n255113 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 50% complete\n255114 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2451]\n260620 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 54% complete\n260731 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n260732 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n260733 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Reduce phase detected, estimating # of required reducers.\n260733 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting Parallelism to 1\n260733 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n260772 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp790840183/pig-0.17.0-core-h2.jar\n260789 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp273625585/automaton-1.11-8.jar\n260804 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp1468801631/antlr-runtime-3.4.jar\n260823 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp1061338696/joda-time-2.9.4.jar\n260826 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up single store job\n260829 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n260829 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n260829 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n260845 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 1 map-reduce job(s) waiting for submission.\n260878 [JobControl] INFO  org.apache.pig.builtin.PigStorage  - Using PigTextInputFormat\n261031 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 40\n261036 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 20\n261038 [JobControl] INFO  org.apache.pig.builtin.PigStorage  - Using PigTextInputFormat\n261185 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 40\n261188 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 40\n261346 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2452\n261346 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases c1,customer,forders,o1,orders,selc1\n261346 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M: orders[6,9],orders[-1,-1],forders[18,10],o1[27,5],customer[4,11],customer[-1,-1],c1[24,5],selc1[25,8],o1[27,5] C:  R: o1[-1,-1]\n283422 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 59% complete\n283422 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2452]\n305451 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 63% complete\n305451 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2452]\n306625 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n306625 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n306626 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Reduce phase detected, estimating # of required reducers.\n306626 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting Parallelism to 1\n306626 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n306666 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp178867505/pig-0.17.0-core-h2.jar\n306684 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp1909347544/automaton-1.11-8.jar\n306701 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp72089544/antlr-runtime-3.4.jar\n306718 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp1679633965/joda-time-2.9.4.jar\n306719 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up single store job\n306720 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n306720 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n306720 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n306735 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 1 map-reduce job(s) waiting for submission.\n306761 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 1\n306761 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n306764 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 1\n306764 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n307236 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2453\n307236 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases l1,sels1\n307236 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M: l1[37,5],l1[37,5] C:  R: sels1[39,8]\n324302 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 68% complete\n324302 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2453]\n332313 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 72% complete\n332313 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2453]\n337448 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n337449 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n337450 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Reduce phase detected, estimating # of required reducers.\n337450 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting Parallelism to 1\n337450 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n337491 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp1634522664/pig-0.17.0-core-h2.jar\n337510 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp746491329/automaton-1.11-8.jar\n337528 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp-218510913/antlr-runtime-3.4.jar\n337547 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp-432593271/joda-time-2.9.4.jar\n337551 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up single store job\n337552 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n337552 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n337552 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n337572 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 1 map-reduce job(s) waiting for submission.\n337588 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 1\n337588 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n338073 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2454\n338073 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases grResult,sumResult\n338073 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M: sumResult[42,12],grResult[40,11] C: sumResult[42,12],grResult[40,11] R: sumResult[42,12]\n347142 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 77% complete\n347143 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2454]\n352649 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 81% complete\n352649 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2454]\n358272 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n358272 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n358274 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Reduce phase detected, estimating # of required reducers.\n358275 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting Parallelism to 1\n358275 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n358329 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp-1263272118/pig-0.17.0-core-h2.jar\n358343 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp-266562766/automaton-1.11-8.jar\n358357 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp-686831069/antlr-runtime-3.4.jar\n358374 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp-122140433/joda-time-2.9.4.jar\n358377 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up single store job\n358378 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n358378 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n358378 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n358394 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 1 map-reduce job(s) waiting for submission.\n358419 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 1\n358419 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n358896 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2455\n358896 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases sortResult\n358896 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M: sortResult[43,13] C:  R: \n368949 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 86% complete\n368949 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2455]\n375958 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 90% complete\n375959 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2455]\n379069 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState  - Pig script settings are added to the job\n379070 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3\n379070 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Reduce phase detected, estimating # of required reducers.\n379070 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting Parallelism to 1\n379070 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - This job cannot be converted run in-process\n379106 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/pig-0.17.0-core-h2.jar to DistributedCache through /tmp/temp-729171684/tmp1282627642/pig-0.17.0-core-h2.jar\n379125 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/automaton-1.11-8.jar to DistributedCache through /tmp/temp-729171684/tmp396688587/automaton-1.11-8.jar\n379151 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/pig-0.17.0/lib/antlr-runtime-3.4.jar to DistributedCache through /tmp/temp-729171684/tmp1530843668/antlr-runtime-3.4.jar\n379169 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Added jar file:/opt/hadoop-2.8.4/share/hadoop/hdfs/lib/joda-time-2.9.4.jar to DistributedCache through /tmp/temp-729171684/tmp-1254193455/joda-time-2.9.4.jar\n379172 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler  - Setting up single store job\n379172 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Key [pig.schematuple] is false, will not generate code.\n379172 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Starting process to move generated code to distributed cacche\n379172 [main] INFO  org.apache.pig.data.SchemaTupleFrontend  - Setting key [pig.schematuple.classes] with classes to deserialize []\n379190 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 1 map-reduce job(s) waiting for submission.\n379218 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths to process : 1\n379218 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil  - Total input paths (combined) to process : 1\n379692 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - HadoopJobId: job_1598736990125_2456\n379692 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Processing aliases sortResult\n379692 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - detailed locations: M: sortResult[43,13] C:  R: \n391714 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 95% complete\n391714 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2456]\n396723 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Running jobs are [job_1598736990125_2456]\n399838 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - 100% complete\n399841 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.SimplePigStats  - Script Statistics: \n\nHadoopVersion\tPigVersion\tUserId\tStartedAt\tFinishedAt\tFeatures\n2.8.4\t0.17.0\troot\t2020-09-01 22:02:43\t2020-09-01 22:09:17\tREPLICATED_JOIN,HASH_JOIN,GROUP_BY,ORDER_BY,FILTER\n\nSuccess!\n\nJob Stats (time in seconds):\nJobId\tMaps\tReduces\tMaxMapTime\tMinMapTime\tAvgMapTime\tMedianMapTime\tMaxReduceTime\tMinReduceTime\tAvgReduceTime\tMedianReducetime\tAlias\tFeature\tOutputs\njob_1598736990125_2446\t1\t0\t3\t3\t3\t3\t0\t0\t0\t0\tfregion,region\tMAP_ONLY\t\njob_1598736990125_2447\t60\t1\t36\t3\t21\t26\t180\t180\t180\t180\tfpart,lineitem,p1,part\tHASH_JOIN\t\njob_1598736990125_2448\t1\t0\t3\t3\t3\t3\t0\t0\t0\t0\tnation\tMULTI_QUERY,MAP_ONLY\t\njob_1598736990125_2449\t2\t1\t7\t6\t7\t7\t9\t9\t9\t9\tn2,s1,supplier\tREPLICATED_JOIN,HASH_JOIN\t\njob_1598736990125_2450\t1\t0\t3\t3\t3\t3\t0\t0\t0\t0\tn1,nation,seln1\tREPLICATED_JOIN,MAP_ONLY\t\njob_1598736990125_2451\t1\t0\t2\t2\t2\t2\t0\t0\t0\t0\t\tMAP_ONLY\t\njob_1598736990125_2452\t60\t1\t10\t4\t7\t7\t26\t26\t26\t26\tc1,customer,forders,o1,orders,selc1\tREPLICATED_JOIN,HASH_JOIN\t\njob_1598736990125_2453\t2\t1\t8\t5\t7\t7\t10\t10\t10\t10\tl1,sels1\tHASH_JOIN\t\njob_1598736990125_2454\t1\t1\t3\t3\t3\t3\t3\t3\t3\t3\tgrResult,sumResult\tGROUP_BY,COMBINER\t\njob_1598736990125_2455\t1\t1\t2\t2\t2\t2\t2\t2\t2\t2\tsortResult\tSAMPLER\t\njob_1598736990125_2456\t1\t1\t3\t3\t3\t3\t3\t3\t3\t3\tsortResult\tORDER_BY\t/tpch/output/Q8out,\n\nInput(s):\nSuccessfully read 4000000 records from: "s3a://data/pig-tpch/20G/part"\nSuccessfully read 119994608 records from: "s3a://data/pig-tpch/20G/lineitem"\nSuccessfully read 25 records (368 bytes) from: "s3a://data/pig-tpch/20G/nation"\nSuccessfully read 200000 records from: "s3a://data/pig-tpch/20G/supplier"\nSuccessfully read 5 records (368 bytes) from: "s3a://data/pig-tpch/20G/region"\nSuccessfully read 3000000 records from: "s3a://data/pig-tpch/20G/customer"\nSuccessfully read 30000000 records from: "s3a://data/pig-tpch/20G/orders"\n\nOutput(s):\nSuccessfully stored 2 records (50 bytes) in: "/tpch/output/Q8out"\n\nCounters:\nTotal records written : 2\nTotal bytes written : 50\nSpillable Memory Manager spill count : 0\nTotal bags proactively spilled: 0\nTotal records proactively spilled: 0\n\nJob DAG:\njob_1598736990125_2447\t->\tjob_1598736990125_2449,\njob_1598736990125_2448\t->\tjob_1598736990125_2449,job_1598736990125_2450,\njob_1598736990125_2449\t->\tjob_1598736990125_2453,\njob_1598736990125_2446\t->\tjob_1598736990125_2450,\njob_1598736990125_2450\t->\tjob_1598736990125_2451,\njob_1598736990125_2451\t->\tjob_1598736990125_2452,\njob_1598736990125_2452\t->\tjob_1598736990125_2453,\njob_1598736990125_2453\t->\tjob_1598736990125_2454,\njob_1598736990125_2454\t->\tjob_1598736990125_2455,\njob_1598736990125_2455\t->\tjob_1598736990125_2456,\njob_1598736990125_2456\n\n\n400771 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher  - Success!\n400786 [main] INFO  org.apache.pig.Main  - Pig script completed in 6 minutes, 40 seconds and 948 milliseconds (400948 ms)\n   Q8 times (sec):\t402\n\n'
print(data.decode())
# Out:
# Running Pig Query Q8
# Going to run:
# /opt/pig-0.17.0//bin/pig -D mapred.min.split.size=536870912 -param input=s3a://data/pig-tpch/20G -param output=/tpch/output -param reducers=1 -f queries/Q8.pig
#
# 41   [main] INFO  org.apache.pig.Main  - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58
# 41   [main] INFO  org.apache.pig.Main  - Logging error messages to: /local0/pig-err.log
# 670  [main] INFO  org.apache.pig.impl.util.Utils  - Default bootup file /root/.pigbootup not found
# 766  [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine  - Connecting to hadoop file system at: hdfs://neu-3-1:9000
# 1224 [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine  - Connecting to map-reduce job tracker at: yarn
# 1243 [main] INFO  org.apache.pig.PigServer  - Pig Script ID for the session: PIG-Q8.pig-8919b802-1133-4109-8547-08574d1616ce
# ...

# %%
import pandas as pd
import graph_tool.all as gt
import requests
import json

def add_dag_to_pool(g, app_name):
    templatef='pig.tpch.template'

    g_str = '#t\t%s\n'%(app_name)
    for v in g.vertices():
        g_str += 'v,%d,%s,%s\n'%(int(v), g.vp.feature[v], g.vp.tables[v])
    for e in g.edges():
        g_str += 'e,%d,%d\n'%(int(e.source()), int(e.target()))

    print(g_str)


def get_s3_objects(jobid):
    host_name='neu-3-1'
    port=19888
    url = 'http://%s:%d/ws/v1/history/mapreduce/jobs/%s/conf'%(host_name, port, jobid)
    r=requests.get(url)
    confs = r.json()['conf']['property']
    tables = [i.split('/')[-1] for i in [c['value'] for c in confs if c['name'] == 'pig.input.dirs'][0].split(',') if i.startswith('s3a')]
    return tables


def build_dag(dag_str, df):
    g = gt.Graph(directed=True)
    
    jid_to_vis = {}
    vis_to_jid = {}
    
    for ln in dag_str:
        vertices = []

        for vstr in ln.replace('\t', '').split(',')[:-1]:
            vertices.extend(vstr.split('->'))

        print(vertices)
        for jid in vertices:
        
            if jid not in jid_to_vis:
                v = g.add_vertex()
                jid_to_vis[jid] = v
                vis_to_jid[v] = jid

    for ln in dag_str:
        vertices = ln.replace('\t', '').split('->')
        if len(vertices) == 2:
            src_jid = vertices[0]
            dst_jids = vertices[1].split(',')[:-1]
            for dst_jid in dst_jids:
                g.add_edge(jid_to_vis[src_jid], jid_to_vis[dst_jid])
    
    
    v_feature = g.new_vertex_property('string')
    v_tables = g.new_vertex_property('string')
    
    for v in g.vertices():
        v_feature[v] = df[df['JobId'] == vis_to_jid[v]]['Feature'].values[0].replace(',', ':')
        v_tables[v] = ':'.join(get_s3_objects(vis_to_jid[v]))
        
    g.vp.feature = v_feature
    g.vp.tables = v_tables
        
    gt.graph_draw(g, vertex_text=g.vertex_index, size=(300, 300))
    return g
        
string = data.decode('utf-8')


dag_str = [ln for ln in string.split('Job DAG:')[1].split('\n') if ln.startswith('job')]
dag_runtime = [int(ln.split('\t')[1]) for ln in string.split('Job DAG:')[1].split('\n') if 'times (sec):' in ln][0]

app_meta = {'app_name': 'name'}

substring = [i for i in string.split('Success!')[1].split('Input(s):')[0].split('\n') if i][1:]
df = pd.DataFrame([{**dict(zip(substring[0].split('\t'), s.split('\t'))), **app_meta} for s in substring[1:]])

g=build_dag(dag_str, df)
add_dag_to_pool(g, app_meta['app_name'])

print(dag_runtime)
# Out:
# ['job_1598736990125_2447', 'job_1598736990125_2449']
# ['job_1598736990125_2448', 'job_1598736990125_2449', 'job_1598736990125_2450']
# ['job_1598736990125_2449', 'job_1598736990125_2453']
# ['job_1598736990125_2446', 'job_1598736990125_2450']
# ['job_1598736990125_2450', 'job_1598736990125_2451']
# ['job_1598736990125_2451', 'job_1598736990125_2452']
# ['job_1598736990125_2452', 'job_1598736990125_2453']
# ['job_1598736990125_2453', 'job_1598736990125_2454']
# ['job_1598736990125_2454', 'job_1598736990125_2455']
# ['job_1598736990125_2455', 'job_1598736990125_2456']
# []
# job_1598736990125_2447 job_1598736990125_2449
# job_1598736990125_2448 job_1598736990125_2449
# job_1598736990125_2448 job_1598736990125_2450
# job_1598736990125_2449 job_1598736990125_2453
# job_1598736990125_2446 job_1598736990125_2450
# job_1598736990125_2450 job_1598736990125_2451
# job_1598736990125_2451 job_1598736990125_2452
# job_1598736990125_2452 job_1598736990125_2453
# ...

# %%
import pandas as pd

string = data.decode('utf-8')

app_meta_str = 'name:tpch-bw:10Gbps-ds:20G'
app_meta = {}
for i in app_meta_str.split('-'):
    app_meta[i.split(':')[0]] = i.split(':')[1]

print(app_meta)

substring = [i for i in string.split('Success!')[1].split('Input(s):')[0].split('\n') if i][1:]
df = pd.DataFrame([{**dict(zip(substring[0].split('\t'), s.split('\t'))), **app_meta} for s in substring[1:]])

df
# Out:
# {'name': 'tpch', 'bw': '10Gbps', 'ds': '20G'}
#                                 Alias AvgMapTime AvgReduceTime    Feature  \
# 0  flineitem,l1,lineitem,orders,sell1         15            80  HASH_JOIN
# 1        grpResult,sumResult,urgItems          4             4   GROUP_BY
# 2                          sortResult          3             3    SAMPLER
# 3                          sortResult          2             3   ORDER_BY
#
#                     JobId Maps MaxMapTime MaxReduceTime MedianMapTime  \
# 0  job_1598736990125_2385   80         29            80            14
# 1  job_1598736990125_2386    1          4             4             4
# 2  job_1598736990125_2387    1          3             3             3
# 3  job_1598736990125_2388    1          2             3             2
#
#   MedianReducetime MinMapTime MinReduceTime               Outputs Reduces  \
# 0               80          7            80                             1
# ...

# %%
prefetch_path = '/local0/Kariz/expriments/runtime_prediction/tpch/%s'%('runtime.pred.pig.prefetch.csv')
stat_path = '/local0/Kariz/expriments/runtime_prediction/tpch/%s'%('runtime.pred.pig.stats.csv')

prefetch_df = pd.read_csv(prefetch_path)
stats_df = pd.read_csv(stat_path)


stats_df
# Out:
#                                                  Alias  AvgMapTime  \
# 0     flineitem,glineitem,lineitem,revenue,sumlineitem          16
# 1                                 grevenue,max_revenue           5
# 2                          j1,sel,supplier,top_revenue           5
# 3                                                  ord           2
# 4                                                  ord           3
# 5                  COG,lineitem,lineitem_orders,orders          14
# 6                    customer,lineitem_orders_customer           6
# 7                lineitem_orders_customer_group,result           2
# 8                                                  out           2
# 9                                                  out           2
# 10                    c1,customer,forders,orders,selc1           7
# 11                                     nation,o1,selo1          10
# 12                         flineitem,l1,lineitem,sell1          18
# ...

# %%
prefetch_df
# Out:
#     framework:pig:name:tpch21-bw:5Gbps-ds:s3a://data/pig-tpch/64G-stride:10  \
# 0    framework:pig:name:tpch21-bw:5Gbps-ds:s3a://da...
# 1    framework:pig:name:tpch21-bw:5Gbps-ds:s3a://da...
# 2    framework:pig:name:tpch21-bw:5Gbps-ds:s3a://da...
# 3    framework:pig:name:tpch21-bw:5Gbps-ds:s3a://da...
# 4    framework:pig:name:tpch21-bw:5Gbps-ds:s3a://da...
# 5    framework:pig:name:tpch21-bw:5Gbps-ds:s3a://da...
# 6    framework:pig:name:tpch21-bw:5Gbps-ds:s3a://da...
# 7    framework:pig:name:tpch18-bw:40Gbps-ds:32G-str...
# 8    framework:pig:name:tpch18-bw:40Gbps-ds:32G-str...
# 9    framework:pig:name:tpch18-bw:40Gbps-ds:32G-str...
# 10   framework:pig:name:tpch18-bw:40Gbps-ds:32G-str...
# 11   framework:pig:name:tpch18-bw:40Gbps-ds:32G-str...
# 12   framework:pig:name:tpch18-bw:40Gbps-ds:32G-str...
# 13   framework:pig:name:tpch18-bw:40Gbps-ds:32G-str...
# 14   framework:pig:name:tpch18-bw:40Gbps-ds:32G-str...
# 15   framework:pig:name:tpch10-bw:5Gbps-ds:64G-stri...
# ...

# %%
from collections import Counter

# count unique features
fpath = '/local0/Kariz/expriments/runtime_prediction/tpch/%s'%('pig.tpch.template')

with open(fpath, 'r') as fd:
    vs = [ln.replace('\n', '').split(',')[2] for ln in fd.readlines() if ln.startswith('v')]
    print(len(vs), len(Counter(vs).keys()))
    
    
    
dict(zip(Counter(vs).keys(), Counter(vs).values()))
# Out:
# 121 15
# {'HASH_JOIN': 35,
#  'GROUP_BY': 2,
#  'SAMPLER': 18,
#  'ORDER_BY': 14,
#  'COGROUP': 4,
#  'GROUP_BY:COMBINER': 20,
#  'MAP_ONLY': 7,
#  'REPLICATED_JOIN:HASH_JOIN': 6,
#  'MULTI_QUERY:MAP_ONLY': 1,
#  'REPLICATED_JOIN:MAP_ONLY': 1,
#  'MULTI_QUERY:COMBINER': 2,
#  'ORDER_BY:COMBINER': 4,
#  '': 4,
#  'DISTINCT': 2,
#  'GROUP_BY:MULTI_QUERY': 1}

# %%
import itertools
import json
import os 
import random

strides = [10, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100]
datasets = ['1GB', '4GB', '8GB', '10GB', '16GB', '32GB', '48GB', '64GB', '80GB']
rgw_rates=[ '1Gbps', '5Gbps', '10Gbps', '20Gbps', '40Gbps']

benchmark_root="/local0/Kariz/expriments/benchmark/BenchmarkScripts/tpch/pig"
queries = [f.replace('Q', '').replace('.pig', '') for f in os.listdir('%s/queries'%(benchmark_root)) if f.endswith('.pig')]

possible_experiemnts = {}
for q in queries:
    for rt in rgw_rates:
        for ds in datasets:
            for st in strides:
                exp_name = '%s:%s:%s:%d'%(q,rt, ds, st)
                possible_experiemnts[exp_name] = {'query': q, 'rgw_rate': rt, 'dataset': ds, 'stride': st}
                
print(len(possible_experiemnts))
for i in range(0, 10):
    exp_name = random.choice(list(possible_experiemnts))
    experiment = possible_experiemnts[exp_name]
    
    del possible_experiemnts[exp_name]
    print(experiment)
# Out:
# 10890
# {'query': '7', 'rgw_rate': '1Gbps', 'dataset': '48GB', 'stride': 20}
# {'query': '12', 'rgw_rate': '20Gbps', 'dataset': '48GB', 'stride': 70}
# {'query': '13', 'rgw_rate': '5Gbps', 'dataset': '10GB', 'stride': 90}
# {'query': '4', 'rgw_rate': '40Gbps', 'dataset': '80GB', 'stride': 90}
# {'query': '14', 'rgw_rate': '1Gbps', 'dataset': '10GB', 'stride': 70}
# {'query': '21', 'rgw_rate': '20Gbps', 'dataset': '48GB', 'stride': 30}
# {'query': '22', 'rgw_rate': '10Gbps', 'dataset': '32GB', 'stride': 20}
# {'query': '12', 'rgw_rate': '40Gbps', 'dataset': '64GB', 'stride': 40}
# {'query': '1', 'rgw_rate': '20Gbps', 'dataset': '32GB', 'stride': 100}
# {'query': '22', 'rgw_rate': '1Gbps', 'dataset': '32GB', 'stride': 60}

# %%
def build_input_format(inputs_str):
    return ' '.join(inputs_str.split(':')).split()

def load_graph_templates(path):
    graph_skeletons = {}
    with open(path, 'r') as fd:
        graph_strs = fd.read().split('#')[1:]
        for g_str in graph_strs:
            g= build_graph_skeleton(g_str)
            graph_skeletons[g.gp.name] = g
    return graph_skeletons


def build_graph_skeleton(g_str):
    g_elements = g_str.split('\n')
    g_name = g_elements[0].split('\t')[1]
    g_id = 0
    g_queuetime = 0

    g = gt.Graph(directed=True)
    g.gp['name'] = g.new_graph_property("string", g_name)
    g.gp['id'] = g.new_graph_property("string", str(g_id))
    g.gp['queue_time'] = g.new_graph_property("int", g_queuetime)
    g.gp['cur_stage'] = g.new_graph_property("int", -1)
    status = g.new_vertex_property("int")
    inputs = g.new_vertex_property("object")
    cache_runtime = g.new_vertex_property("int")
    remote_runtime = g.new_vertex_property("int")
    color = g.new_vertex_property("string")
    ops = g.new_vertex_property("string")

    # build vertices
    for el in g_elements[1:]:
        if el.startswith('v'):
            vid, operation, inputs_str = el.split(',')[1:]
            v = g.add_vertex()

            inputs[v] = build_input_format(inputs_str)
            colorv = '' if len(inputs[v]) > 0 else ''
            cache_runtime[v] = 0
            remote_runtime[v] = 0
            ops[v] = operation

    # build edges
    for el in g_elements[1:]:
        if el.startswith('e'):
            v_src, v_dest = el.split(',')[1:]
            e = g.add_edge(v_src, v_dest)

    g.vp['tables'] = inputs
    g.vp['remote_runtime'] = remote_runtime
    g.vp['cache_runtime'] = cache_runtime
    g.vp['status'] = status
    g.vp['feature'] = ops
    gt.graph_draw(g, vertex_text=g.vertex_index, size=(300, 300))
    
    return g

graphs_pool = load_graph_templates('/local0/Kariz/expriments/simulator/multidag/%s'%('pig.tpch.template'))

# %%
dt[df['Feature'] == '']
