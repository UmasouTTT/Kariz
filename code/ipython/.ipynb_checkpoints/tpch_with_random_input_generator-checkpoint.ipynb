# %%
# read graphs and build graph pool 
import graph_tool.all as gt

import sys
sys.path.append('/local0/Kariz/code')
import utils.objectstore as object_store

def build_input_format(inputs_str):
    return ' '.join(inputs_str.split(':')).split()

def load_graph_templates(path):
    graph_skeletons = {}
    with open(path, 'r') as fd:
        graph_strs = fd.read().split('#')[1:]
        for g_str in graph_strs:
            g= build_graph_skeleton(g_str)
            graph_skeletons[g.gp.name] = g
    return graph_skeletons


def build_graph_skeleton(g_str):
    g_elements = g_str.split('\n')
    g_name = g_elements[0].split('\t')[1]
    g_id = 0
    g_queuetime = 0

    g = gt.Graph(directed=True)
    g.gp['name'] = g.new_graph_property("string", g_name)
    g.gp['id'] = g.new_graph_property("string", str(g_id))
    g.gp['queue_time'] = g.new_graph_property("int", g_queuetime)
    g.gp['cur_stage'] = g.new_graph_property("int", -1)
    status = g.new_vertex_property("int")
    inputs = g.new_vertex_property("string")
    cache_runtime = g.new_vertex_property("float")
    remote_runtime = g.new_vertex_property("int")
    color = g.new_vertex_property("string")
    ops = g.new_vertex_property("string")
    vids = g.new_vertex_property("int")
    id_v = {}
    
    # build vertices
    for el in g_elements[1:]:
        if el.startswith('v'):
            vid, operation, inputs_str = el.split(',')[1:]
            v = g.add_vertex()
            vids[v] = int(vid)
            id_v[int(vid)] = v
            inputs[v] = inputs_str #build_input_format(inputs_str)
            #print(inputs_str)
            color[v] = '#fb8072' if len(inputs[v]) > 0 else '#80b1d3'
            cache_runtime[v] = 0
            remote_runtime[v] = 0
            ops[v] = operation if operation else 'SAVE'

    # build edges
    for el in g_elements[1:]:
        if el.startswith('e'):
            v_src, v_dest = el.split(',')[1:]
            e = g.add_edge(id_v[int(v_src)], id_v[int(v_dest)])

    g.vp['id'] = vids
    g.vp['color'] = color
    g.vp['tables'] = inputs
    g.vp['remote_runtime'] = remote_runtime
    g.vp['cache_runtime'] = cache_runtime
    g.vp['status'] = status
    g.vp['feature'] = ops
    print('Load query:', g_name)
    return g

graphs_pool = load_graph_templates('/local0/Kariz/expriments/simulator/multidag/%s'%('pig.tpch.template'))

inputs = object_store.load_object_meta('/local0/Kariz/expriments/simulator/multidag/config/inputs.csv')
# Out:
# Load query: TPCH_Q12
# Load query: TPCH_Q17
# Load query: TPCH_Q9
# Load query: TPCH_Q4
# Load query: TPCH_Q16
# Load query: TPCH_Q8
# Load query: TPCH_Q7
# Load query: TPCH_Q22
# Load query: TPCH_Q19
# Load query: TPCH_Q6
# Load query: TPCH_Q3
# Load query: TPCH_Q5
# Load query: TPCH_Q15
# Load query: TPCH_Q18
# Load query: TPCH_Q13
# Load query: TPCH_Q10
# Load query: TPCH_Q14
# Load query: TPCH_Q20
# Load query: TPCH_Q21
# Load query: TPCH_Q2
# Load query: TPCH_Q11
# Load query: TPCH_Q1

# %%
import random 

def choose_input(seen_objects):
    reuse = random.choices([1, 0], cum_weights=(reuse_ratio, 1.00), k=1)[0]
    table, _ = random.choice(list(seen_objects.items())) if ((reuse) and (len(seen_objects) > 5)) else random.choice(list(inputs.items())) 
    seen_objects[table] = 1 if table not in seen_objects else seen_objects[table]+1
    return table

def random_query():
    gid, g = random.choice(list(graphs_pool.items()))
    return gid, g.copy()
    
reuse_ratio = 0.32
cfg_n_similar = 6
max_dag_concurrency=10
min_dag_concurrency=1
n_iterations = 10

seen_objects = {}
workload_str=''
g = None
for it in range(0, n_iterations):
    n_similar = cfg_n_similar
    n_concurrent_dags = 10 #random.randint(min_dag_concurrency, max_dag_concurrency)
    workload_str += ("%" + 'r,%d,%d\n'%(it,n_concurrent_dags))
    for i in range(0, n_concurrent_dags):
        if not (g and g.num_vertices() > 4 and n_similar > 1):
            gid, g = random_query()
        else:
            n_similar -= 1
            
        workload_str += ('#t,%d%d,%s\n'%(it,i,gid))
        for v in g.vertices():
            t_compute = random.randint(5, 100)
            t_reduction = 1
            if len(g.vp.tables[v]) > 0: 
                table = choose_input(seen_objects) 
                g.vp.tables[v] = table
                t_reduction = random.uniform(0.3, 1)
            workload_str += ('v,%d,%s,%s,%d,%.2f\n'%(g.vp.id[v],g.vp.feature[v],g.vp.tables[v],
                                            t_compute, t_reduction))
        for e in g.edges():
            workload_str += ('e,%d,%d\n'%(g.vp.id[e.source()],g.vp.id[e.target()]))
    
print(workload_str)
workload_file = '/local0/Kariz/expriments/simulator/multidag/config/synthetic_worload_8.g'
with open(workload_file, 'w') as fd:
    fd.write(workload_str)
# Out:
# %r,0,10
# #t,00,TPCH_Q13
# v,0,COGROUP,o12,41,0.74
# v,1,GROUP_BY:COMBINER,,85,1.00
# v,2,SAMPLER,,16,1.00
# v,3,ORDER_BY,,18,1.00
# e,0,1
# e,1,2
# e,2,3
# #t,01,TPCH_Q18
# v,0,COGROUP,g16,85,0.30
# v,1,HASH_JOIN,w12,88,0.81
# v,2,GROUP_BY:COMBINER,,8,1.00
# v,3,SAMPLER,,49,1.00
# v,4,ORDER_BY,,61,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,02,TPCH_Q18
# v,0,COGROUP,e8,41,0.36
# v,1,HASH_JOIN,b16,28,0.74
# v,2,GROUP_BY:COMBINER,,27,1.00
# v,3,SAMPLER,,87,1.00
# v,4,ORDER_BY,,17,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,03,TPCH_Q18
# v,0,COGROUP,o18,61,0.46
# v,1,HASH_JOIN,b16,51,0.48
# v,2,GROUP_BY:COMBINER,,6,1.00
# v,3,SAMPLER,,53,1.00
# v,4,ORDER_BY,,79,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,04,TPCH_Q18
# v,0,COGROUP,c5,53,0.64
# v,1,HASH_JOIN,c5,18,0.68
# v,2,GROUP_BY:COMBINER,,65,1.00
# v,3,SAMPLER,,79,1.00
# v,4,ORDER_BY,,39,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,05,TPCH_Q18
# v,0,COGROUP,l18,84,0.67
# v,1,HASH_JOIN,g16,23,0.73
# v,2,GROUP_BY:COMBINER,,26,1.00
# v,3,SAMPLER,,30,1.00
# v,4,ORDER_BY,,43,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,06,TPCH_Q18
# v,0,COGROUP,e0,44,0.60
# v,1,HASH_JOIN,e8,51,0.89
# v,2,GROUP_BY:COMBINER,,13,1.00
# v,3,SAMPLER,,6,1.00
# v,4,ORDER_BY,,8,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,07,TPCH_Q13
# v,0,COGROUP,w15,75,0.89
# v,1,GROUP_BY:COMBINER,,100,1.00
# v,2,SAMPLER,,95,1.00
# v,3,ORDER_BY,,34,1.00
# e,0,1
# e,1,2
# e,2,3
# #t,08,TPCH_Q3
# v,0,HASH_JOIN,y16,68,0.82
# v,1,HASH_JOIN,r12,42,0.62
# v,2,GROUP_BY:COMBINER,,96,1.00
# v,3,SAMPLER,,95,1.00
# v,4,ORDER_BY:COMBINER,,25,1.00
# v,5,SAVE,,40,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# #t,09,TPCH_Q13
# v,0,COGROUP,q15,89,0.64
# v,1,GROUP_BY:COMBINER,,75,1.00
# v,2,SAMPLER,,40,1.00
# v,3,ORDER_BY,,94,1.00
# e,0,1
# e,1,2
# e,2,3
# %r,1,10
# #t,10,TPCH_Q5
# v,0,HASH_JOIN,i0,78,0.45
# v,1,HASH_JOIN,e0,20,0.75
# v,2,HASH_JOIN,t17,79,0.56
# v,3,HASH_JOIN,w19,18,0.76
# v,4,HASH_JOIN,g16,79,0.72
# v,5,GROUP_BY:COMBINER,,21,1.00
# v,6,SAMPLER,,57,1.00
# v,7,ORDER_BY,,72,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,11,TPCH_Q5
# v,0,HASH_JOIN,m19,7,0.75
# v,1,HASH_JOIN,d1,44,0.58
# v,2,HASH_JOIN,u11,97,0.89
# v,3,HASH_JOIN,p18,17,0.47
# v,4,HASH_JOIN,g13,79,0.58
# v,5,GROUP_BY:COMBINER,,45,1.00
# v,6,SAMPLER,,12,1.00
# v,7,ORDER_BY,,88,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,12,TPCH_Q5
# v,0,HASH_JOIN,w19,64,0.79
# v,1,HASH_JOIN,w19,87,0.78
# v,2,HASH_JOIN,x14,27,0.32
# v,3,HASH_JOIN,b2,51,0.60
# v,4,HASH_JOIN,p15,18,0.73
# v,5,GROUP_BY:COMBINER,,55,1.00
# v,6,SAMPLER,,64,1.00
# v,7,ORDER_BY,,47,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,13,TPCH_Q5
# v,0,HASH_JOIN,n18,39,0.39
# v,1,HASH_JOIN,o13,49,0.76
# v,2,HASH_JOIN,b7,40,0.58
# v,3,HASH_JOIN,b13,10,0.73
# v,4,HASH_JOIN,c13,32,0.52
# v,5,GROUP_BY:COMBINER,,34,1.00
# v,6,SAMPLER,,19,1.00
# v,7,ORDER_BY,,9,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,14,TPCH_Q5
# v,0,HASH_JOIN,e1,8,0.72
# v,1,HASH_JOIN,p15,88,0.54
# v,2,HASH_JOIN,c4,8,0.89
# v,3,HASH_JOIN,p18,35,0.59
# v,4,HASH_JOIN,k19,32,0.34
# v,5,GROUP_BY:COMBINER,,70,1.00
# v,6,SAMPLER,,53,1.00
# v,7,ORDER_BY,,30,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,15,TPCH_Q5
# v,0,HASH_JOIN,b7,100,0.98
# v,1,HASH_JOIN,r17,27,0.78
# v,2,HASH_JOIN,z15,40,0.92
# v,3,HASH_JOIN,l19,14,0.81
# v,4,HASH_JOIN,c11,21,0.74
# v,5,GROUP_BY:COMBINER,,47,1.00
# v,6,SAMPLER,,96,1.00
# v,7,ORDER_BY,,34,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,16,TPCH_Q7
# v,0,MAP_ONLY,r17,29,0.43
# v,1,REPLICATED_JOIN:HASH_JOIN,q15,59,0.97
# v,2,HASH_JOIN,,91,1.00
# v,3,MAP_ONLY,l11,28,0.53
# v,4,REPLICATED_JOIN:HASH_JOIN,h19,98,0.37
# v,5,GROUP_BY:COMBINER,,43,1.00
# v,6,SAMPLER,,11,1.00
# v,7,ORDER_BY,,96,1.00
# e,0,1
# e,1,2
# e,2,5
# e,3,4
# e,4,2
# e,5,6
# e,6,7
# #t,17,TPCH_Q18
# v,0,COGROUP,d2,89,0.75
# v,1,HASH_JOIN,c5,79,0.76
# v,2,GROUP_BY:COMBINER,,31,1.00
# v,3,SAMPLER,,26,1.00
# v,4,ORDER_BY,,14,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,18,TPCH_Q18
# v,0,COGROUP,o12,31,0.79
# v,1,HASH_JOIN,u19,86,0.97
# v,2,GROUP_BY:COMBINER,,33,1.00
# v,3,SAMPLER,,36,1.00
# v,4,ORDER_BY,,90,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,19,TPCH_Q5
# v,0,HASH_JOIN,o12,10,0.89
# v,1,HASH_JOIN,w12,39,0.57
# v,2,HASH_JOIN,n18,57,0.57
# v,3,HASH_JOIN,i13,69,0.70
# v,4,HASH_JOIN,e9,60,0.47
# v,5,GROUP_BY:COMBINER,,58,1.00
# v,6,SAMPLER,,36,1.00
# v,7,ORDER_BY,,88,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# %r,2,10
# #t,20,TPCH_Q5
# v,0,HASH_JOIN,v16,81,0.97
# v,1,HASH_JOIN,l16,73,0.56
# v,2,HASH_JOIN,f12,26,0.61
# v,3,HASH_JOIN,q19,34,0.33
# v,4,HASH_JOIN,w11,91,0.64
# v,5,GROUP_BY:COMBINER,,100,1.00
# v,6,SAMPLER,,57,1.00
# v,7,ORDER_BY,,29,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,21,TPCH_Q5
# v,0,HASH_JOIN,q19,57,0.88
# v,1,HASH_JOIN,i0,86,0.93
# v,2,HASH_JOIN,c11,64,0.87
# v,3,HASH_JOIN,t17,69,0.77
# v,4,HASH_JOIN,v14,10,0.82
# v,5,GROUP_BY:COMBINER,,86,1.00
# v,6,SAMPLER,,33,1.00
# v,7,ORDER_BY,,71,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,22,TPCH_Q5
# v,0,HASH_JOIN,b4,90,0.42
# v,1,HASH_JOIN,e19,21,0.99
# v,2,HASH_JOIN,l18,72,0.79
# v,3,HASH_JOIN,b1,20,0.59
# v,4,HASH_JOIN,v14,51,0.34
# v,5,GROUP_BY:COMBINER,,26,1.00
# v,6,SAMPLER,,53,1.00
# v,7,ORDER_BY,,85,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,23,TPCH_Q5
# v,0,HASH_JOIN,c2,88,0.71
# v,1,HASH_JOIN,k12,33,0.89
# v,2,HASH_JOIN,z12,66,0.59
# v,3,HASH_JOIN,k12,38,0.93
# v,4,HASH_JOIN,f19,66,0.72
# v,5,GROUP_BY:COMBINER,,66,1.00
# v,6,SAMPLER,,53,1.00
# v,7,ORDER_BY,,68,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,24,TPCH_Q5
# v,0,HASH_JOIN,f19,33,0.69
# v,1,HASH_JOIN,u14,100,0.84
# v,2,HASH_JOIN,x14,16,0.53
# v,3,HASH_JOIN,n13,5,0.41
# v,4,HASH_JOIN,c2,16,0.65
# v,5,GROUP_BY:COMBINER,,23,1.00
# v,6,SAMPLER,,47,1.00
# v,7,ORDER_BY,,37,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,25,TPCH_Q8
# v,0,HASH_JOIN,n13,12,0.61
# v,1,REPLICATED_JOIN:HASH_JOIN,y16,22,0.32
# v,2,MULTI_QUERY:MAP_ONLY,l19,26,0.76
# v,3,REPLICATED_JOIN:MAP_ONLY,,15,1.00
# v,4,HASH_JOIN,,33,1.00
# v,5,MAP_ONLY,p18,54,0.57
# v,6,MAP_ONLY,,33,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,t17,64,0.79
# v,8,GROUP_BY:COMBINER,,86,1.00
# v,9,SAMPLER,,71,1.00
# v,10,ORDER_BY,,59,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,26,TPCH_Q14
# v,0,HASH_JOIN,j13,66,0.37
# v,1,MULTI_QUERY:COMBINER,,11,1.00
# v,2,MAP_ONLY,,33,1.00
# e,0,1
# e,1,2
# #t,27,TPCH_Q17
# v,0,COGROUP,b7,98,0.70
# v,1,GROUP_BY:COMBINER,,28,1.00
# e,0,1
# #t,28,TPCH_Q9
# v,0,MAP_ONLY,k19,62,0.99
# v,1,REPLICATED_JOIN:HASH_JOIN,k12,57,0.36
# v,2,HASH_JOIN,g17,31,0.53
# v,3,HASH_JOIN,d1,44,0.63
# v,4,HASH_JOIN,b13,13,0.56
# v,5,GROUP_BY:COMBINER,,31,1.00
# v,6,SAMPLER,,47,1.00
# v,7,ORDER_BY,,48,1.00
# e,0,1
# e,1,3
# e,2,1
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,29,TPCH_Q12
# v,0,HASH_JOIN,k13,53,0.83
# v,1,GROUP_BY,,36,1.00
# v,2,SAMPLER,,17,1.00
# v,3,ORDER_BY,,34,1.00
# e,0,1
# e,1,2
# e,2,3
# %r,3,10
# #t,30,TPCH_Q8
# v,0,HASH_JOIN,e1,86,0.57
# v,1,REPLICATED_JOIN:HASH_JOIN,w17,54,0.78
# v,2,MULTI_QUERY:MAP_ONLY,f14,100,0.35
# v,3,REPLICATED_JOIN:MAP_ONLY,,77,1.00
# v,4,HASH_JOIN,,86,1.00
# v,5,MAP_ONLY,t16,38,0.41
# v,6,MAP_ONLY,,45,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,h17,67,0.93
# v,8,GROUP_BY:COMBINER,,49,1.00
# v,9,SAMPLER,,82,1.00
# v,10,ORDER_BY,,28,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,31,TPCH_Q8
# v,0,HASH_JOIN,e8,93,0.72
# v,1,REPLICATED_JOIN:HASH_JOIN,a13,34,0.98
# v,2,MULTI_QUERY:MAP_ONLY,t17,13,0.75
# v,3,REPLICATED_JOIN:MAP_ONLY,,60,1.00
# v,4,HASH_JOIN,,21,1.00
# v,5,MAP_ONLY,p15,34,0.93
# v,6,MAP_ONLY,,56,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,o13,80,0.42
# v,8,GROUP_BY:COMBINER,,64,1.00
# v,9,SAMPLER,,58,1.00
# v,10,ORDER_BY,,9,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,32,TPCH_Q8
# v,0,HASH_JOIN,l19,85,0.44
# v,1,REPLICATED_JOIN:HASH_JOIN,g15,15,0.81
# v,2,MULTI_QUERY:MAP_ONLY,a11,98,0.65
# v,3,REPLICATED_JOIN:MAP_ONLY,,41,1.00
# v,4,HASH_JOIN,,71,1.00
# v,5,MAP_ONLY,x14,20,0.94
# v,6,MAP_ONLY,,34,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,z14,92,0.96
# v,8,GROUP_BY:COMBINER,,88,1.00
# v,9,SAMPLER,,11,1.00
# v,10,ORDER_BY,,81,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,33,TPCH_Q8
# v,0,HASH_JOIN,s12,60,0.97
# v,1,REPLICATED_JOIN:HASH_JOIN,z14,72,0.37
# v,2,MULTI_QUERY:MAP_ONLY,m18,97,0.44
# v,3,REPLICATED_JOIN:MAP_ONLY,,45,1.00
# v,4,HASH_JOIN,,32,1.00
# v,5,MAP_ONLY,u17,17,0.86
# v,6,MAP_ONLY,,9,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,g16,71,0.37
# v,8,GROUP_BY:COMBINER,,31,1.00
# v,9,SAMPLER,,6,1.00
# v,10,ORDER_BY,,48,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,34,TPCH_Q8
# v,0,HASH_JOIN,w15,23,0.82
# v,1,REPLICATED_JOIN:HASH_JOIN,l16,9,0.55
# v,2,MULTI_QUERY:MAP_ONLY,h11,27,0.71
# v,3,REPLICATED_JOIN:MAP_ONLY,,89,1.00
# v,4,HASH_JOIN,,34,1.00
# v,5,MAP_ONLY,x18,54,0.67
# v,6,MAP_ONLY,,39,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,b5,62,0.50
# v,8,GROUP_BY:COMBINER,,81,1.00
# v,9,SAMPLER,,94,1.00
# v,10,ORDER_BY,,52,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,35,TPCH_Q8
# v,0,HASH_JOIN,b17,47,0.84
# v,1,REPLICATED_JOIN:HASH_JOIN,h11,59,0.41
# v,2,MULTI_QUERY:MAP_ONLY,x16,22,0.69
# v,3,REPLICATED_JOIN:MAP_ONLY,,89,1.00
# v,4,HASH_JOIN,,67,1.00
# v,5,MAP_ONLY,f5,24,0.83
# v,6,MAP_ONLY,,6,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,z11,53,0.36
# v,8,GROUP_BY:COMBINER,,40,1.00
# v,9,SAMPLER,,62,1.00
# v,10,ORDER_BY,,86,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,36,TPCH_Q16
# v,0,HASH_JOIN,i13,44,0.45
# v,1,HASH_JOIN,e13,27,0.83
# v,2,GROUP_BY:COMBINER,,27,1.00
# v,3,SAMPLER,,31,1.00
# v,4,ORDER_BY,,55,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,37,TPCH_Q4
# v,0,COGROUP,v16,12,0.71
# v,1,GROUP_BY:COMBINER,,53,1.00
# v,2,SAMPLER,,97,1.00
# v,3,ORDER_BY,,77,1.00
# e,0,1
# e,1,2
# e,2,3
# #t,38,TPCH_Q10
# v,0,HASH_JOIN,b5,99,0.87
# v,1,HASH_JOIN,i13,63,0.90
# v,2,HASH_JOIN,a6,55,0.53
# v,3,GROUP_BY:COMBINER,,82,1.00
# v,4,SAMPLER,,76,1.00
# v,5,ORDER_BY:COMBINER,,75,1.00
# v,6,SAVE,,100,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# #t,39,TPCH_Q11
# v,0,HASH_JOIN,f19,59,0.76
# v,1,HASH_JOIN,v11,97,0.79
# v,2,GROUP_BY:COMBINER,,96,1.00
# v,3,GROUP_BY:COMBINER,,24,1.00
# v,4,SAMPLER,,88,1.00
# v,5,ORDER_BY,,65,1.00
# e,0,1
# e,1,2
# e,1,3
# e,2,3
# e,3,4
# e,4,5
# %r,4,10
# #t,40,TPCH_Q11
# v,0,HASH_JOIN,b12,16,0.50
# v,1,HASH_JOIN,q14,36,0.67
# v,2,GROUP_BY:COMBINER,,29,1.00
# v,3,GROUP_BY:COMBINER,,5,1.00
# v,4,SAMPLER,,75,1.00
# v,5,ORDER_BY,,62,1.00
# e,0,1
# e,1,2
# e,1,3
# e,2,3
# e,3,4
# e,4,5
# #t,41,TPCH_Q11
# v,0,HASH_JOIN,w19,11,0.90
# v,1,HASH_JOIN,c7,52,0.43
# v,2,GROUP_BY:COMBINER,,43,1.00
# v,3,GROUP_BY:COMBINER,,50,1.00
# v,4,SAMPLER,,51,1.00
# v,5,ORDER_BY,,67,1.00
# e,0,1
# e,1,2
# e,1,3
# e,2,3
# e,3,4
# e,4,5
# #t,42,TPCH_Q11
# v,0,HASH_JOIN,c13,36,0.66
# v,1,HASH_JOIN,f11,88,0.51
# v,2,GROUP_BY:COMBINER,,70,1.00
# v,3,GROUP_BY:COMBINER,,57,1.00
# v,4,SAMPLER,,74,1.00
# v,5,ORDER_BY,,81,1.00
# e,0,1
# e,1,2
# e,1,3
# e,2,3
# e,3,4
# e,4,5
# #t,43,TPCH_Q11
# v,0,HASH_JOIN,m16,61,0.85
# v,1,HASH_JOIN,b1,47,0.49
# v,2,GROUP_BY:COMBINER,,58,1.00
# v,3,GROUP_BY:COMBINER,,37,1.00
# v,4,SAMPLER,,99,1.00
# v,5,ORDER_BY,,96,1.00
# e,0,1
# e,1,2
# e,1,3
# e,2,3
# e,3,4
# e,4,5
# #t,44,TPCH_Q11
# v,0,HASH_JOIN,j17,62,0.35
# v,1,HASH_JOIN,p15,74,0.38
# v,2,GROUP_BY:COMBINER,,43,1.00
# v,3,GROUP_BY:COMBINER,,33,1.00
# v,4,SAMPLER,,12,1.00
# v,5,ORDER_BY,,8,1.00
# e,0,1
# e,1,2
# e,1,3
# e,2,3
# e,3,4
# e,4,5
# #t,45,TPCH_Q12
# v,0,HASH_JOIN,x18,33,0.87
# v,1,GROUP_BY,,65,1.00
# v,2,SAMPLER,,30,1.00
# v,3,ORDER_BY,,92,1.00
# e,0,1
# e,1,2
# e,2,3
# #t,46,TPCH_Q5
# v,0,HASH_JOIN,a15,61,0.35
# v,1,HASH_JOIN,f15,41,0.70
# v,2,HASH_JOIN,b2,15,0.70
# v,3,HASH_JOIN,e8,66,0.41
# v,4,HASH_JOIN,g15,58,0.70
# v,5,GROUP_BY:COMBINER,,62,1.00
# v,6,SAMPLER,,41,1.00
# v,7,ORDER_BY,,90,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,47,TPCH_Q6
# v,0,HASH_JOIN,v11,79,0.91
# #t,48,TPCH_Q8
# v,0,HASH_JOIN,d2,74,0.91
# v,1,REPLICATED_JOIN:HASH_JOIN,y13,39,0.97
# v,2,MULTI_QUERY:MAP_ONLY,m13,82,0.72
# v,3,REPLICATED_JOIN:MAP_ONLY,,40,1.00
# v,4,HASH_JOIN,,63,1.00
# v,5,MAP_ONLY,a16,94,0.48
# v,6,MAP_ONLY,,10,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,a11,42,0.55
# v,8,GROUP_BY:COMBINER,,30,1.00
# v,9,SAMPLER,,93,1.00
# v,10,ORDER_BY,,33,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,49,TPCH_Q7
# v,0,MAP_ONLY,a18,50,0.81
# v,1,REPLICATED_JOIN:HASH_JOIN,b7,76,0.74
# v,2,HASH_JOIN,,33,1.00
# v,3,MAP_ONLY,d6,75,0.88
# v,4,REPLICATED_JOIN:HASH_JOIN,e14,94,0.51
# v,5,GROUP_BY:COMBINER,,68,1.00
# v,6,SAMPLER,,41,1.00
# v,7,ORDER_BY,,51,1.00
# e,0,1
# e,1,2
# e,2,5
# e,3,4
# e,4,2
# e,5,6
# e,6,7
# %r,5,10
# #t,50,TPCH_Q7
# v,0,MAP_ONLY,b5,20,0.38
# v,1,REPLICATED_JOIN:HASH_JOIN,h12,50,0.46
# v,2,HASH_JOIN,,40,1.00
# v,3,MAP_ONLY,x11,89,0.36
# v,4,REPLICATED_JOIN:HASH_JOIN,n15,47,0.97
# v,5,GROUP_BY:COMBINER,,20,1.00
# v,6,SAMPLER,,100,1.00
# v,7,ORDER_BY,,97,1.00
# e,0,1
# e,1,2
# e,2,5
# e,3,4
# e,4,2
# e,5,6
# e,6,7
# #t,51,TPCH_Q7
# v,0,MAP_ONLY,b17,40,0.49
# v,1,REPLICATED_JOIN:HASH_JOIN,e16,22,0.60
# v,2,HASH_JOIN,,55,1.00
# v,3,MAP_ONLY,g0,29,0.81
# v,4,REPLICATED_JOIN:HASH_JOIN,c17,69,0.41
# v,5,GROUP_BY:COMBINER,,37,1.00
# v,6,SAMPLER,,18,1.00
# v,7,ORDER_BY,,74,1.00
# e,0,1
# e,1,2
# e,2,5
# e,3,4
# e,4,2
# e,5,6
# e,6,7
# #t,52,TPCH_Q7
# v,0,MAP_ONLY,v11,61,0.91
# v,1,REPLICATED_JOIN:HASH_JOIN,b8,82,0.85
# v,2,HASH_JOIN,,41,1.00
# v,3,MAP_ONLY,e0,51,0.91
# v,4,REPLICATED_JOIN:HASH_JOIN,x13,59,0.51
# v,5,GROUP_BY:COMBINER,,39,1.00
# v,6,SAMPLER,,58,1.00
# v,7,ORDER_BY,,60,1.00
# e,0,1
# e,1,2
# e,2,5
# e,3,4
# e,4,2
# e,5,6
# e,6,7
# #t,53,TPCH_Q7
# v,0,MAP_ONLY,b17,55,0.99
# v,1,REPLICATED_JOIN:HASH_JOIN,e17,7,0.42
# v,2,HASH_JOIN,,77,1.00
# v,3,MAP_ONLY,e8,57,0.87
# v,4,REPLICATED_JOIN:HASH_JOIN,f11,98,0.97
# v,5,GROUP_BY:COMBINER,,33,1.00
# v,6,SAMPLER,,57,1.00
# v,7,ORDER_BY,,29,1.00
# e,0,1
# e,1,2
# e,2,5
# e,3,4
# e,4,2
# e,5,6
# e,6,7
# #t,54,TPCH_Q7
# v,0,MAP_ONLY,a18,14,0.71
# v,1,REPLICATED_JOIN:HASH_JOIN,g0,41,0.40
# v,2,HASH_JOIN,,52,1.00
# v,3,MAP_ONLY,n11,80,0.43
# v,4,REPLICATED_JOIN:HASH_JOIN,h15,54,0.36
# v,5,GROUP_BY:COMBINER,,96,1.00
# v,6,SAMPLER,,82,1.00
# v,7,ORDER_BY,,58,1.00
# e,0,1
# e,1,2
# e,2,5
# e,3,4
# e,4,2
# e,5,6
# e,6,7
# #t,55,TPCH_Q8
# v,0,HASH_JOIN,r14,44,0.73
# v,1,REPLICATED_JOIN:HASH_JOIN,s13,67,0.44
# v,2,MULTI_QUERY:MAP_ONLY,r11,76,0.96
# v,3,REPLICATED_JOIN:MAP_ONLY,,52,1.00
# v,4,HASH_JOIN,,9,1.00
# v,5,MAP_ONLY,p15,16,0.42
# v,6,MAP_ONLY,,20,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,b9,99,0.91
# v,8,GROUP_BY:COMBINER,,32,1.00
# v,9,SAMPLER,,18,1.00
# v,10,ORDER_BY,,52,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,56,TPCH_Q21
# v,0,GROUP_BY:MULTI_QUERY,z19,57,0.69
# v,1,REPLICATED_JOIN:HASH_JOIN,m11,9,0.43
# v,2,MAP_ONLY,j13,71,0.68
# v,3,HASH_JOIN,a16,62,0.59
# v,4,GROUP_BY:COMBINER,,30,1.00
# v,5,SAMPLER,,22,1.00
# v,6,ORDER_BY:COMBINER,,45,1.00
# v,7,SAVE,,80,1.00
# e,0,1
# e,1,3
# e,2,1
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,57,TPCH_Q6
# v,0,HASH_JOIN,b0,80,0.47
# #t,58,TPCH_Q16
# v,0,HASH_JOIN,q17,73,0.80
# v,1,HASH_JOIN,u12,55,0.91
# v,2,GROUP_BY:COMBINER,,94,1.00
# v,3,SAMPLER,,12,1.00
# v,4,ORDER_BY,,70,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,59,TPCH_Q5
# v,0,HASH_JOIN,a15,49,0.54
# v,1,HASH_JOIN,n18,18,0.68
# v,2,HASH_JOIN,a11,52,0.79
# v,3,HASH_JOIN,c6,5,0.53
# v,4,HASH_JOIN,d2,32,0.86
# v,5,GROUP_BY:COMBINER,,28,1.00
# v,6,SAMPLER,,41,1.00
# v,7,ORDER_BY,,18,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# %r,6,10
# #t,60,TPCH_Q5
# v,0,HASH_JOIN,r17,89,0.77
# v,1,HASH_JOIN,y12,24,0.99
# v,2,HASH_JOIN,q14,83,0.99
# v,3,HASH_JOIN,i12,55,0.95
# v,4,HASH_JOIN,f14,71,0.90
# v,5,GROUP_BY:COMBINER,,74,1.00
# v,6,SAMPLER,,53,1.00
# v,7,ORDER_BY,,44,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,61,TPCH_Q5
# v,0,HASH_JOIN,p14,46,0.81
# v,1,HASH_JOIN,g17,96,0.42
# v,2,HASH_JOIN,c13,93,0.94
# v,3,HASH_JOIN,k12,7,0.99
# v,4,HASH_JOIN,e18,38,0.35
# v,5,GROUP_BY:COMBINER,,46,1.00
# v,6,SAMPLER,,5,1.00
# v,7,ORDER_BY,,17,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,62,TPCH_Q5
# v,0,HASH_JOIN,k16,67,0.72
# v,1,HASH_JOIN,g16,96,0.55
# v,2,HASH_JOIN,y14,25,0.71
# v,3,HASH_JOIN,g11,18,0.93
# v,4,HASH_JOIN,g13,85,0.85
# v,5,GROUP_BY:COMBINER,,46,1.00
# v,6,SAMPLER,,48,1.00
# v,7,ORDER_BY,,73,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,63,TPCH_Q5
# v,0,HASH_JOIN,k14,81,0.73
# v,1,HASH_JOIN,t12,23,0.84
# v,2,HASH_JOIN,c7,66,0.56
# v,3,HASH_JOIN,p11,14,0.67
# v,4,HASH_JOIN,o19,55,0.74
# v,5,GROUP_BY:COMBINER,,78,1.00
# v,6,SAMPLER,,15,1.00
# v,7,ORDER_BY,,69,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,64,TPCH_Q5
# v,0,HASH_JOIN,l14,77,0.99
# v,1,HASH_JOIN,h0,82,0.57
# v,2,HASH_JOIN,e0,61,0.82
# v,3,HASH_JOIN,g1,78,0.74
# v,4,HASH_JOIN,k12,62,0.99
# v,5,GROUP_BY:COMBINER,,29,1.00
# v,6,SAMPLER,,61,1.00
# v,7,ORDER_BY,,37,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,65,TPCH_Q9
# v,0,MAP_ONLY,l19,31,0.83
# v,1,REPLICATED_JOIN:HASH_JOIN,a18,46,0.32
# v,2,HASH_JOIN,p14,95,0.89
# v,3,HASH_JOIN,e17,44,0.57
# v,4,HASH_JOIN,d3,86,0.45
# v,5,GROUP_BY:COMBINER,,33,1.00
# v,6,SAMPLER,,24,1.00
# v,7,ORDER_BY,,61,1.00
# e,0,1
# e,1,3
# e,2,1
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,66,TPCH_Q2
# v,0,HASH_JOIN,t12,78,0.32
# v,1,HASH_JOIN,o12,67,0.73
# v,2,HASH_JOIN,z14,82,0.37
# v,3,HASH_JOIN,c19,47,0.98
# v,4,GROUP_BY,,53,1.00
# v,5,SAMPLER,,92,1.00
# v,6,ORDER_BY:COMBINER,,16,1.00
# v,7,SAVE,,37,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# e,6,7
# #t,67,TPCH_Q22
# v,0,MULTI_QUERY:COMBINER,a1,91,0.96
# v,1,HASH_JOIN,h19,39,0.53
# v,2,GROUP_BY:COMBINER,,39,1.00
# v,3,SAMPLER,,14,1.00
# v,4,ORDER_BY,,64,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# #t,68,TPCH_Q17
# v,0,COGROUP,j13,47,0.94
# v,1,GROUP_BY:COMBINER,,25,1.00
# e,0,1
# #t,69,TPCH_Q20
# v,0,GROUP_BY:COMBINER,d8,59,0.86
# v,1,HASH_JOIN,,55,1.00
# v,2,DISTINCT,x11,20,0.44
# v,3,HASH_JOIN,f16,13,0.57
# v,4,DISTINCT,,56,1.00
# v,5,HASH_JOIN,,87,1.00
# v,6,HASH_JOIN,f9,64,0.89
# v,7,SAMPLER,,21,1.00
# v,8,ORDER_BY,,46,1.00
# e,0,1
# e,1,4
# e,2,3
# e,3,1
# e,4,5
# e,5,7
# e,6,5
# e,7,8
# %r,7,10
# #t,70,TPCH_Q20
# v,0,GROUP_BY:COMBINER,b0,51,0.82
# v,1,HASH_JOIN,,67,1.00
# v,2,DISTINCT,n11,67,0.78
# v,3,HASH_JOIN,n12,10,0.59
# v,4,DISTINCT,,35,1.00
# v,5,HASH_JOIN,,66,1.00
# v,6,HASH_JOIN,a15,78,0.31
# v,7,SAMPLER,,62,1.00
# v,8,ORDER_BY,,100,1.00
# e,0,1
# e,1,4
# e,2,3
# e,3,1
# e,4,5
# e,5,7
# e,6,5
# e,7,8
# #t,71,TPCH_Q20
# v,0,GROUP_BY:COMBINER,x17,73,0.63
# v,1,HASH_JOIN,,50,1.00
# v,2,DISTINCT,e9,61,0.77
# v,3,HASH_JOIN,c15,11,0.95
# v,4,DISTINCT,,76,1.00
# v,5,HASH_JOIN,,21,1.00
# v,6,HASH_JOIN,l18,87,0.35
# v,7,SAMPLER,,91,1.00
# v,8,ORDER_BY,,30,1.00
# e,0,1
# e,1,4
# e,2,3
# e,3,1
# e,4,5
# e,5,7
# e,6,5
# e,7,8
# #t,72,TPCH_Q20
# v,0,GROUP_BY:COMBINER,o12,53,0.79
# v,1,HASH_JOIN,,79,1.00
# v,2,DISTINCT,o12,93,0.47
# v,3,HASH_JOIN,l18,48,0.96
# v,4,DISTINCT,,88,1.00
# v,5,HASH_JOIN,,8,1.00
# v,6,HASH_JOIN,m13,67,0.95
# v,7,SAMPLER,,26,1.00
# v,8,ORDER_BY,,80,1.00
# e,0,1
# e,1,4
# e,2,3
# e,3,1
# e,4,5
# e,5,7
# e,6,5
# e,7,8
# #t,73,TPCH_Q20
# v,0,GROUP_BY:COMBINER,t18,50,0.85
# v,1,HASH_JOIN,,46,1.00
# v,2,DISTINCT,d3,31,0.79
# v,3,HASH_JOIN,d6,92,0.53
# v,4,DISTINCT,,27,1.00
# v,5,HASH_JOIN,,42,1.00
# v,6,HASH_JOIN,e18,71,0.57
# v,7,SAMPLER,,56,1.00
# v,8,ORDER_BY,,76,1.00
# e,0,1
# e,1,4
# e,2,3
# e,3,1
# e,4,5
# e,5,7
# e,6,5
# e,7,8
# #t,74,TPCH_Q20
# v,0,GROUP_BY:COMBINER,r19,14,0.60
# v,1,HASH_JOIN,,7,1.00
# v,2,DISTINCT,i13,60,0.88
# v,3,HASH_JOIN,e15,89,0.90
# v,4,DISTINCT,,16,1.00
# v,5,HASH_JOIN,,44,1.00
# v,6,HASH_JOIN,f15,9,0.52
# v,7,SAMPLER,,29,1.00
# v,8,ORDER_BY,,25,1.00
# e,0,1
# e,1,4
# e,2,3
# e,3,1
# e,4,5
# e,5,7
# e,6,5
# e,7,8
# #t,75,TPCH_Q7
# v,0,MAP_ONLY,d7,70,0.34
# v,1,REPLICATED_JOIN:HASH_JOIN,p15,70,0.97
# v,2,HASH_JOIN,,57,1.00
# v,3,MAP_ONLY,j13,88,0.63
# v,4,REPLICATED_JOIN:HASH_JOIN,c4,91,0.48
# v,5,GROUP_BY:COMBINER,,32,1.00
# v,6,SAMPLER,,25,1.00
# v,7,ORDER_BY,,19,1.00
# e,0,1
# e,1,2
# e,2,5
# e,3,4
# e,4,2
# e,5,6
# e,6,7
# #t,76,TPCH_Q11
# v,0,HASH_JOIN,f12,53,0.84
# v,1,HASH_JOIN,w15,71,0.44
# v,2,GROUP_BY:COMBINER,,10,1.00
# v,3,GROUP_BY:COMBINER,,25,1.00
# v,4,SAMPLER,,87,1.00
# v,5,ORDER_BY,,78,1.00
# e,0,1
# e,1,2
# e,1,3
# e,2,3
# e,3,4
# e,4,5
# #t,77,TPCH_Q12
# v,0,HASH_JOIN,m17,41,0.34
# v,1,GROUP_BY,,33,1.00
# v,2,SAMPLER,,17,1.00
# v,3,ORDER_BY,,50,1.00
# e,0,1
# e,1,2
# e,2,3
# #t,78,TPCH_Q10
# v,0,HASH_JOIN,r19,67,0.30
# v,1,HASH_JOIN,f16,49,0.86
# v,2,HASH_JOIN,y13,34,0.61
# v,3,GROUP_BY:COMBINER,,16,1.00
# v,4,SAMPLER,,99,1.00
# v,5,ORDER_BY:COMBINER,,22,1.00
# v,6,SAVE,,48,1.00
# e,0,1
# e,1,2
# e,2,3
# e,3,4
# e,4,5
# e,5,6
# #t,79,TPCH_Q14
# v,0,HASH_JOIN,j18,83,0.94
# v,1,MULTI_QUERY:COMBINER,,54,1.00
# v,2,MAP_ONLY,,13,1.00
# e,0,1
# e,1,2
# %r,8,10
# #t,80,TPCH_Q13
# v,0,COGROUP,w12,10,0.48
# v,1,GROUP_BY:COMBINER,,40,1.00
# v,2,SAMPLER,,98,1.00
# v,3,ORDER_BY,,6,1.00
# e,0,1
# e,1,2
# e,2,3
# #t,81,TPCH_Q17
# v,0,COGROUP,r14,5,0.66
# v,1,GROUP_BY:COMBINER,,12,1.00
# e,0,1
# #t,82,TPCH_Q13
# v,0,COGROUP,l13,76,0.44
# v,1,GROUP_BY:COMBINER,,12,1.00
# v,2,SAMPLER,,70,1.00
# v,3,ORDER_BY,,34,1.00
# e,0,1
# e,1,2
# e,2,3
# #t,83,TPCH_Q12
# v,0,HASH_JOIN,j14,100,0.38
# v,1,GROUP_BY,,10,1.00
# v,2,SAMPLER,,67,1.00
# v,3,ORDER_BY,,23,1.00
# e,0,1
# e,1,2
# e,2,3
# #t,84,TPCH_Q8
# v,0,HASH_JOIN,h17,90,0.92
# v,1,REPLICATED_JOIN:HASH_JOIN,p12,55,0.93
# v,2,MULTI_QUERY:MAP_ONLY,y13,40,0.98
# v,3,REPLICATED_JOIN:MAP_ONLY,,85,1.00
# v,4,HASH_JOIN,,90,1.00
# v,5,MAP_ONLY,g13,78,0.64
# v,6,MAP_ONLY,,94,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,b17,61,0.76
# v,8,GROUP_BY:COMBINER,,49,1.00
# v,9,SAMPLER,,32,1.00
# v,10,ORDER_BY,,16,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,85,TPCH_Q8
# v,0,HASH_JOIN,b1,36,0.51
# v,1,REPLICATED_JOIN:HASH_JOIN,a7,20,0.60
# v,2,MULTI_QUERY:MAP_ONLY,o12,71,0.33
# v,3,REPLICATED_JOIN:MAP_ONLY,,67,1.00
# v,4,HASH_JOIN,,48,1.00
# v,5,MAP_ONLY,i13,95,0.37
# v,6,MAP_ONLY,,23,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,f8,43,0.31
# v,8,GROUP_BY:COMBINER,,39,1.00
# v,9,SAMPLER,,94,1.00
# v,10,ORDER_BY,,37,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,86,TPCH_Q8
# v,0,HASH_JOIN,d6,56,0.34
# v,1,REPLICATED_JOIN:HASH_JOIN,c11,58,0.84
# v,2,MULTI_QUERY:MAP_ONLY,r11,48,0.93
# v,3,REPLICATED_JOIN:MAP_ONLY,,44,1.00
# v,4,HASH_JOIN,,34,1.00
# v,5,MAP_ONLY,z12,87,0.38
# v,6,MAP_ONLY,,35,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,c16,74,0.93
# v,8,GROUP_BY:COMBINER,,38,1.00
# v,9,SAMPLER,,68,1.00
# v,10,ORDER_BY,,57,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,87,TPCH_Q8
# v,0,HASH_JOIN,w18,76,0.32
# v,1,REPLICATED_JOIN:HASH_JOIN,h11,68,0.82
# v,2,MULTI_QUERY:MAP_ONLY,c11,71,0.87
# v,3,REPLICATED_JOIN:MAP_ONLY,,99,1.00
# v,4,HASH_JOIN,,52,1.00
# v,5,MAP_ONLY,r14,90,0.91
# v,6,MAP_ONLY,,25,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,a7,29,0.84
# v,8,GROUP_BY:COMBINER,,44,1.00
# v,9,SAMPLER,,7,1.00
# v,10,ORDER_BY,,56,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,88,TPCH_Q8
# v,0,HASH_JOIN,g1,11,0.70
# v,1,REPLICATED_JOIN:HASH_JOIN,o15,57,0.41
# v,2,MULTI_QUERY:MAP_ONLY,t18,29,0.97
# v,3,REPLICATED_JOIN:MAP_ONLY,,63,1.00
# v,4,HASH_JOIN,,90,1.00
# v,5,MAP_ONLY,l13,51,0.33
# v,6,MAP_ONLY,,12,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,y11,72,0.51
# v,8,GROUP_BY:COMBINER,,36,1.00
# v,9,SAMPLER,,24,1.00
# v,10,ORDER_BY,,88,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,89,TPCH_Q8
# v,0,HASH_JOIN,g16,51,0.34
# v,1,REPLICATED_JOIN:HASH_JOIN,v15,55,0.58
# v,2,MULTI_QUERY:MAP_ONLY,m17,12,0.96
# v,3,REPLICATED_JOIN:MAP_ONLY,,52,1.00
# v,4,HASH_JOIN,,54,1.00
# v,5,MAP_ONLY,p15,39,0.91
# v,6,MAP_ONLY,,52,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,a19,94,0.51
# v,8,GROUP_BY:COMBINER,,8,1.00
# v,9,SAMPLER,,63,1.00
# v,10,ORDER_BY,,6,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# %r,9,10
# #t,90,TPCH_Q8
# v,0,HASH_JOIN,v16,81,0.87
# v,1,REPLICATED_JOIN:HASH_JOIN,c11,6,0.63
# v,2,MULTI_QUERY:MAP_ONLY,j16,11,0.67
# v,3,REPLICATED_JOIN:MAP_ONLY,,90,1.00
# v,4,HASH_JOIN,,96,1.00
# v,5,MAP_ONLY,v18,57,0.76
# v,6,MAP_ONLY,,47,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,d1,7,0.39
# v,8,GROUP_BY:COMBINER,,72,1.00
# v,9,SAMPLER,,50,1.00
# v,10,ORDER_BY,,17,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,91,TPCH_Q8
# v,0,HASH_JOIN,d9,32,0.51
# v,1,REPLICATED_JOIN:HASH_JOIN,j13,78,0.77
# v,2,MULTI_QUERY:MAP_ONLY,c15,50,0.78
# v,3,REPLICATED_JOIN:MAP_ONLY,,63,1.00
# v,4,HASH_JOIN,,77,1.00
# v,5,MAP_ONLY,y11,39,0.82
# v,6,MAP_ONLY,,44,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,d6,80,0.55
# v,8,GROUP_BY:COMBINER,,45,1.00
# v,9,SAMPLER,,41,1.00
# v,10,ORDER_BY,,74,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,92,TPCH_Q8
# v,0,HASH_JOIN,u19,96,0.60
# v,1,REPLICATED_JOIN:HASH_JOIN,a12,45,0.61
# v,2,MULTI_QUERY:MAP_ONLY,c11,48,0.72
# v,3,REPLICATED_JOIN:MAP_ONLY,,85,1.00
# v,4,HASH_JOIN,,78,1.00
# v,5,MAP_ONLY,f19,39,0.53
# v,6,MAP_ONLY,,51,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,x17,28,0.34
# v,8,GROUP_BY:COMBINER,,54,1.00
# v,9,SAMPLER,,41,1.00
# v,10,ORDER_BY,,85,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,93,TPCH_Q8
# v,0,HASH_JOIN,k11,42,0.54
# v,1,REPLICATED_JOIN:HASH_JOIN,b9,13,0.96
# v,2,MULTI_QUERY:MAP_ONLY,k16,77,0.67
# v,3,REPLICATED_JOIN:MAP_ONLY,,73,1.00
# v,4,HASH_JOIN,,72,1.00
# v,5,MAP_ONLY,j18,77,0.70
# v,6,MAP_ONLY,,47,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,t13,7,0.72
# v,8,GROUP_BY:COMBINER,,74,1.00
# v,9,SAMPLER,,89,1.00
# v,10,ORDER_BY,,95,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,94,TPCH_Q8
# v,0,HASH_JOIN,n18,40,0.36
# v,1,REPLICATED_JOIN:HASH_JOIN,c1,75,0.73
# v,2,MULTI_QUERY:MAP_ONLY,y12,30,0.80
# v,3,REPLICATED_JOIN:MAP_ONLY,,74,1.00
# v,4,HASH_JOIN,,83,1.00
# v,5,MAP_ONLY,d1,11,0.47
# v,6,MAP_ONLY,,11,1.00
# v,7,REPLICATED_JOIN:HASH_JOIN,m18,58,0.39
# v,8,GROUP_BY:COMBINER,,19,1.00
# v,9,SAMPLER,,59,1.00
# v,10,ORDER_BY,,36,1.00
# e,0,1
# e,1,4
# e,2,1
# e,2,3
# e,3,6
# e,4,8
# e,5,3
# e,6,7
# e,7,4
# e,8,9
# e,9,10
# #t,95,TPCH_Q19
# v,0,HASH_JOIN,m12,11,0.67
# v,1,GROUP_BY:COMBINER,,69,1.00
# e,0,1
# #t,96,TPCH_Q12
# v,0,HASH_JOIN,g17,63,0.61
# v,1,GROUP_BY,,8,1.00
# v,2,SAMPLER,,89,1.00
# v,3,ORDER_BY,,11,1.00
# e,0,1
# e,1,2
# e,2,3
# #t,97,TPCH_Q6
# v,0,HASH_JOIN,u16,15,0.63
# #t,98,TPCH_Q20
# v,0,GROUP_BY:COMBINER,e13,37,0.39
# v,1,HASH_JOIN,,81,1.00
# v,2,DISTINCT,a11,7,0.67
# v,3,HASH_JOIN,n12,45,0.82
# v,4,DISTINCT,,18,1.00
# v,5,HASH_JOIN,,85,1.00
# v,6,HASH_JOIN,a14,34,0.98
# v,7,SAMPLER,,91,1.00
# v,8,ORDER_BY,,48,1.00
# e,0,1
# e,1,4
# e,2,3
# e,3,1
# e,4,5
# e,5,7
# e,6,5
# e,7,8
# #t,99,TPCH_Q1
# v,0,GROUP_BY:COMBINER,j18,27,0.81
# v,1,SAMPLER,,77,1.00
# v,2,ORDER_BY,,100,1.00
# e,0,1
# e,1,2

# %%
# prepare inputs
import string
import random

input_min = 1
input_max = 256

index_min = 11
index_max = 20

fpath = '/local0/Kariz/expriments/simulator/multidag/config/inputs.csv'

input_str=''
for c in string.ascii_lowercase:
    for i in range(index_min, index_max):
        input_str += '%s%d,%d\n'%(c, i, random.randint(input_min, input_max))

with open(fpath, 'a') as fd:
    fd.write(input_str)

inputs= []
for i in range(0, n_iterations):
    alphabets = list(string.ascii_lowercase)
    inputs.append(random.sample(alphabets, k=5))

# %%
metadatas={'lineitem': {}, 'part': {}, 
           'nation': {}, 'supplier': {}, 'partsupp': {}, 
           'orders': {}, 'customers': {} , 'region': {}}
inputs=['lineitem', 'part', 'nation', 'supplier', 'partsupp', 'orders', 'customers', 'region']

input_str=''
for it in range(0, n_iterations):
    for al in inputs:
        size = random.randint(10, 256)
        for i in range(0, max_dag_concurrency):
            metadatas[al]['%d_%d'%(it,i)] = size
            input_str += '%s_%d_%d,%d\n'%(al, it, i, size)

fpath = '/local0/Kariz/expriments/simulator/multidag/config/inputs.csv'
with open(fpath, 'a') as fd:
    fd.write(input_str)
print(input_str)
# Out:
# lineitem_0_0,243
# lineitem_0_1,243
# lineitem_0_2,243
# lineitem_0_3,243
# lineitem_0_4,243
# lineitem_0_5,243
# lineitem_0_6,243
# lineitem_0_7,243
# lineitem_0_8,243
# lineitem_0_9,243
# part_0_0,244
# part_0_1,244
# part_0_2,244
# part_0_3,244
# part_0_4,244
# part_0_5,244
# part_0_6,244
# part_0_7,244
# part_0_8,244
# part_0_9,244
# nation_0_0,206
# nation_0_1,206
# nation_0_2,206
# nation_0_3,206
# nation_0_4,206
# nation_0_5,206
# nation_0_6,206
# nation_0_7,206
# nation_0_8,206
# nation_0_9,206
# supplier_0_0,236
# supplier_0_1,236
# supplier_0_2,236
# supplier_0_3,236
# supplier_0_4,236
# supplier_0_5,236
# supplier_0_6,236
# supplier_0_7,236
# supplier_0_8,236
# supplier_0_9,236
# partsupp_0_0,85
# partsupp_0_1,85
# partsupp_0_2,85
# partsupp_0_3,85
# partsupp_0_4,85
# partsupp_0_5,85
# partsupp_0_6,85
# partsupp_0_7,85
# partsupp_0_8,85
# partsupp_0_9,85
# orders_0_0,25
# orders_0_1,25
# orders_0_2,25
# orders_0_3,25
# orders_0_4,25
# orders_0_5,25
# orders_0_6,25
# orders_0_7,25
# orders_0_8,25
# orders_0_9,25
# customers_0_0,209
# customers_0_1,209
# customers_0_2,209
# customers_0_3,209
# customers_0_4,209
# customers_0_5,209
# customers_0_6,209
# customers_0_7,209
# customers_0_8,209
# customers_0_9,209
# region_0_0,234
# region_0_1,234
# region_0_2,234
# region_0_3,234
# region_0_4,234
# region_0_5,234
# region_0_6,234
# region_0_7,234
# region_0_8,234
# region_0_9,234
# lineitem_1_0,111
# lineitem_1_1,111
# lineitem_1_2,111
# lineitem_1_3,111
# lineitem_1_4,111
# lineitem_1_5,111
# lineitem_1_6,111
# lineitem_1_7,111
# lineitem_1_8,111
# lineitem_1_9,111
# part_1_0,200
# part_1_1,200
# part_1_2,200
# part_1_3,200
# part_1_4,200
# part_1_5,200
# part_1_6,200
# part_1_7,200
# part_1_8,200
# part_1_9,200
# nation_1_0,166
# nation_1_1,166
# nation_1_2,166
# nation_1_3,166
# nation_1_4,166
# nation_1_5,166
# nation_1_6,166
# nation_1_7,166
# nation_1_8,166
# nation_1_9,166
# supplier_1_0,176
# supplier_1_1,176
# supplier_1_2,176
# supplier_1_3,176
# supplier_1_4,176
# supplier_1_5,176
# supplier_1_6,176
# supplier_1_7,176
# supplier_1_8,176
# supplier_1_9,176
# partsupp_1_0,221
# partsupp_1_1,221
# partsupp_1_2,221
# partsupp_1_3,221
# partsupp_1_4,221
# partsupp_1_5,221
# partsupp_1_6,221
# partsupp_1_7,221
# partsupp_1_8,221
# partsupp_1_9,221
# orders_1_0,188
# orders_1_1,188
# orders_1_2,188
# orders_1_3,188
# orders_1_4,188
# orders_1_5,188
# orders_1_6,188
# orders_1_7,188
# orders_1_8,188
# orders_1_9,188
# customers_1_0,148
# customers_1_1,148
# customers_1_2,148
# customers_1_3,148
# customers_1_4,148
# customers_1_5,148
# customers_1_6,148
# customers_1_7,148
# customers_1_8,148
# customers_1_9,148
# region_1_0,133
# region_1_1,133
# region_1_2,133
# region_1_3,133
# region_1_4,133
# region_1_5,133
# region_1_6,133
# region_1_7,133
# region_1_8,133
# region_1_9,133
# lineitem_2_0,30
# lineitem_2_1,30
# lineitem_2_2,30
# lineitem_2_3,30
# lineitem_2_4,30
# lineitem_2_5,30
# lineitem_2_6,30
# lineitem_2_7,30
# lineitem_2_8,30
# lineitem_2_9,30
# part_2_0,218
# part_2_1,218
# part_2_2,218
# part_2_3,218
# part_2_4,218
# part_2_5,218
# part_2_6,218
# part_2_7,218
# part_2_8,218
# part_2_9,218
# nation_2_0,189
# nation_2_1,189
# nation_2_2,189
# nation_2_3,189
# nation_2_4,189
# nation_2_5,189
# nation_2_6,189
# nation_2_7,189
# nation_2_8,189
# nation_2_9,189
# supplier_2_0,22
# supplier_2_1,22
# supplier_2_2,22
# supplier_2_3,22
# supplier_2_4,22
# supplier_2_5,22
# supplier_2_6,22
# supplier_2_7,22
# supplier_2_8,22
# supplier_2_9,22
# partsupp_2_0,227
# partsupp_2_1,227
# partsupp_2_2,227
# partsupp_2_3,227
# partsupp_2_4,227
# partsupp_2_5,227
# partsupp_2_6,227
# partsupp_2_7,227
# partsupp_2_8,227
# partsupp_2_9,227
# orders_2_0,69
# orders_2_1,69
# orders_2_2,69
# orders_2_3,69
# orders_2_4,69
# orders_2_5,69
# orders_2_6,69
# orders_2_7,69
# orders_2_8,69
# orders_2_9,69
# customers_2_0,124
# customers_2_1,124
# customers_2_2,124
# customers_2_3,124
# customers_2_4,124
# customers_2_5,124
# customers_2_6,124
# customers_2_7,124
# customers_2_8,124
# customers_2_9,124
# region_2_0,103
# region_2_1,103
# region_2_2,103
# region_2_3,103
# region_2_4,103
# region_2_5,103
# region_2_6,103
# region_2_7,103
# region_2_8,103
# region_2_9,103
# lineitem_3_0,69
# lineitem_3_1,69
# lineitem_3_2,69
# lineitem_3_3,69
# lineitem_3_4,69
# lineitem_3_5,69
# lineitem_3_6,69
# lineitem_3_7,69
# lineitem_3_8,69
# lineitem_3_9,69
# part_3_0,228
# part_3_1,228
# part_3_2,228
# part_3_3,228
# part_3_4,228
# part_3_5,228
# part_3_6,228
# part_3_7,228
# part_3_8,228
# part_3_9,228
# nation_3_0,45
# nation_3_1,45
# nation_3_2,45
# nation_3_3,45
# nation_3_4,45
# nation_3_5,45
# nation_3_6,45
# nation_3_7,45
# nation_3_8,45
# nation_3_9,45
# supplier_3_0,160
# supplier_3_1,160
# supplier_3_2,160
# supplier_3_3,160
# supplier_3_4,160
# supplier_3_5,160
# supplier_3_6,160
# supplier_3_7,160
# supplier_3_8,160
# supplier_3_9,160
# partsupp_3_0,10
# partsupp_3_1,10
# partsupp_3_2,10
# partsupp_3_3,10
# partsupp_3_4,10
# partsupp_3_5,10
# partsupp_3_6,10
# partsupp_3_7,10
# partsupp_3_8,10
# partsupp_3_9,10
# orders_3_0,205
# orders_3_1,205
# orders_3_2,205
# orders_3_3,205
# orders_3_4,205
# orders_3_5,205
# orders_3_6,205
# orders_3_7,205
# orders_3_8,205
# orders_3_9,205
# customers_3_0,87
# customers_3_1,87
# customers_3_2,87
# customers_3_3,87
# customers_3_4,87
# customers_3_5,87
# customers_3_6,87
# customers_3_7,87
# customers_3_8,87
# customers_3_9,87
# region_3_0,140
# region_3_1,140
# region_3_2,140
# region_3_3,140
# region_3_4,140
# region_3_5,140
# region_3_6,140
# region_3_7,140
# region_3_8,140
# region_3_9,140
# lineitem_4_0,170
# lineitem_4_1,170
# lineitem_4_2,170
# lineitem_4_3,170
# lineitem_4_4,170
# lineitem_4_5,170
# lineitem_4_6,170
# lineitem_4_7,170
# lineitem_4_8,170
# lineitem_4_9,170
# part_4_0,168
# part_4_1,168
# part_4_2,168
# part_4_3,168
# part_4_4,168
# part_4_5,168
# part_4_6,168
# part_4_7,168
# part_4_8,168
# part_4_9,168
# nation_4_0,60
# nation_4_1,60
# nation_4_2,60
# nation_4_3,60
# nation_4_4,60
# nation_4_5,60
# nation_4_6,60
# nation_4_7,60
# nation_4_8,60
# nation_4_9,60
# supplier_4_0,192
# supplier_4_1,192
# supplier_4_2,192
# supplier_4_3,192
# supplier_4_4,192
# supplier_4_5,192
# supplier_4_6,192
# supplier_4_7,192
# supplier_4_8,192
# supplier_4_9,192
# partsupp_4_0,151
# partsupp_4_1,151
# partsupp_4_2,151
# partsupp_4_3,151
# partsupp_4_4,151
# partsupp_4_5,151
# partsupp_4_6,151
# partsupp_4_7,151
# partsupp_4_8,151
# partsupp_4_9,151
# orders_4_0,247
# orders_4_1,247
# orders_4_2,247
# orders_4_3,247
# orders_4_4,247
# orders_4_5,247
# orders_4_6,247
# orders_4_7,247
# orders_4_8,247
# orders_4_9,247
# customers_4_0,157
# customers_4_1,157
# customers_4_2,157
# customers_4_3,157
# customers_4_4,157
# customers_4_5,157
# customers_4_6,157
# customers_4_7,157
# customers_4_8,157
# customers_4_9,157
# region_4_0,155
# region_4_1,155
# region_4_2,155
# region_4_3,155
# region_4_4,155
# region_4_5,155
# region_4_6,155
# region_4_7,155
# region_4_8,155
# region_4_9,155
# lineitem_5_0,22
# lineitem_5_1,22
# lineitem_5_2,22
# lineitem_5_3,22
# lineitem_5_4,22
# lineitem_5_5,22
# lineitem_5_6,22
# lineitem_5_7,22
# lineitem_5_8,22
# lineitem_5_9,22
# part_5_0,20
# part_5_1,20
# part_5_2,20
# part_5_3,20
# part_5_4,20
# part_5_5,20
# part_5_6,20
# part_5_7,20
# part_5_8,20
# part_5_9,20
# nation_5_0,11
# nation_5_1,11
# nation_5_2,11
# nation_5_3,11
# nation_5_4,11
# nation_5_5,11
# nation_5_6,11
# nation_5_7,11
# nation_5_8,11
# nation_5_9,11
# supplier_5_0,218
# supplier_5_1,218
# supplier_5_2,218
# supplier_5_3,218
# supplier_5_4,218
# supplier_5_5,218
# supplier_5_6,218
# supplier_5_7,218
# supplier_5_8,218
# supplier_5_9,218
# partsupp_5_0,131
# partsupp_5_1,131
# partsupp_5_2,131
# partsupp_5_3,131
# partsupp_5_4,131
# partsupp_5_5,131
# partsupp_5_6,131
# partsupp_5_7,131
# partsupp_5_8,131
# partsupp_5_9,131
# orders_5_0,85
# orders_5_1,85
# orders_5_2,85
# orders_5_3,85
# orders_5_4,85
# orders_5_5,85
# orders_5_6,85
# orders_5_7,85
# orders_5_8,85
# orders_5_9,85
# customers_5_0,82
# customers_5_1,82
# customers_5_2,82
# customers_5_3,82
# customers_5_4,82
# customers_5_5,82
# customers_5_6,82
# customers_5_7,82
# customers_5_8,82
# customers_5_9,82
# region_5_0,113
# region_5_1,113
# region_5_2,113
# region_5_3,113
# region_5_4,113
# region_5_5,113
# region_5_6,113
# region_5_7,113
# region_5_8,113
# region_5_9,113
# lineitem_6_0,98
# lineitem_6_1,98
# lineitem_6_2,98
# lineitem_6_3,98
# lineitem_6_4,98
# lineitem_6_5,98
# lineitem_6_6,98
# lineitem_6_7,98
# lineitem_6_8,98
# lineitem_6_9,98
# part_6_0,106
# part_6_1,106
# part_6_2,106
# part_6_3,106
# part_6_4,106
# part_6_5,106
# part_6_6,106
# part_6_7,106
# part_6_8,106
# part_6_9,106
# nation_6_0,44
# nation_6_1,44
# nation_6_2,44
# nation_6_3,44
# nation_6_4,44
# nation_6_5,44
# nation_6_6,44
# nation_6_7,44
# nation_6_8,44
# nation_6_9,44
# supplier_6_0,94
# supplier_6_1,94
# supplier_6_2,94
# supplier_6_3,94
# supplier_6_4,94
# supplier_6_5,94
# supplier_6_6,94
# supplier_6_7,94
# supplier_6_8,94
# supplier_6_9,94
# partsupp_6_0,101
# partsupp_6_1,101
# partsupp_6_2,101
# partsupp_6_3,101
# partsupp_6_4,101
# partsupp_6_5,101
# partsupp_6_6,101
# partsupp_6_7,101
# partsupp_6_8,101
# partsupp_6_9,101
# orders_6_0,60
# orders_6_1,60
# orders_6_2,60
# orders_6_3,60
# orders_6_4,60
# orders_6_5,60
# orders_6_6,60
# orders_6_7,60
# orders_6_8,60
# orders_6_9,60
# customers_6_0,27
# customers_6_1,27
# customers_6_2,27
# customers_6_3,27
# customers_6_4,27
# customers_6_5,27
# customers_6_6,27
# customers_6_7,27
# customers_6_8,27
# customers_6_9,27
# region_6_0,43
# region_6_1,43
# region_6_2,43
# region_6_3,43
# region_6_4,43
# region_6_5,43
# region_6_6,43
# region_6_7,43
# region_6_8,43
# region_6_9,43
# lineitem_7_0,120
# lineitem_7_1,120
# lineitem_7_2,120
# lineitem_7_3,120
# lineitem_7_4,120
# lineitem_7_5,120
# lineitem_7_6,120
# lineitem_7_7,120
# lineitem_7_8,120
# lineitem_7_9,120
# part_7_0,136
# part_7_1,136
# part_7_2,136
# part_7_3,136
# part_7_4,136
# part_7_5,136
# part_7_6,136
# part_7_7,136
# part_7_8,136
# part_7_9,136
# nation_7_0,113
# nation_7_1,113
# nation_7_2,113
# nation_7_3,113
# nation_7_4,113
# nation_7_5,113
# nation_7_6,113
# nation_7_7,113
# nation_7_8,113
# nation_7_9,113
# supplier_7_0,233
# supplier_7_1,233
# supplier_7_2,233
# supplier_7_3,233
# supplier_7_4,233
# supplier_7_5,233
# supplier_7_6,233
# supplier_7_7,233
# supplier_7_8,233
# supplier_7_9,233
# partsupp_7_0,76
# partsupp_7_1,76
# partsupp_7_2,76
# partsupp_7_3,76
# partsupp_7_4,76
# partsupp_7_5,76
# partsupp_7_6,76
# partsupp_7_7,76
# partsupp_7_8,76
# partsupp_7_9,76
# orders_7_0,199
# orders_7_1,199
# orders_7_2,199
# orders_7_3,199
# orders_7_4,199
# orders_7_5,199
# orders_7_6,199
# orders_7_7,199
# orders_7_8,199
# orders_7_9,199
# customers_7_0,79
# customers_7_1,79
# customers_7_2,79
# customers_7_3,79
# customers_7_4,79
# customers_7_5,79
# customers_7_6,79
# customers_7_7,79
# customers_7_8,79
# customers_7_9,79
# region_7_0,114
# region_7_1,114
# region_7_2,114
# region_7_3,114
# region_7_4,114
# region_7_5,114
# region_7_6,114
# region_7_7,114
# region_7_8,114
# region_7_9,114
# lineitem_8_0,24
# lineitem_8_1,24
# lineitem_8_2,24
# lineitem_8_3,24
# lineitem_8_4,24
# lineitem_8_5,24
# lineitem_8_6,24
# lineitem_8_7,24
# lineitem_8_8,24
# lineitem_8_9,24
# part_8_0,125
# part_8_1,125
# part_8_2,125
# part_8_3,125
# part_8_4,125
# part_8_5,125
# part_8_6,125
# part_8_7,125
# part_8_8,125
# part_8_9,125
# nation_8_0,204
# nation_8_1,204
# nation_8_2,204
# nation_8_3,204
# nation_8_4,204
# nation_8_5,204
# nation_8_6,204
# nation_8_7,204
# nation_8_8,204
# nation_8_9,204
# supplier_8_0,48
# supplier_8_1,48
# supplier_8_2,48
# supplier_8_3,48
# supplier_8_4,48
# supplier_8_5,48
# supplier_8_6,48
# supplier_8_7,48
# supplier_8_8,48
# supplier_8_9,48
# partsupp_8_0,70
# partsupp_8_1,70
# partsupp_8_2,70
# partsupp_8_3,70
# partsupp_8_4,70
# partsupp_8_5,70
# partsupp_8_6,70
# partsupp_8_7,70
# partsupp_8_8,70
# partsupp_8_9,70
# orders_8_0,226
# orders_8_1,226
# orders_8_2,226
# orders_8_3,226
# orders_8_4,226
# orders_8_5,226
# orders_8_6,226
# orders_8_7,226
# orders_8_8,226
# orders_8_9,226
# customers_8_0,182
# customers_8_1,182
# customers_8_2,182
# customers_8_3,182
# customers_8_4,182
# customers_8_5,182
# customers_8_6,182
# customers_8_7,182
# customers_8_8,182
# customers_8_9,182
# region_8_0,186
# region_8_1,186
# region_8_2,186
# region_8_3,186
# region_8_4,186
# region_8_5,186
# region_8_6,186
# region_8_7,186
# region_8_8,186
# region_8_9,186
# lineitem_9_0,212
# lineitem_9_1,212
# lineitem_9_2,212
# lineitem_9_3,212
# lineitem_9_4,212
# lineitem_9_5,212
# lineitem_9_6,212
# lineitem_9_7,212
# lineitem_9_8,212
# lineitem_9_9,212
# part_9_0,223
# part_9_1,223
# part_9_2,223
# part_9_3,223
# part_9_4,223
# part_9_5,223
# part_9_6,223
# part_9_7,223
# part_9_8,223
# part_9_9,223
# nation_9_0,73
# nation_9_1,73
# nation_9_2,73
# nation_9_3,73
# nation_9_4,73
# nation_9_5,73
# nation_9_6,73
# nation_9_7,73
# nation_9_8,73
# nation_9_9,73
# supplier_9_0,31
# supplier_9_1,31
# supplier_9_2,31
# supplier_9_3,31
# supplier_9_4,31
# supplier_9_5,31
# supplier_9_6,31
# supplier_9_7,31
# supplier_9_8,31
# supplier_9_9,31
# partsupp_9_0,88
# partsupp_9_1,88
# partsupp_9_2,88
# partsupp_9_3,88
# partsupp_9_4,88
# partsupp_9_5,88
# partsupp_9_6,88
# partsupp_9_7,88
# partsupp_9_8,88
# partsupp_9_9,88
# orders_9_0,111
# orders_9_1,111
# orders_9_2,111
# orders_9_3,111
# orders_9_4,111
# orders_9_5,111
# orders_9_6,111
# orders_9_7,111
# orders_9_8,111
# orders_9_9,111
# customers_9_0,114
# customers_9_1,114
# customers_9_2,114
# customers_9_3,114
# customers_9_4,114
# customers_9_5,114
# customers_9_6,114
# customers_9_7,114
# customers_9_8,114
# customers_9_9,114
# region_9_0,92
# region_9_1,92
# region_9_2,92
# region_9_3,92
# region_9_4,92
# region_9_5,92
# region_9_6,92
# region_9_7,92
# region_9_8,92
# region_9_9,92

# %%
reuse_ratio = 0.32
cfg_n_similar = 6
max_dag_concurrency=10
min_dag_concurrency=1
n_iterations = 10

seen_objects = {}

random_dags = {}

def query_runtime(g):
    roots = [v for v in g.vertices() if v.in_degree() == 0]
    leaves = [v for v in g.vertices() if v.out_degree() == 0]
    runtime = g.new_edge_property("float")
    t_query = []
    
    if g.num_edges() == 0: return g.vp.remote_runtime[0]
    
    for e in g.edges(): runtime[e] = -1*g.vp.remote_runtime[e.source()]
    g.ep['runtime'] = runtime
    
    predict_list= []
    for root in roots:
        for leaf in leaves:
            t_query.append(-1*gt.shortest_distance(g, g.vertex(root), g.vertex(leaf), weights=g.ep.runtime, 
                                            negative_weights=True, pred_map=None))
    return max(t_query)
    

n_inputs = 0
workload_str=''
g = None
for it in range(0, n_iterations):
    for i in range(0, n_concurrent_dags):
        gid, g = random_query()
        n_inputs = 0
        if it not in random_dags: random_dags[it] = {'graphs' : [], 'runtimes': [], 'shared': []}
        
        for v in g.vertices():
            t_compute = random.randint(5, 100)
            g.vp.remote_runtime[v] = t_compute
            g.vp.cache_runtime[v] = 1
            if len(g.vp.tables[v]) > 0: 
                n_inputs += 1
                g.vp.cache_runtime[v] = random.uniform(0.3, 1)        
        random_dags[it]['graphs'].append(g)
        random_dags[it]['runtimes'].append(query_runtime(g))
        
        
    #random_dags[it]['runtimes'], random_dags[it]['graphs'] = zip(*sorted(zip(random_dags[it]['runtimes'], 
    #                                                                         random_dags[it]['graphs']),
    #                                                                    key=lambda pair: pair[0]))    
    print(it, random_dags[it]['runtimes'])
    

it_sim = {}

for nsim in [0, 2, 4, 6, 8, 10]:
    workload_str = ''
    for it in range(0, n_iterations):
        workload_str += ("%" + 'r,%d,%d\n'%(it,n_concurrent_dags))
        if it not in it_sim:
            it_sim[it] = []
        i=0
        dags_wshare = random.sample(random_dags[it]['graphs'], 2) if nsim else []
        for g in dags_wshare:
            it_sim[it].append(g)
            random_dags[it]['graphs'].remove(g)
            
        for g in it_sim[it]:
            workload_str += ('#t,%d%d,%s\n'%(it,i,g.gp.id))
            for v in g.vertices():
                input_str=''
                if len(g.vp.tables[v]) > 0:  
                    inputs = g.vp.tables[v].split(':')
                    input_str = ':'.join(['%s_%d_%d'%(al,it,0) for al in inputs])
                workload_str += ('v,%d,%s,%s,%d,%.2f\n'%(g.vp.id[v],g.vp.feature[v],input_str,
                                            g.vp.remote_runtime[v], g.vp.cache_runtime[v]))
            for e in g.edges():
                workload_str += ('e,%d,%d\n'%(g.vp.id[e.source()],g.vp.id[e.target()]))
            i += 1
        
        for g in random_dags[it]['graphs']:    
            workload_str += ('#t,%d%d,%s\n'%(it,i,g.gp.id))
            for v in g.vertices():
                input_str=''
                if len(g.vp.tables[v]) > 0:  
                    inputs = g.vp.tables[v].split(':')
                    input_str = ':'.join(['%s_%d_%d'%(al,it,i) for al in inputs])                 
                workload_str += ('v,%d,%s,%s,%d,%.2f\n'%(g.vp.id[v],g.vp.feature[v],input_str,
                                            g.vp.remote_runtime[v], g.vp.cache_runtime[v]))
            for e in g.edges():
                workload_str += ('e,%d,%d\n'%(g.vp.id[e.source()],g.vp.id[e.target()]))
            i += 1
    print('Workflow for %d string was created'%(nsim))
    workload_file = '/local0/Kariz/expriments/simulator/multidag/config/synthetic_worload_md_%d.g'%(nsim)
    with open(workload_file, 'w') as fd:
        fd.write(workload_str)
# Out:
# 0 [396.0, 267.0, 12.0, 39, 361.0, 224.0, 18.0, 145.0, 191.0, 339.0]
# 1 [429.0, 378.0, 121.0, 255.0, 147.0, 224.0, 245.0, 332.0, 351.0, 216.0]
# 2 [170.0, 117.0, 180.0, 235.0, 50.0, 219.0, 141.0, 369.0, 257.0, 290.0]
# 3 [135.0, 358.0, 82.0, 160.0, 323.0, 274.0, 515.0, 163.0, 69, 360.0]
# 4 [146.0, 219.0, 362.0, 193.0, 280.0, 81.0, 149.0, 193.0, 210.0, 194.0]
# 5 [13.0, 254.0, 163.0, 150.0, 36.0, 91.0, 184.0, 61, 195.0, 304.0]
# 6 [16.0, 255.0, 71.0, 325.0, 173.0, 98.0, 132.0, 330.0, 339.0, 245.0]
# 7 [88.0, 354.0, 433.0, 68.0, 124.0, 277.0, 314.0, 327.0, 218.0, 380.0]
# 8 [158.0, 247.0, 15.0, 117.0, 123.0, 216.0, 85.0, 224.0, 168.0, 345.0]
# 9 [254.0, 335.0, 64.0, 169.0, 429.0, 197.0, 157.0, 9.0, 22.0, 160.0]
# Workflow for 0 string was created
# Workflow for 2 string was created
# Workflow for 4 string was created
# Workflow for 6 string was created
# Workflow for 8 string was created
# Workflow for 10 string was created

# %%
 
for i in range(0, n_concurrent_dags):
    if not (g and g.num_vertices() > 4 and n_similar > 1):
        gid, g = random_query()
    else:
        n_similar -= 1

    workload_str += ('#t,%d%d,%s\n'%(it,i,gid))
    for v in g.vertices():
        t_compute = random.randint(5, 100)
        t_reduction = 1
        if len(g.vp.tables[v]) > 0: 
            table = choose_input(seen_objects) 
            g.vp.tables[v] = table
            t_reduction = random.uniform(0.3, 1)
        workload_str += ('v,%d,%s,%s,%d,%.2f\n'%(g.vp.id[v],g.vp.feature[v],g.vp.tables[v],
                                        t_compute, t_reduction))
    for e in g.edges():
        workload_str += ('e,%d,%d\n'%(g.vp.id[e.source()],g.vp.id[e.target()]))
