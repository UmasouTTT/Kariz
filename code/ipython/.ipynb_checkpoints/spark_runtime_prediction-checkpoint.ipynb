# %%
import pandas as pd
import requests
import time
import datetime
import json
import ast
import subprocess


def spark_get_app_jobs(app_id):
    spark_hists_host='neu-3-1'
    spark_hists_port=18080
    URL = "http://%s:%d/api/v1/applications/%s/jobs"%(spark_hists_host,spark_hists_port,
                                                      app_id)
    return requests.get(url = URL).json()
    
def get_spark_job(app_id, jobid):
    spark_hists_host='neu-3-1'
    spark_hists_port=18080
    URL = "http://%s:%d/api/v1/applications/%s/jobs/%d"%(spark_hists_host,spark_hists_port,
                                                      app_id, jobid)
    return requests.get(url = URL).json()

def spark_get_app_stages(app_id):
    spark_hists_host='neu-3-1'
    spark_hists_port=18080
    URL = "http://%s:%d/api/v1/applications/%s/stages"%(spark_hists_host, spark_hists_port, 
                                                      app_id)
    return requests.get(url = URL).json()

def spark_get_app_stage(app_id, stage_id):
    spark_hists_host='neu-3-1'
    spark_hists_port=18080
    URL = "http://%s:%d/api/v1/applications/%s/stages/%d"%(spark_hists_host, spark_hists_port, 
                                                      app_id, stage_id)
    return requests.get(url = URL).json()


def get_spark_apps():
    spark_hists_host='neu-3-1'
    spark_hists_port=18080
    URL = "http://%s:%d/api/v1/applications"%(spark_hists_host,spark_hists_port)
    return requests.get(url = URL).json()

def get_dag_from_log(app_id):
    cat = subprocess.Popen(["hadoop", "fs", "-cat", '/local0/spark-logs/%s'%(app_id)], 
                           stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    stdout, stderr = cat.communicate()
    job_dag_str = ''
    for l in stdout.decode().split('\n'):
        l = l.replace('\n', '')
        if l.startswith('{"Event":"SparkListenerJobStart"'):
            job = json.loads(l)
            for stage in job['Stage Infos']:
                if len(stage['Parent IDs']) == 0:
                    job_dag_str += 'j:%s,e:->%s\n'%(job['Job ID'],stage['Stage ID'])
                    continue
                for pid in stage['Parent IDs']:
                    job_dag_str += 'j:%s,e:%s->%s\n'%(job['Job ID'],pid,stage['Stage ID'])           
    print('Application %s has been processed'%(app_id))
    return job_dag_str

app_name_to_id = {}
for app in get_spark_apps():
    if not app['name'].startswith('framework:spark'):
        continue
    app_name_to_id[app['name']] = {
        'app_name' : app['name'],
        'app_id' : app['id'],
        'app_start_time': app['attempts'][0]['startTimeEpoch'],
        'app_completion_time': app['attempts'][0]['endTimeEpoch'],
        'app_dag': get_dag_from_log(app['id'])}
    for i in app['name'].split('-'):
        app_name_to_id[app['name']][i.split(':')[0]] = i.split(':')[1]
# Out:
# Application app-20200906205822-0296 has been processed
# Application app-20200906205231-0295 has been processed
# Application app-20200906204446-0294 has been processed
# Application app-20200906203015-0292 has been processed
# Application app-20200906202643-0291 has been processed
# Application app-20200906202345-0290 has been processed
# Application app-20200906202223-0289 has been processed
# Application app-20200906202021-0288 has been processed
# Application app-20200906201651-0287 has been processed
# Application app-20200906201007-0286 has been processed
# Application app-20200906200438-0285 has been processed
# Application app-20200906200232-0284 has been processed
# Application app-20200906195516-0283 has been processed
# Application app-20200906195137-0282 has been processed
# Application app-20200906194404-0281 has been processed
# Application app-20200906193403-0280 has been processed
# Application app-20200906192726-0279 has been processed
# Application app-20200906192020-0278 has been processed
# Application app-20200906190651-0276 has been processed
# Application app-20200906185653-0275 has been processed
# Application app-20200906185242-0274 has been processed
# Application app-20200906184832-0273 has been processed
# Application app-20200906184423-0272 has been processed
# Application app-20200906184259-0271 has been processed
# Application app-20200906183905-0270 has been processed
# Application app-20200906183408-0269 has been processed
# Application app-20200906183220-0268 has been processed
# Application app-20200906183001-0267 has been processed
# Application app-20200906182828-0266 has been processed
# Application app-20200906182351-0265 has been processed
# Application app-20200906182138-0264 has been processed
# Application app-20200906181927-0263 has been processed
# Application app-20200906181657-0262 has been processed
# Application app-20200906181502-0261 has been processed
# Application app-20200906181122-0260 has been processed
# Application app-20200906180915-0259 has been processed
# Application app-20200906180609-0258 has been processed
# Application app-20200906180245-0257 has been processed
# Application app-20200906175919-0256 has been processed
# Application app-20200906175634-0255 has been processed
# Application app-20200906175232-0254 has been processed
# Application app-20200906173213-0253 has been processed
# Application app-20200906172704-0252 has been processed
# Application app-20200906172522-0251 has been processed
# Application app-20200906172105-0250 has been processed
# Application app-20200906171910-0249 has been processed
# Application app-20200906171620-0248 has been processed
# Application app-20200906171302-0247 has been processed
# Application app-20200906171132-0246 has been processed
# Application app-20200906170923-0245 has been processed
# Application app-20200906170731-0244 has been processed
# Application app-20200906170431-0243 has been processed
# Application app-20200906170107-0242 has been processed
# Application app-20200906165839-0241 has been processed
# Application app-20200906165706-0240 has been processed
# Application app-20200906165455-0239 has been processed
# Application app-20200906165130-0238 has been processed
# Application app-20200906164916-0237 has been processed
# Application app-20200906164601-0236 has been processed
# Application app-20200906164341-0235 has been processed
# Application app-20200906164057-0234 has been processed
# Application app-20200906163840-0233 has been processed
# Application app-20200906163551-0232 has been processed
# Application app-20200906163258-0231 has been processed
# Application app-20200906125727-0230 has been processed
# Application app-20200906123846-0228 has been processed
# Application app-20200906123415-0227 has been processed
# Application app-20200906122356-0226 has been processed
# Application app-20200906121717-0225 has been processed
# Application app-20200906121331-0224 has been processed
# Application app-20200906120725-0223 has been processed
# Application app-20200906120230-0222 has been processed
# Application app-20200906115712-0221 has been processed
# Application app-20200906115511-0220 has been processed
# Application app-20200906115107-0219 has been processed
# Application app-20200906113907-0218 has been processed
# Application app-20200906113424-0217 has been processed
# Application app-20200906112849-0216 has been processed
# Application app-20200906111826-0215 has been processed
# Application app-20200906110748-0214 has been processed
# Application app-20200906110356-0213 has been processed
# Application app-20200906105503-0212 has been processed
# Application app-20200906105222-0211 has been processed
# Application app-20200906104420-0210 has been processed
# Application app-20200906103350-0209 has been processed
# Application app-20200906102657-0208 has been processed
# Application app-20200906102415-0207 has been processed
# Application app-20200906102153-0206 has been processed
# Application app-20200906101719-0205 has been processed
# Application app-20200906101306-0204 has been processed
# Application app-20200906101106-0203 has been processed
# Application app-20200906100732-0202 has been processed
# Application app-20200906100444-0201 has been processed
# Application app-20200906100143-0200 has been processed
# Application app-20200906095823-0199 has been processed
# Application app-20200906095710-0198 has been processed
# Application app-20200906095525-0197 has been processed
# Application app-20200906095147-0196 has been processed
# Application app-20200906094901-0195 has been processed
# Application app-20200906094628-0194 has been processed
# Application app-20200906094005-0193 has been processed
# Application app-20200906093542-0192 has been processed
# Application app-20200906093347-0191 has been processed
# Application app-20200906093228-0190 has been processed
# Application app-20200906092841-0189 has been processed
# Application app-20200906092332-0188 has been processed
# Application app-20200906091925-0187 has been processed
# Application app-20200906091336-0186 has been processed
# Application app-20200906091027-0185 has been processed
# Application app-20200906090723-0184 has been processed
# Application app-20200906090521-0183 has been processed
# Application app-20200906090303-0182 has been processed
# Application app-20200906085922-0181 has been processed
# Application app-20200906085750-0180 has been processed
# Application app-20200906085344-0179 has been processed
# Application app-20200906084904-0178 has been processed
# Application app-20200906084642-0177 has been processed
# Application app-20200906084411-0176 has been processed
# Application app-20200906084101-0175 has been processed
# Application app-20200906083849-0174 has been processed
# Application app-20200906083521-0173 has been processed
# Application app-20200906083141-0172 has been processed
# Application app-20200906082909-0171 has been processed
# Application app-20200906082617-0170 has been processed
# Application app-20200906082344-0169 has been processed
# Application app-20200906082151-0168 has been processed
# Application app-20200906081639-0167 has been processed
# Application app-20200906081250-0166 has been processed
# Application app-20200906081056-0165 has been processed
# Application app-20200905205146-0164 has been processed
# Application app-20200905204238-0163 has been processed
# Application app-20200905203825-0162 has been processed
# Application app-20200905203447-0161 has been processed
# Application app-20200905203043-0160 has been processed
# Application app-20200905202031-0159 has been processed
# Application app-20200905201110-0158 has been processed
# Application app-20200905200525-0157 has been processed
# Application app-20200905195310-0156 has been processed
# Application app-20200905194943-0155 has been processed
# Application app-20200905194203-0154 has been processed
# Application app-20200905193824-0153 has been processed
# Application app-20200905193458-0152 has been processed
# Application app-20200905192603-0151 has been processed
# Application app-20200905191925-0150 has been processed
# Application app-20200905191603-0149 has been processed
# Application app-20200905191246-0148 has been processed
# Application app-20200905190424-0147 has been processed
# Application app-20200905185511-0146 has been processed
# Application app-20200905185134-0145 has been processed
# Application app-20200905184332-0144 has been processed
# Application app-20200905183848-0143 has been processed
# Application app-20200905183443-0142 has been processed
# Application app-20200905183147-0141 has been processed
# Application app-20200905182931-0140 has been processed
# Application app-20200905182508-0139 has been processed
# Application app-20200905182030-0138 has been processed
# Application app-20200905181709-0137 has been processed
# Application app-20200905181303-0136 has been processed
# Application app-20200905180847-0135 has been processed
# Application app-20200905180720-0134 has been processed
# Application app-20200905180519-0133 has been processed
# Application app-20200905180057-0132 has been processed
# Application app-20200905175622-0131 has been processed
# Application app-20200905175345-0130 has been processed
# Application app-20200905174956-0129 has been processed
# Application app-20200905174635-0128 has been processed
# Application app-20200905173653-0127 has been processed
# Application app-20200905173415-0126 has been processed
# Application app-20200905172943-0125 has been processed
# Application app-20200905172800-0124 has been processed
# Application app-20200905172313-0123 has been processed
# Application app-20200905172139-0122 has been processed
# Application app-20200905171848-0121 has been processed
# Application app-20200905171448-0120 has been processed
# Application app-20200905171046-0119 has been processed
# Application app-20200905170611-0118 has been processed
# Application app-20200905170351-0117 has been processed
# Application app-20200905170110-0116 has been processed
# Application app-20200905165821-0115 has been processed
# Application app-20200905165623-0114 has been processed
# Application app-20200905165409-0113 has been processed
# Application app-20200905165053-0112 has been processed
# Application app-20200905164809-0111 has been processed
# Application app-20200905164612-0110 has been processed
# Application app-20200905164219-0109 has been processed
# Application app-20200905163914-0108 has been processed
# Application app-20200905163707-0107 has been processed
# Application app-20200905163243-0106 has been processed
# Application app-20200905163114-0105 has been processed
# Application app-20200905162814-0104 has been processed
# Application app-20200905162319-0103 has been processed
# Application app-20200905162038-0102 has been processed
# Application app-20200905161712-0101 has been processed
# Application app-20200905161343-0100 has been processed
# Application app-20200905160939-0099 has been processed
# Application app-20200905160355-0098 has been processed
# Application app-20200905160240-0097 has been processed
# Application app-20200905155937-0096 has been processed
# Application app-20200905155730-0095 has been processed
# Application app-20200905132024-0046 has been processed
# Application app-20200905131459-0045 has been processed
# Application app-20200905131041-0044 has been processed
# Application app-20200905130055-0043 has been processed
# Application app-20200905125630-0042 has been processed
# Application app-20200905125353-0041 has been processed
# Application app-20200905125013-0040 has been processed
# Application app-20200905124745-0039 has been processed
# Application app-20200905124418-0038 has been processed
# Application app-20200905124103-0037 has been processed
# Application app-20200905123920-0036 has been processed
# Application app-20200905123610-0035 has been processed
# Application app-20200905123417-0034 has been processed
# Application app-20200905123121-0033 has been processed
# Application app-20200905122800-0032 has been processed
# Application app-20200905122625-0031 has been processed
# Application app-20200905122427-0030 has been processed
# Application app-20200905122121-0029 has been processed
# Application app-20200905121944-0028 has been processed
# Application app-20200905121709-0027 has been processed
# Application app-20200905121427-0026 has been processed
# Application app-20200905121100-0025 has been processed
# Application app-20200905120611-0023 has been processed
# Application app-20200905120329-0022 has been processed
# Application app-20200905120200-0021 has been processed
# Application app-20200905120040-0020 has been processed
# Application app-20200905115708-0019 has been processed
# Application app-20200905115424-0018 has been processed
# Application app-20200905115243-0017 has been processed
# Application app-20200905114946-0016 has been processed
# Application app-20200905114706-0015 has been processed
# Application app-20200905105312-0014 has been processed
# Application app-20200905105112-0013 has been processed
# Application app-20200905104849-0012 has been processed
# Application app-20200905104607-0011 has been processed
# Application app-20200905104304-0010 has been processed
# Application app-20200905103633-0009 has been processed

# %%
fpath='/local0/Kariz/expriments/runtime_prediction/tpch/runtime.pred.spark.stats.csv'
kariz_apps = pd.read_csv(fpath)
kariz_apps.head(5)
# Out:
#                                                                  app_name
# 0     framework:spark-name:tpch17-bw:40Gbps-ds:-stride:90-random:hszhwpis
# 1    framework:spark-name:tpch9-bw:5Gbps-ds:20G-stride:50-random:munbjefq
# 2   framework:spark-name:tpch3-bw:5Gbps-ds:20G-stride:100-random:xqrhrjjz
# 3  framework:spark-name:tpch22-bw:10Gbps-ds:20G-stride:90-random:sedbveld
# 4  framework:spark-name:tpch13-bw:40Gbps-ds:20G-stride:80-random:ufhowguh

# %%
def get_spark_app_history(row, app_stats):
    if row['app_name'] not in app_name_to_id:
        return 
    
    app_meta = app_name_to_id[row['app_name']]
    app_id = app_name_to_id[row['app_name']]['app_id']
    
    print('Application', app_id, 'with name', row['app_name'], 'to be processed')
    
    # jobs within this application
    jobs = spark_get_app_jobs(app_id)
    for job in jobs:
        job_start_time = time.mktime(datetime.datetime.strptime(job['submissionTime'],
                                                     "%Y-%m-%dT%H:%M:%S.%fGMT").timetuple())
        job_completion_time = time.mktime(datetime.datetime.strptime(job['completionTime'],
                                                     "%Y-%m-%dT%H:%M:%S.%fGMT").timetuple())

        stages = job['stageIds']
        for sid in stages:
            stage = spark_get_app_stage(app_id, sid)[0]
            
            if stage['status'] == 'SKIPPED':
                continue
            
            stage_submit_time = time.mktime(datetime.datetime.strptime(stage['submissionTime'],
                                                         "%Y-%m-%dT%H:%M:%S.%fGMT").timetuple())
            stage_start_time = time.mktime(datetime.datetime.strptime(stage['firstTaskLaunchedTime'],
                                                         "%Y-%m-%dT%H:%M:%S.%fGMT").timetuple())
            stage_completion_time = time.mktime(datetime.datetime.strptime(stage['completionTime'],
                                                         "%Y-%m-%dT%H:%M:%S.%fGMT").timetuple())
            stage_queue_time = stage_start_time - stage_submit_time
            stage_run_time = stage_completion_time - stage_start_time

            stage_stats = {
                      'job_id': job['jobId'], 
                      'job_submission_time': job_start_time,
                      'job_completion_time': job_completion_time,
                      'job_stage_ids': job['stageIds'],
                      'stage_id': stage['stageId'], 'numTasks': stage['numTasks'], 
                      'stage_submission_time': stage_submit_time, 
                      'stage_start_time': stage_start_time, 
                      'stage_completion_time': stage_completion_time,
                      'stage_queue_time': stage_queue_time,
                      'stage_run_time': stage_run_time,
                      'stage_input_bytes': stage['inputBytes'], 
                      'outputBytes': stage['outputBytes'], 
                      'stage_shuffle_read_bytes': stage['shuffleReadBytes'], 
                      'stage_shuffle_write_bytes': stage['shuffleWriteBytes'],
                      'stage_rdds': stage['rddIds']}
            stage_stats.update(app_meta)
            app_stats.append(stage_stats)

application_stats = []
kariz_apps.apply(get_spark_app_history, axis=1, app_stats=application_stats)
df = pd.DataFrame(application_stats)
# Out:
# Application app-20200905103633-0009 with name framework:spark-name:tpch9-bw:5Gbps-ds:20G-stride:50-random:munbjefq to be processed
# Application app-20200905104304-0010 with name framework:spark-name:tpch3-bw:5Gbps-ds:20G-stride:100-random:xqrhrjjz to be processed
# Application app-20200905104607-0011 with name framework:spark-name:tpch22-bw:10Gbps-ds:20G-stride:90-random:sedbveld to be processed
# Application app-20200905104849-0012 with name framework:spark-name:tpch13-bw:40Gbps-ds:20G-stride:80-random:ufhowguh to be processed
# Application app-20200905105112-0013 with name framework:spark-name:tpch11-bw:5Gbps-ds:20G-stride:60-random:phbqgajg to be processed
# Application app-20200905105312-0014 with name framework:spark-name:tpch4-bw:1Gbps-ds:20G-stride:25-random:mjqwwtnr to be processed
# Application app-20200905114706-0015 with name framework:spark-name:tpch3-bw:10Gbps-ds:20G-stride:10-random:jfmaevlu to be processed
# Application app-20200905114946-0016 with name framework:spark-name:tpch20-bw:10Gbps-ds:20G-stride:70-random:itpfzkim to be processed
# Application app-20200905115243-0017 with name framework:spark-name:tpch16-bw:40Gbps-ds:20G-stride:80-random:mxwnpzpi to be processed
# Application app-20200905115424-0018 with name framework:spark-name:tpch17-bw:10Gbps-ds:20G-stride:25-random:zmcwhvzv to be processed
# Application app-20200905115708-0019 with name framework:spark-name:tpch15-bw:1Gbps-ds:20G-stride:10-random:addgbgan to be processed
# Application app-20200905120040-0020 with name framework:spark-name:tpch10-bw:40Gbps-ds:20G-stride:25-random:buiarvbp to be processed
# Application app-20200905120200-0021 with name framework:spark-name:tpch5-bw:20Gbps-ds:20G-stride:0-random:ohefuksa to be processed
# Application app-20200905120329-0022 with name framework:spark-name:tpch22-bw:40Gbps-ds:20G-stride:0-random:aeisjkcv to be processed
# Application app-20200905120611-0023 with name framework:spark-name:tpch11-bw:20Gbps-ds:20G-stride:70-random:auerdiiw to be processed
# Application app-20200905121100-0025 with name framework:spark-name:tpch7-bw:1Gbps-ds:20G-stride:40-random:ozsbfswi to be processed
# Application app-20200905121427-0026 with name framework:spark-name:tpch13-bw:20Gbps-ds:20G-stride:30-random:bcippubi to be processed
# Application app-20200905121709-0027 with name framework:spark-name:tpch9-bw:5Gbps-ds:20G-stride:70-random:wvuoldfx to be processed
# Application app-20200905121944-0028 with name framework:spark-name:tpch17-bw:5Gbps-ds:20G-stride:50-random:bufaprks to be processed
# Application app-20200905122121-0029 with name framework:spark-name:tpch16-bw:20Gbps-ds:20G-stride:10-random:hcxrffth to be processed
# Application app-20200905122427-0030 with name framework:spark-name:tpch21-bw:10Gbps-ds:20G-stride:90-random:agjkgzqw to be processed
# Application app-20200905122625-0031 with name framework:spark-name:tpch8-bw:5Gbps-ds:20G-stride:10-random:wqtxerot to be processed
# Application app-20200905122800-0032 with name framework:spark-name:tpch4-bw:40Gbps-ds:20G-stride:0-random:hoqdthsc to be processed
# Application app-20200905123121-0033 with name framework:spark-name:tpch18-bw:20Gbps-ds:20G-stride:100-random:qgvqilxr to be processed
# Application app-20200905123417-0034 with name framework:spark-name:tpch20-bw:10Gbps-ds:20G-stride:70-random:naqrotyk to be processed
# Application app-20200905123610-0035 with name framework:spark-name:tpch19-bw:5Gbps-ds:20G-stride:20-random:yrijmogx to be processed
# Application app-20200905123920-0036 with name framework:spark-name:tpch12-bw:40Gbps-ds:20G-stride:90-random:mvsrmbmg to be processed
# Application app-20200905124103-0037 with name framework:spark-name:tpch14-bw:20Gbps-ds:20G-stride:20-random:nzsdfrrf to be processed
# Application app-20200905124418-0038 with name framework:spark-name:tpch2-bw:5Gbps-ds:20G-stride:100-random:vpqsdaip to be processed
# Application app-20200905124745-0039 with name framework:spark-name:tpch1-bw:1Gbps-ds:20G-stride:70-random:rczdywbp to be processed
# Application app-20200905125013-0040 with name framework:spark-name:tpch3-bw:40Gbps-ds:20G-stride:40-random:blacmfaz to be processed
# Application app-20200905125353-0041 with name framework:spark-name:tpch15-bw:40Gbps-ds:32G-stride:60-random:oxhbvnkw to be processed
# Application app-20200905125630-0042 with name framework:spark-name:tpch10-bw:1Gbps-ds:32G-stride:25-random:pwktfgvp to be processed
# Application app-20200905130055-0043 with name framework:spark-name:tpch5-bw:1Gbps-ds:32G-stride:0-random:oikswlnd to be processed
# Application app-20200905131041-0044 with name framework:spark-name:tpch22-bw:20Gbps-ds:32G-stride:100-random:pipcwliv to be processed
# Application app-20200905131459-0045 with name framework:spark-name:tpch11-bw:10Gbps-ds:32G-stride:80-random:pzicgarz to be processed
# Application app-20200905132024-0046 with name framework:spark-name:tpch6-bw:1Gbps-ds:32G-stride:80-random:mwmvnxoy to be processed
# Application app-20200905155730-0095 with name framework:spark-name:tpch14-bw:20Gbps-ds:20G-stride:40-random:ztodawjn to be processed
# Application app-20200905155937-0096 with name framework:spark-name:tpch2-bw:20Gbps-ds:20G-stride:30-random:mrlxxxnr to be processed
# Application app-20200905160240-0097 with name framework:spark-name:tpch22-bw:20Gbps-ds:20G-stride:70-random:gxtthyxk to be processed
# Application app-20200905160939-0099 with name framework:spark-name:tpch9-bw:20Gbps-ds:20G-stride:80-random:jznmngao to be processed
# Application app-20200905161343-0100 with name framework:spark-name:tpch6-bw:1Gbps-ds:20G-stride:80-random:ciksuvux to be processed
# Application app-20200905161712-0101 with name framework:spark-name:tpch10-bw:5Gbps-ds:20G-stride:100-random:hfcolgak to be processed
# Application app-20200905162038-0102 with name framework:spark-name:tpch18-bw:10Gbps-ds:20G-stride:90-random:dolbavit to be processed
# Application app-20200905162319-0103 with name framework:spark-name:tpch3-bw:1Gbps-ds:20G-stride:40-random:rdvsaqnm to be processed
# Application app-20200905162814-0104 with name framework:spark-name:tpch16-bw:1Gbps-ds:20G-stride:70-random:naolxirw to be processed
# Application app-20200905163114-0105 with name framework:spark-name:tpch20-bw:5Gbps-ds:20G-stride:80-random:nmjopxnk to be processed
# Application app-20200905163243-0106 with name framework:spark-name:tpch8-bw:1Gbps-ds:20G-stride:0-random:jrrcissy to be processed
# Application app-20200905163707-0107 with name framework:spark-name:tpch15-bw:5Gbps-ds:20G-stride:20-random:xqjaswao to be processed
# Application app-20200905163914-0108 with name framework:spark-name:tpch22-bw:20Gbps-ds:20G-stride:30-random:eqxtmlbf to be processed
# Application app-20200905164219-0109 with name framework:spark-name:tpch11-bw:1Gbps-ds:20G-stride:60-random:ugzoskuj to be processed
# Application app-20200905164612-0110 with name framework:spark-name:tpch19-bw:1Gbps-ds:20G-stride:80-random:eyxzzznf to be processed
# Application app-20200905164809-0111 with name framework:spark-name:tpch2-bw:5Gbps-ds:20G-stride:20-random:kyrsveng to be processed
# Application app-20200905165053-0112 with name framework:spark-name:tpch7-bw:20Gbps-ds:20G-stride:70-random:ecwyevha to be processed
# Application app-20200905165409-0113 with name framework:spark-name:tpch13-bw:1Gbps-ds:20G-stride:60-random:bcwwsoup to be processed
# Application app-20200905165623-0114 with name framework:spark-name:tpch21-bw:10Gbps-ds:20G-stride:40-random:zzglfsfv to be processed
# Application app-20200905165821-0115 with name framework:spark-name:tpch5-bw:10Gbps-ds:20G-stride:10-random:rwgvtqrr to be processed
# Application app-20200905170110-0116 with name framework:spark-name:tpch1-bw:20Gbps-ds:20G-stride:50-random:ohvymowr to be processed
# Application app-20200905170351-0117 with name framework:spark-name:tpch17-bw:40Gbps-ds:20G-stride:70-random:viwdjojq to be processed
# Application app-20200905170611-0118 with name framework:spark-name:tpch14-bw:1Gbps-ds:20G-stride:30-random:ljcltenh to be processed
# Application app-20200905171046-0119 with name framework:spark-name:tpch12-bw:1Gbps-ds:20G-stride:60-random:rkvjiijq to be processed
# Application app-20200905171448-0120 with name framework:spark-name:tpch4-bw:40Gbps-ds:20G-stride:90-random:uudxswkn to be processed
# Application app-20200905171848-0121 with name framework:spark-name:tpch9-bw:20Gbps-ds:32G-stride:70-random:bvqkekxy to be processed
# Application app-20200905172139-0122 with name framework:spark-name:tpch6-bw:20Gbps-ds:32G-stride:30-random:fibkbexf to be processed
# Application app-20200905172313-0123 with name framework:spark-name:tpch10-bw:5Gbps-ds:32G-stride:10-random:ivhwekgg to be processed
# Application app-20200905172800-0124 with name framework:spark-name:tpch18-bw:20Gbps-ds:32G-stride:80-random:vmanmvwn to be processed
# Application app-20200905172943-0125 with name framework:spark-name:tpch3-bw:20Gbps-ds:32G-stride:0-random:dqlycaka to be processed
# Application app-20200905173415-0126 with name framework:spark-name:tpch16-bw:5Gbps-ds:32G-stride:90-random:ckqzurdf to be processed
# Application app-20200905173653-0127 with name framework:spark-name:tpch20-bw:40Gbps-ds:32G-stride:40-random:fanbmydw to be processed
# Application app-20200905174635-0128 with name framework:spark-name:tpch8-bw:10Gbps-ds:32G-stride:25-random:shtsvktc to be processed
# Application app-20200905174956-0129 with name framework:spark-name:tpch15-bw:10Gbps-ds:32G-stride:50-random:fpfvygit to be processed
# Application app-20200905175345-0130 with name framework:spark-name:tpch22-bw:20Gbps-ds:32G-stride:70-random:pzeiinww to be processed
# Application app-20200905175622-0131 with name framework:spark-name:tpch11-bw:10Gbps-ds:32G-stride:40-random:paetuevi to be processed
# Application app-20200905180057-0132 with name framework:spark-name:tpch19-bw:40Gbps-ds:32G-stride:100-random:dtfrnlxj to be processed
# Application app-20200905180519-0133 with name framework:spark-name:tpch2-bw:40Gbps-ds:32G-stride:90-random:zalhmxne to be processed
# Application app-20200905180720-0134 with name framework:spark-name:tpch7-bw:20Gbps-ds:32G-stride:20-random:cwqcymeb to be processed
# Application app-20200905180847-0135 with name framework:spark-name:tpch13-bw:40Gbps-ds:32G-stride:0-random:vihzphmq to be processed
# Application app-20200905181303-0136 with name framework:spark-name:tpch21-bw:40Gbps-ds:32G-stride:90-random:voigccdn to be processed
# Application app-20200905181709-0137 with name framework:spark-name:tpch5-bw:20Gbps-ds:32G-stride:60-random:hqvwmrra to be processed
# Application app-20200905182030-0138 with name framework:spark-name:tpch1-bw:40Gbps-ds:32G-stride:50-random:tohfxhji to be processed
# Application app-20200905182508-0139 with name framework:spark-name:tpch17-bw:20Gbps-ds:32G-stride:100-random:pqhpptzi to be processed
# Application app-20200905182931-0140 with name framework:spark-name:tpch14-bw:40Gbps-ds:32G-stride:80-random:bgpsnwsa to be processed
# Application app-20200905183147-0141 with name framework:spark-name:tpch12-bw:40Gbps-ds:32G-stride:30-random:nhanfhid to be processed
# Application app-20200905183443-0142 with name framework:spark-name:tpch4-bw:1Gbps-ds:32G-stride:30-random:dovrlkmk to be processed
# Application app-20200905183848-0143 with name framework:spark-name:tpch9-bw:10Gbps-ds:64G-stride:0-random:ljoqppvq to be processed
# Application app-20200905184332-0144 with name framework:spark-name:tpch6-bw:5Gbps-ds:64G-stride:30-random:uskdcuux to be processed
# Application app-20200905185134-0145 with name framework:spark-name:tpch10-bw:10Gbps-ds:64G-stride:80-random:tiedgoek to be processed
# Application app-20200905185511-0146 with name framework:spark-name:tpch18-bw:5Gbps-ds:64G-stride:25-random:cspnmdev to be processed
# Application app-20200905190424-0147 with name framework:spark-name:tpch3-bw:10Gbps-ds:64G-stride:80-random:vfoslbhn to be processed
# Application app-20200905191246-0148 with name framework:spark-name:tpch16-bw:40Gbps-ds:64G-stride:90-random:mquabpwc to be processed
# Application app-20200905191603-0149 with name framework:spark-name:tpch20-bw:10Gbps-ds:64G-stride:25-random:qrhajvqt to be processed
# Application app-20200905191925-0150 with name framework:spark-name:tpch8-bw:10Gbps-ds:64G-stride:20-random:hkzsejcx to be processed
# Application app-20200905192603-0151 with name framework:spark-name:tpch15-bw:10Gbps-ds:64G-stride:60-random:lkofptxz to be processed
# Application app-20200905193458-0152 with name framework:spark-name:tpch22-bw:1Gbps-ds:64G-stride:70-random:iprjrflu to be processed
# Application app-20200905193824-0153 with name framework:spark-name:tpch11-bw:5Gbps-ds:64G-stride:20-random:wjbphovq to be processed
# Application app-20200905194203-0154 with name framework:spark-name:tpch19-bw:20Gbps-ds:64G-stride:30-random:uusdtsdd to be processed
# Application app-20200905194943-0155 with name framework:spark-name:tpch2-bw:5Gbps-ds:64G-stride:80-random:iycnqczq to be processed
# Application app-20200905195310-0156 with name framework:spark-name:tpch7-bw:1Gbps-ds:64G-stride:20-random:pcdzckcp to be processed
# Application app-20200905200525-0157 with name framework:spark-name:tpch13-bw:5Gbps-ds:64G-stride:50-random:eoiknhsi to be processed
# Application app-20200905201110-0158 with name framework:spark-name:tpch21-bw:5Gbps-ds:64G-stride:60-random:hlhuoapw to be processed
# Application app-20200905202031-0159 with name framework:spark-name:tpch5-bw:10Gbps-ds:64G-stride:90-random:dkucfxzl to be processed
# Application app-20200905203043-0160 with name framework:spark-name:tpch1-bw:1Gbps-ds:64G-stride:80-random:baohrbdu to be processed
# Application app-20200905203447-0161 with name framework:spark-name:tpch17-bw:20Gbps-ds:64G-stride:20-random:wrubnwjh to be processed
# Application app-20200905203825-0162 with name framework:spark-name:tpch14-bw:20Gbps-ds:64G-stride:20-random:okboflkz to be processed
# Application app-20200905204238-0163 with name framework:spark-name:tpch12-bw:1Gbps-ds:64G-stride:25-random:iosfuyda to be processed
# Application app-20200905205146-0164 with name framework:spark-name:tpch4-bw:5Gbps-ds:64G-stride:20-random:dyydebss to be processed
# Application app-20200906081056-0165 with name framework:spark-name:tpch13-bw:5Gbps-ds:20G-stride:60-random:kuscltcg to be processed
# Application app-20200906081250-0166 with name framework:spark-name:tpch21-bw:10Gbps-ds:20G-stride:30-random:pifggabj to be processed
# Application app-20200906081639-0167 with name framework:spark-name:tpch11-bw:5Gbps-ds:20G-stride:100-random:ajexullc to be processed
# Application app-20200906082151-0168 with name framework:spark-name:tpch19-bw:10Gbps-ds:20G-stride:60-random:gabsbccg to be processed
# Application app-20200906082344-0169 with name framework:spark-name:tpch12-bw:10Gbps-ds:20G-stride:30-random:xplprxir to be processed
# Application app-20200906082617-0170 with name framework:spark-name:tpch2-bw:10Gbps-ds:20G-stride:60-random:ijabcjrl to be processed
# Application app-20200906082909-0171 with name framework:spark-name:tpch4-bw:40Gbps-ds:20G-stride:80-random:rigmgavk to be processed
# Application app-20200906083141-0172 with name framework:spark-name:tpch9-bw:1Gbps-ds:20G-stride:40-random:alaayntq to be processed
# Application app-20200906083521-0173 with name framework:spark-name:tpch18-bw:20Gbps-ds:20G-stride:10-random:uttelwpk to be processed
# Application app-20200906083849-0174 with name framework:spark-name:tpch7-bw:20Gbps-ds:20G-stride:100-random:exxffmgh to be processed
# Application app-20200906084101-0175 with name framework:spark-name:tpch3-bw:10Gbps-ds:20G-stride:40-random:syksyxal to be processed
# Application app-20200906084411-0176 with name framework:spark-name:tpch22-bw:5Gbps-ds:20G-stride:90-random:mwmzlkjz to be processed
# Application app-20200906084642-0177 with name framework:spark-name:tpch17-bw:5Gbps-ds:20G-stride:60-random:cynmznuh to be processed
# Application app-20200906084904-0178 with name framework:spark-name:tpch8-bw:1Gbps-ds:20G-stride:30-random:jjtjigwk to be processed
# Application app-20200906085344-0179 with name framework:spark-name:tpch14-bw:5Gbps-ds:20G-stride:70-random:kxswetno to be processed
# Application app-20200906085750-0180 with name framework:spark-name:tpch15-bw:10Gbps-ds:20G-stride:100-random:qmjehwbj to be processed
# Application app-20200906085922-0181 with name framework:spark-name:tpch6-bw:20Gbps-ds:20G-stride:10-random:tokxearf to be processed
# Application app-20200906090303-0182 with name framework:spark-name:tpch20-bw:1Gbps-ds:20G-stride:80-random:twwxjzgg to be processed
# Application app-20200906090521-0183 with name framework:spark-name:tpch1-bw:20Gbps-ds:20G-stride:25-random:hgepbzqp to be processed
# Application app-20200906090723-0184 with name framework:spark-name:tpch16-bw:1Gbps-ds:20G-stride:25-random:pigkwyxe to be processed
# Application app-20200906091027-0185 with name framework:spark-name:tpch5-bw:40Gbps-ds:20G-stride:80-random:uytgvwqs to be processed
# Application app-20200906091336-0186 with name framework:spark-name:tpch10-bw:1Gbps-ds:20G-stride:50-random:ajvajwru to be processed
# Application app-20200906091925-0187 with name framework:spark-name:tpch13-bw:20Gbps-ds:32G-stride:90-random:civaqyqk to be processed
# Application app-20200906092332-0188 with name framework:spark-name:tpch21-bw:5Gbps-ds:32G-stride:80-random:gxmkpbre to be processed
# Application app-20200906092841-0189 with name framework:spark-name:tpch11-bw:20Gbps-ds:32G-stride:90-random:omlevyen to be processed
# Application app-20200906093228-0190 with name framework:spark-name:tpch19-bw:10Gbps-ds:32G-stride:70-random:pjqdfpco to be processed
# Application app-20200906093347-0191 with name framework:spark-name:tpch12-bw:20Gbps-ds:32G-stride:0-random:ytgpvfcm to be processed
# Application app-20200906093542-0192 with name framework:spark-name:tpch2-bw:1Gbps-ds:32G-stride:10-random:jxcjbozh to be processed
# Application app-20200906094005-0193 with name framework:spark-name:tpch4-bw:1Gbps-ds:32G-stride:50-random:rcfgzffu to be processed
# Application app-20200906094628-0194 with name framework:spark-name:tpch9-bw:10Gbps-ds:32G-stride:90-random:yjilbnfj to be processed
# Application app-20200906094901-0195 with name framework:spark-name:tpch18-bw:20Gbps-ds:32G-stride:25-random:smcohvuo to be processed
# Application app-20200906095147-0196 with name framework:spark-name:tpch7-bw:10Gbps-ds:32G-stride:30-random:acvgwpuk to be processed
# Application app-20200906095525-0197 with name framework:spark-name:tpch3-bw:20Gbps-ds:32G-stride:60-random:umrclpht to be processed
# Application app-20200906095710-0198 with name framework:spark-name:tpch22-bw:10Gbps-ds:32G-stride:10-random:osyownpj to be processed
# Application app-20200906095823-0199 with name framework:spark-name:tpch17-bw:20Gbps-ds:32G-stride:0-random:gbfgvwib to be processed
# Application app-20200906100143-0200 with name framework:spark-name:tpch8-bw:5Gbps-ds:32G-stride:50-random:fvymfqra to be processed
# Application app-20200906100444-0201 with name framework:spark-name:tpch14-bw:40Gbps-ds:32G-stride:40-random:hpipugqt to be processed
# Application app-20200906100732-0202 with name framework:spark-name:tpch15-bw:1Gbps-ds:32G-stride:30-random:mgiicapp to be processed
# Application app-20200906101106-0203 with name framework:spark-name:tpch6-bw:10Gbps-ds:32G-stride:0-random:piylumki to be processed
# Application app-20200906101306-0204 with name framework:spark-name:tpch20-bw:20Gbps-ds:32G-stride:20-random:lljxtwnf to be processed
# Application app-20200906101719-0205 with name framework:spark-name:tpch1-bw:40Gbps-ds:32G-stride:80-random:joerjptd to be processed
# Application app-20200906102153-0206 with name framework:spark-name:tpch16-bw:10Gbps-ds:32G-stride:100-random:bgvaxgdx to be processed
# Application app-20200906102415-0207 with name framework:spark-name:tpch5-bw:5Gbps-ds:32G-stride:30-random:jkyutdzx to be processed
# Application app-20200906102657-0208 with name framework:spark-name:tpch10-bw:10Gbps-ds:32G-stride:20-random:xqcxxdew to be processed
# Application app-20200906103350-0209 with name framework:spark-name:tpch13-bw:5Gbps-ds:64G-stride:70-random:pvpkhsyw to be processed
# Application app-20200906104420-0210 with name framework:spark-name:tpch21-bw:1Gbps-ds:64G-stride:90-random:aswgcnfu to be processed
# Application app-20200906105222-0211 with name framework:spark-name:tpch11-bw:1Gbps-ds:64G-stride:50-random:zfdqqwvn to be processed
# Application app-20200906105503-0212 with name framework:spark-name:tpch19-bw:20Gbps-ds:64G-stride:10-random:smenmsnb to be processed
# Application app-20200906110356-0213 with name framework:spark-name:tpch12-bw:10Gbps-ds:64G-stride:100-random:dzlfhmfv to be processed
# Application app-20200906110748-0214 with name framework:spark-name:tpch2-bw:5Gbps-ds:64G-stride:30-random:xnwjypzq to be processed
# Application app-20200906111826-0215 with name framework:spark-name:tpch4-bw:1Gbps-ds:64G-stride:90-random:jgdrptjv to be processed
# Application app-20200906112849-0216 with name framework:spark-name:tpch9-bw:1Gbps-ds:64G-stride:80-random:aspyunrk to be processed
# Application app-20200906113424-0217 with name framework:spark-name:tpch18-bw:5Gbps-ds:64G-stride:25-random:cppdyzwq to be processed
# Application app-20200906113907-0218 with name framework:spark-name:tpch7-bw:10Gbps-ds:64G-stride:20-random:feuuclth to be processed
# Application app-20200906115107-0219 with name framework:spark-name:tpch3-bw:1Gbps-ds:64G-stride:100-random:ykzqsvgv to be processed
# Application app-20200906115511-0220 with name framework:spark-name:tpch22-bw:10Gbps-ds:64G-stride:30-random:dnxckoej to be processed
# Application app-20200906115712-0221 with name framework:spark-name:tpch17-bw:10Gbps-ds:64G-stride:10-random:qbvdrfsr to be processed
# Application app-20200906120230-0222 with name framework:spark-name:tpch8-bw:10Gbps-ds:64G-stride:40-random:nogzgeiz to be processed
# Application app-20200906120725-0223 with name framework:spark-name:tpch14-bw:10Gbps-ds:64G-stride:40-random:ygojmcuk to be processed
# Application app-20200906121331-0224 with name framework:spark-name:tpch15-bw:5Gbps-ds:64G-stride:60-random:ttkmfuqx to be processed
# Application app-20200906121717-0225 with name framework:spark-name:tpch6-bw:1Gbps-ds:64G-stride:20-random:hmrizwnv to be processed
# Application app-20200906122356-0226 with name framework:spark-name:tpch20-bw:1Gbps-ds:64G-stride:0-random:ngolegry to be processed
# Application app-20200906123415-0227 with name framework:spark-name:tpch1-bw:20Gbps-ds:64G-stride:10-random:zjqnmltv to be processed
# Application app-20200906123846-0228 with name framework:spark-name:tpch16-bw:10Gbps-ds:64G-stride:40-random:ybyncssa to be processed
# Application app-20200906125727-0230 with name framework:spark-name:tpch10-bw:20Gbps-ds:64G-stride:100-random:wfljxlcj to be processed
# Application app-20200906163258-0231 with name framework:spark-name:tpch5-bw:20Gbps-ds:20G-stride:20-random:jnmzogne to be processed
# Application app-20200906163551-0232 with name framework:spark-name:tpch21-bw:5Gbps-ds:20G-stride:60-random:fgxohlvc to be processed
# Application app-20200906163840-0233 with name framework:spark-name:tpch4-bw:20Gbps-ds:20G-stride:50-random:urtutteu to be processed
# Application app-20200906164057-0234 with name framework:spark-name:tpch8-bw:40Gbps-ds:20G-stride:50-random:iimjlnou to be processed
# Application app-20200906164341-0235 with name framework:spark-name:tpch11-bw:1Gbps-ds:20G-stride:40-random:awwwmfpa to be processed
# Application app-20200906164601-0236 with name framework:spark-name:tpch15-bw:5Gbps-ds:20G-stride:40-random:yylfddzx to be processed
# Application app-20200906164916-0237 with name framework:spark-name:tpch1-bw:10Gbps-ds:20G-stride:90-random:pkdffcme to be processed
# Application app-20200906165130-0238 with name framework:spark-name:tpch13-bw:1Gbps-ds:20G-stride:30-random:femhdwwz to be processed
# Application app-20200906165455-0239 with name framework:spark-name:tpch6-bw:5Gbps-ds:20G-stride:90-random:zntrzfvq to be processed
# Application app-20200906165706-0240 with name framework:spark-name:tpch17-bw:5Gbps-ds:20G-stride:50-random:zypldjrw to be processed
# Application app-20200906165839-0241 with name framework:spark-name:tpch19-bw:40Gbps-ds:20G-stride:10-random:akfspblm to be processed
# Application app-20200906170107-0242 with name framework:spark-name:tpch9-bw:1Gbps-ds:20G-stride:40-random:rxpuhssd to be processed
# Application app-20200906170431-0243 with name framework:spark-name:tpch14-bw:20Gbps-ds:20G-stride:10-random:cnbkcmrz to be processed
# Application app-20200906170731-0244 with name framework:spark-name:tpch22-bw:40Gbps-ds:20G-stride:90-random:ohrnipxk to be processed
# Application app-20200906170923-0245 with name framework:spark-name:tpch16-bw:1Gbps-ds:20G-stride:20-random:rbcmudgm to be processed
# Application app-20200906171132-0246 with name framework:spark-name:tpch7-bw:10Gbps-ds:20G-stride:30-random:xahgypsf to be processed
# Application app-20200906171302-0247 with name framework:spark-name:tpch2-bw:1Gbps-ds:20G-stride:0-random:iefjcksc to be processed
# Application app-20200906171620-0248 with name framework:spark-name:tpch10-bw:5Gbps-ds:20G-stride:80-random:hbsfdbth to be processed
# Application app-20200906171910-0249 with name framework:spark-name:tpch12-bw:20Gbps-ds:20G-stride:70-random:vomhcvyk to be processed
# Application app-20200906172105-0250 with name framework:spark-name:tpch3-bw:1Gbps-ds:20G-stride:20-random:yvncqfak to be processed
# Application app-20200906172522-0251 with name framework:spark-name:tpch18-bw:20Gbps-ds:20G-stride:50-random:htdianjf to be processed
# Application app-20200906172704-0252 with name framework:spark-name:tpch20-bw:20Gbps-ds:20G-stride:10-random:bdfbbknt to be processed
# Application app-20200906173213-0253 with name framework:spark-name:tpch5-bw:10Gbps-ds:32G-stride:100-random:nhissvha to be processed
# Application app-20200906175232-0254 with name framework:spark-name:tpch21-bw:1Gbps-ds:32G-stride:60-random:lisrcekx to be processed
# Application app-20200906175634-0255 with name framework:spark-name:tpch4-bw:40Gbps-ds:32G-stride:60-random:nqhhaitc to be processed
# Application app-20200906175919-0256 with name framework:spark-name:tpch8-bw:5Gbps-ds:32G-stride:40-random:bdzvhewq to be processed
# Application app-20200906180245-0257 with name framework:spark-name:tpch11-bw:40Gbps-ds:32G-stride:50-random:yzysjafl to be processed
# Application app-20200906180609-0258 with name framework:spark-name:tpch15-bw:10Gbps-ds:32G-stride:60-random:enzfuaoy to be processed
# Application app-20200906180915-0259 with name framework:spark-name:tpch1-bw:10Gbps-ds:32G-stride:50-random:cwdqfwsu to be processed
# Application app-20200906181122-0260 with name framework:spark-name:tpch13-bw:10Gbps-ds:32G-stride:25-random:nzyweokl to be processed
# Application app-20200906181502-0261 with name framework:spark-name:tpch6-bw:10Gbps-ds:32G-stride:70-random:yqiumzdw to be processed
# Application app-20200906181657-0262 with name framework:spark-name:tpch17-bw:20Gbps-ds:32G-stride:20-random:vyhmwzed to be processed
# Application app-20200906181927-0263 with name framework:spark-name:tpch19-bw:20Gbps-ds:32G-stride:25-random:ewbrndvq to be processed
# Application app-20200906182138-0264 with name framework:spark-name:tpch9-bw:20Gbps-ds:32G-stride:25-random:whdpkmfj to be processed
# Application app-20200906182351-0265 with name framework:spark-name:tpch14-bw:1Gbps-ds:32G-stride:10-random:kkhmqklu to be processed
# Application app-20200906182828-0266 with name framework:spark-name:tpch22-bw:10Gbps-ds:32G-stride:10-random:gznixmma to be processed
# Application app-20200906183001-0267 with name framework:spark-name:tpch16-bw:5Gbps-ds:32G-stride:10-random:hbcvnjvm to be processed
# Application app-20200906183220-0268 with name framework:spark-name:tpch7-bw:5Gbps-ds:32G-stride:30-random:abojrzgy to be processed
# Application app-20200906183408-0269 with name framework:spark-name:tpch2-bw:1Gbps-ds:32G-stride:0-random:nkpzflii to be processed
# Application app-20200906183905-0270 with name framework:spark-name:tpch10-bw:20Gbps-ds:32G-stride:90-random:jmhkxrqn to be processed
# Application app-20200906184259-0271 with name framework:spark-name:tpch12-bw:20Gbps-ds:32G-stride:70-random:ckrnrevi to be processed
# Application app-20200906184423-0272 with name framework:spark-name:tpch3-bw:20Gbps-ds:32G-stride:0-random:kivmynmq to be processed
# Application app-20200906184832-0273 with name framework:spark-name:tpch18-bw:5Gbps-ds:32G-stride:80-random:aszjielb to be processed
# Application app-20200906185242-0274 with name framework:spark-name:tpch20-bw:20Gbps-ds:32G-stride:70-random:xclrtguh to be processed
# Application app-20200906185653-0275 with name framework:spark-name:tpch5-bw:1Gbps-ds:64G-stride:25-random:dftcvtqh to be processed
# Application app-20200906190651-0276 with name framework:spark-name:tpch21-bw:10Gbps-ds:64G-stride:25-random:znhxmvcr to be processed
# Application app-20200906192020-0278 with name framework:spark-name:tpch8-bw:10Gbps-ds:64G-stride:80-random:kueyoeuo to be processed
# Application app-20200906192726-0279 with name framework:spark-name:tpch11-bw:10Gbps-ds:64G-stride:70-random:ztzwzhyc to be processed
# Application app-20200906193403-0280 with name framework:spark-name:tpch15-bw:1Gbps-ds:64G-stride:50-random:xtfpfjau to be processed
# Application app-20200906194404-0281 with name framework:spark-name:tpch1-bw:5Gbps-ds:64G-stride:70-random:pfxlizvo to be processed
# Application app-20200906195137-0282 with name framework:spark-name:tpch13-bw:10Gbps-ds:64G-stride:80-random:fymgdrjq to be processed
# Application app-20200906195516-0283 with name framework:spark-name:tpch6-bw:5Gbps-ds:64G-stride:30-random:jgelqemn to be processed
# Application app-20200906200232-0284 with name framework:spark-name:tpch17-bw:5Gbps-ds:64G-stride:70-random:zbeybrnm to be processed
# Application app-20200906200438-0285 with name framework:spark-name:tpch19-bw:10Gbps-ds:64G-stride:0-random:zesvnedf to be processed
# Application app-20200906201007-0286 with name framework:spark-name:tpch9-bw:40Gbps-ds:64G-stride:50-random:tehacxgy to be processed
# Application app-20200906201651-0287 with name framework:spark-name:tpch14-bw:20Gbps-ds:64G-stride:60-random:zofeapax to be processed
# Application app-20200906202021-0288 with name framework:spark-name:tpch22-bw:10Gbps-ds:64G-stride:25-random:gpgvxwxx to be processed
# Application app-20200906202223-0289 with name framework:spark-name:tpch16-bw:20Gbps-ds:64G-stride:10-random:fidyhucs to be processed
# Application app-20200906202345-0290 with name framework:spark-name:tpch7-bw:5Gbps-ds:64G-stride:0-random:psaplsjf to be processed
# Application app-20200906202643-0291 with name framework:spark-name:tpch2-bw:40Gbps-ds:64G-stride:0-random:sbsjscpp to be processed
# Application app-20200906203015-0292 with name framework:spark-name:tpch10-bw:20Gbps-ds:64G-stride:30-random:tjtfibnt to be processed
# Application app-20200906204446-0294 with name framework:spark-name:tpch3-bw:40Gbps-ds:64G-stride:50-random:bmyvuhed to be processed
# Application app-20200906205231-0295 with name framework:spark-name:tpch18-bw:5Gbps-ds:64G-stride:80-random:rwuhvebu to be processed
# Application app-20200906205822-0296 with name framework:spark-name:tpch20-bw:40Gbps-ds:64G-stride:50-random:ywmanghe to be processed

# %%
print(df.columns)

df['app_runtime'] = df['app_completion_time'] - df['app_start_time']
df[['app_runtime', 'bw', 'ds', 'stride']].sort_values(by='app_runtime',ascending=False).head(5)
# Out:
# Index(['app_completion_time', 'app_dag', 'app_id', 'app_name',
#        'app_start_time', 'bw', 'ds', 'framework', 'job_completion_time',
#        'job_id', 'job_stage_ids', 'job_submission_time', 'name', 'numTasks',
#        'outputBytes', 'random', 'stage_completion_time', 'stage_id',
#        'stage_input_bytes', 'stage_queue_time', 'stage_rdds', 'stage_run_time',
#        'stage_shuffle_read_bytes', 'stage_shuffle_write_bytes',
#        'stage_start_time', 'stage_submission_time', 'stride'],
#       dtype='object')
#       app_runtime     bw   ds stride
# 1523       525165  1Gbps  64G      0
# 1529       525165  1Gbps  64G      0
# 1524       525165  1Gbps  64G      0
# 1533       525165  1Gbps  64G      0
# 1532       525165  1Gbps  64G      0

# %%
ppath='/local0/Kariz/expriments/runtime_prediction/tpch/runtime.pred.spark.prefetch.csv'
dp = pd.read_csv(ppath)
dp.head(5)
# Out:
#                                                              app_name  \
# 0  framework:spark-name:tpch6-bw:20Gbps-ds:-stride:10-random:yryilqex
# 1  framework:spark-name:tpch6-bw:20Gbps-ds:-stride:10-random:yryilqex
# 2  framework:spark-name:tpch6-bw:20Gbps-ds:-stride:10-random:yryilqex
# 3  framework:spark-name:tpch6-bw:20Gbps-ds:-stride:10-random:yryilqex
# 4  framework:spark-name:tpch6-bw:20Gbps-ds:-stride:10-random:yryilqex
#
#                     path  prefetched  requested  stride
# 0  pig-tpch/20G/customer          11         11      10
# 1  pig-tpch/20G/lineitem         371        371      10
# 2    pig-tpch/20G/nation           0          0      10
# 3    pig-tpch/20G/orders          83         83      10
# 4      pig-tpch/20G/part          11         11      10

# %%
dm = df.groupby('app_id')['name', 'app_dag'].agg('max').reset_index()
pd.set_option("display.max_colwidth",800)

string_to_query=[]
n_uniques = 0
for i in range(1,23):
    for j, dag_str in enumerate(dm[dm['name']=='tpch%d'%(i)].groupby('app_dag').agg('max').reset_index()['app_dag'].values):
        n_uniques += 1
        string_to_query.append({'query': i, 'dag': dag_str, 'index': j, 'id': n_uniques})

sq_df = pd.DataFrame(string_to_query)

# %%
# read graphs and build graph pool 
import graph_tool.all as gt

sptpath = '/local0/Kariz/expriments/simulator/multidag/spark.tpch.template'

def build_graph_from_string(dag_str):
    meta = dag_str.split('\n')[0]
    g_name, g_index = meta.split('Q')[1].split(',')
    g_elements = dag_str.split('\n')[1:]
    g_queuetime = 0
    g_id = sq_df[(sq_df['query']==int(g_name)) & (sq_df['index']==int(g_index))]['id'].values[0]
    print('query', g_name, 'index', g_index, 'id', g_id)
    
    g = gt.Graph(directed=True)
    g.gp['name'] = g.new_graph_property("string", 'Q%s,%s'%(g_name,g_index))
    g.gp['id'] = g.new_graph_property("int", str(g_id))
    g.gp['queue_time'] = g.new_graph_property("int", g_queuetime)
    g.gp['cur_stage'] = g.new_graph_property("int", -1)
    status = g.new_vertex_property("int")
    inputs = g.new_vertex_property("string")
    color = g.new_vertex_property("string")
    ops = g.new_vertex_property("string")
    vids = g.new_vertex_property("string")
    sv_gv = {}
    # build vertices
    for el in g_elements[:-1]:
        if el.startswith('v'):
           # print(el)
            vid, operation, inputs_str = el.split(',')[1:]
            v = g.add_vertex()
            vids[v] = vid
            sv_gv[vid] = v
            inputs[v] = inputs_str #build_input_format(inputs_str)
            ops[v] = operation if operation else 'skipped'
            color[v] = '#fb8072' if len(inputs[v]) > 0 else '#bdbdbd' if ops[v] == 'skipped' else '#80b1d3'
            #if g_name == '11' and g_index=='1':
            #    print(v, vids[v], inputs[v])
        
    # build edges
    for el in g_elements[:-1]:
        if el.startswith('e'):
            #if g_name == '11' and g_index=='1' :
            #    print(el)
            v_src, v_dest = el.split(',')[1:]
            e = g.add_edge(sv_gv[v_src], sv_gv[v_dest])

    g.vp['vids'] = vids
    g.vp['color'] = color
    g.vp['tables'] = inputs
    g.vp['status'] = status
    g.vp['feature'] = ops
    if g_name == '23' and g_index=='0':
        gt.graph_draw(g, vertex_text=g.vp.vids, vertex_color=g.vp.color, 
                  vertex_fill_color=g.vp.color, size=(700, 700))
    return g

graphs_pool = {}
with open(sptpath, 'r') as fd:
    dag_strs = fd.read().split('#')[1:]
    for index, dag_str in enumerate(dag_strs):
        g = build_graph_from_string(dag_str)
        graphs_pool[g.gp.id] = g
        if index ==43:
            break
            
print('Total number of graphs in the graph pool', len(graphs_pool))
# Out:
# query 1 index 0 id 1
# query 2 index 0 id 2
# query 2 index 1 id 3
# query 2 index 2 id 4
# query 2 index 3 id 5
# query 3 index 0 id 6
# query 4 index 0 id 7
# query 5 index 0 id 8
# query 5 index 1 id 9
# query 5 index 2 id 10
# query 5 index 3 id 11
# query 6 index 0 id 12
# query 7 index 0 id 13
# query 7 index 1 id 14
# query 7 index 2 id 15
# query 8 index 0 id 16
# query 9 index 0 id 17
# query 9 index 1 id 18
# query 10 index 0 id 19
# query 10 index 1 id 20
# query 10 index 2 id 21
# query 12 index 0 id 25
# query 13 index 0 id 26
# query 14 index 0 id 27
# query 15 index 0 id 28
# query 16 index 0 id 29
# query 16 index 1 id 30
# query 17 index 0 id 31
# query 17 index 1 id 32
# query 17 index 2 id 33
# query 19 index 0 id 37
# query 18 index 0 id 34
# query 18 index 1 id 35
# query 18 index 2 id 36
# query 20 index 0 id 38
# query 20 index 1 id 39
# query 21 index 0 id 40
# query 21 index 1 id 41
# query 21 index 2 id 42
# query 11 index 0 id 22
# query 11 index 1 id 23
# query 11 index 2 id 24
# query 22 index 0 id 43
# Total number of graphs in the graph pool 43

# %%
cache_block_size = 4*1024*1024

def bandwidth_regularization(row):
    if 'Gbps' in row['bw']:
        row ['bw_i'] = float(row['bw'].replace(r'Gbps', ''))
    elif 'Mbps' in row['bw']:
        row['bw_i'] = int(row['bw'].replace(r'Mbps', ''))/1000
    else:
        raise NameError('The bandwidth string is not parsable')
    return row

def assign_prefetched_blocks(row):
    row['prefetched_blocks'] = 0
    if row['tables'] and int(row['stride'])>0:
        table = 'pig-tpch/%s/%s'%(row['ds'], row['tables'])
        row['prefetched_blocks'] = dp[(dp['app_name'] == row['app_name']) & (dp['path'] == table)]['prefetched'].values[0]
    row['prefetched_bytes'] = row['prefetched_blocks']*cache_block_size
    return row

def annotate_dag(row):
    query = row['name'].replace('tpch', '')
    stage_id = row['stage_id']
    query_dag = row['app_dag']
    g_id = sq_df[(sq_df['query']==int(query)) & (sq_df['dag'] == query_dag)]['id'].values[0]
    g = graphs_pool[g_id]
    v = gt.find_vertex(g, g.vp.vids, stage_id)[0]
    row['feature'] = g.vp.feature[v]
    row['tables'] = g.vp.tables[v].replace(' ', '')
    row = assign_prefetched_blocks(row)
    row = bandwidth_regularization(row)
    return row
    
df =  df.apply(annotate_dag, axis=1)
print(df.columns)

df[['stage_input_bytes', 'prefetched_bytes', 'stage_shuffle_read_bytes','stride']].head(5)
# Out:
# Index(['app_completion_time', 'app_dag', 'app_id', 'app_name',
#        'app_start_time', 'bw', 'ds', 'framework', 'job_completion_time',
#        'job_id', 'job_stage_ids', 'job_submission_time', 'name', 'numTasks',
#        'outputBytes', 'random', 'stage_completion_time', 'stage_id',
#        'stage_input_bytes', 'stage_queue_time', 'stage_rdds', 'stage_run_time',
#        'stage_shuffle_read_bytes', 'stage_shuffle_write_bytes',
#        'stage_start_time', 'stage_submission_time', 'stride', 'app_runtime',
#        'feature', 'tables', 'prefetched_blocks', 'prefetched_bytes', 'bw_i'],
#       dtype='object')
#    stage_input_bytes  prefetched_bytes  stage_shuffle_read_bytes stride
# 0                  0                 0                     16269     50
# 1                  0                 0                   2611955     50
# 2           28271512                 0                         0     50
# 3         3487488366        1740636160                         0     50
# 4               2199                 0                         0     50

# %%
def build_prediction_df(row):
    pred_row = {}
    
    pred_row['feature'] = row['feature']
    pred_row['input_sz'] = row['stage_input_bytes']
    pred_row['cache_read'] =  row['prefetched_bytes']/bw_cache
    pred_row['remote_read'] = np.abs(8*(row['stage_input_bytes'] - row['prefetched_bytes'])/(row['bw_i']*(10**9)))
    pred_row['sequential'] = (row['stage_input_bytes'] + row['stage_shuffle_read_bytes'])/row['numTasks']
    
    logd = (row['stage_input_bytes'] + row['stage_shuffle_read_bytes'])/row['numTasks']
    
    if not logd:
        pred_row['aggregate'] = 0 
        pred_row['sort'] = 0
    else:
        pred_row['aggregate'] = np.log(logd)
        pred_row['sort'] = logd*np.log(logd)
df2['sort'] = ((df['stage_input_bytes'] + df['stage_shuffle_read_bytes'])/df['numTasks'])*np.log((df['stage_input_bytes'] + df['stage_shuffle_read_bytes'])/df['numTasks'])
df2['shuffle'] = (df['numTasks'])#*dt['total_bytes']
df2['runtime'] = df['stage_run_time']

    
    return pred_row

bw_cache = 5*(10**9)

df2 = pd.DataFrame()



df2['feature'] = df['feature']
df2['input_sz'] = df['stage_input_bytes']
df2['cache_read'] =  df['prefetched_bytes']/bw_cache
df2['remote_read'] = np.abs(8*(df['stage_input_bytes'] - df['prefetched_bytes'])/(df['bw_i']*(10**9)))
df2['sequential'] = (df['stage_input_bytes'] + df['stage_shuffle_read_bytes'])/df['numTasks']
df2['aggregate'] = np.log((df['stage_input_bytes'] + df['stage_shuffle_read_bytes'])/df['numTasks'])
df2['sort'] = ((df['stage_input_bytes'] + df['stage_shuffle_read_bytes'])/df['numTasks'])*np.log((df['stage_input_bytes'] + df['stage_shuffle_read_bytes'])/df['numTasks'])
df2['shuffle'] = (df['numTasks'])#*dt['total_bytes']
df2['runtime'] = df['stage_run_time']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.

# %%
df['log'] = (df['stage_input_bytes'] + df['stage_shuffle_read_bytes'])/df['numTasks']

df[df['log'] == 0][['stage_input_bytes', 'stage_shuffle_read_bytes', 'stage_run_time']]
# Out:
#       stage_input_bytes  stage_shuffle_read_bytes  stage_run_time
# 36                    0                         0             0.0
# 123                   0                         0             0.0
# 322                   0                         0             0.0
# 441                   0                         0             1.0
# 457                   0                         0             0.0
# 642                   0                         0             1.0
# 658                   0                         0             0.0
# 843                   0                         0             1.0
# 859                   0                         0             0.0
# 991                   0                         0             1.0
# 1192                  0                         0             1.0
# 1313                  0                         0             0.0
# 1393                  0                         0             1.0
# 1514                  0                         0             0.0
# 1611                  0                         0             0.0
# 1812                  0                         0             1.0
# 2007                  0                         0             1.0
# 2017                  0                         0             1.0

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn import metrics
# %matplotlib inline

gdf2 = df2.groupby('feature')

regressors = {}

for index, df3 in gdf2:
    print(index)
    print(df3.isnull().values.any())
    if df3.isnull().values.any():
        print(df3)
    continue
    #if index == 'SCAN':
    #    X = df3[['remote_read', 'cache_read', 'sequential']].values
    #else:
    X = df3[['remote_read', 'cache_read', 'sequential', 'sort', 'shuffle', 'aggregate']].values

    Y= df3['runtime'].values

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
    
    regressor = Lasso(alpha=0.0001,precompute=True,max_iter=1000,
                positive=True, random_state=9999, selection='random')
 #   regressor = LassoCV(max_iter=1000, positive=True, random_state=9999, selection='random')
    regressor.fit(X_train,y_train)
    
    #print(X_test)
    #regressor = LinearRegression()  
    #regressor.fit(X_train, y_train)

    #if index == 'SCAN':
    #    coeff_df = pd.DataFrame(regressor.coef_, 
    #                            df3[['remote_read', 'cache_read', 'sequential']].columns, 
    #                            columns=['Coefficient'])  
    #else:
    coeff_df = pd.DataFrame(regressor.coef_, 
                            df3[['remote_read', 'cache_read', 'sequential', 'sort', 'shuffle', 'aggregate']].columns, 
                            columns=['Coefficient'])  
    print(index, '\n', coeff_df, '\n', regressor.intercept_)

    y_pred = regressor.predict(X_test)

    dn = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
    dn['Accuracy'] = 100*(1 - dn['Predicted']/dn['Actual'])

    df1 = dn.head(25)

    fig, ax = plt.subplots(figsize=(16, 8))
    df1[['Predicted', 'Actual']].plot(kind='bar',ax=ax)
    ax.set_title(index)
    ax.set_xlabel('Test Sample', fontsize=20)
    ax.set_ylabel('Runtime (sec)', fontsize=20)
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
    plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
    plt.show()
    
    if index not in regressors: 
        regressors[index] = regressor; 
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
    print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
    print('Mean stage runtime:', y_test.mean())
    
    print('*******************************************************', '\n\n\n')
# Out:
# HASHAGGREGATE
# False
# HASHAGGREGATE:BROADCASTNESTEDJOINLOOP
# False
# HASHAGGREGATE:FILTER
# False
# SCAN
# False
# SCAN:FILTER
# False
# SCAN:FILTER:HASHAGGREGATE
# False
# SCAN:HASHAGGREGATE
# False
# SORT
# True
#      feature  input_sz  cache_read  remote_read    sequential  aggregate  \
# 0       SORT         0         0.0          0.0  9.296571e+01   4.532231
# 21      SORT         0         0.0          0.0  8.100000e+01   4.394449
# 29      SORT         0         0.0          0.0  6.282222e+01   4.140309
# 36      SORT         0         0.0          0.0  0.000000e+00       -inf
# 47      SORT         0         0.0          0.0  7.480000e+01   4.314818
# 59      SORT         0         0.0          0.0  2.212280e+03   7.701779
# 70      SORT         0         0.0          0.0  1.229305e+04   9.416789
# 84      SORT         0         0.0          0.0  1.670000e+02   5.117994
# 99      SORT         0         0.0          0.0  6.195270e+05  13.336712
# 100     SORT         0         0.0          0.0  7.760000e+01   4.351567
# 115     SORT         0         0.0          0.0  8.100000e+01   4.394449
# 123     SORT         0         0.0          0.0  0.000000e+00       -inf
# 134     SORT         0         0.0          0.0  1.080000e+02   4.682131
# 147     SORT         0         0.0          0.0  6.282222e+01   4.140309
# 153     SORT         0         0.0          0.0  9.298286e+01   4.532415
# 174     SORT         0         0.0          0.0  1.229367e+04   9.416839
# 183     SORT         0         0.0          0.0  1.252450e+05  11.738027
# 199     SORT         0         0.0          0.0  7.600000e+01   4.330733
# 217     SORT         0         0.0          0.0  7.480000e+01   4.314818
# 231     SORT         0         0.0          0.0  2.212280e+03   7.701779
# 246     SORT         0         0.0          0.0  7.900000e+01   4.369448
# 261     SORT         0         0.0          0.0  1.239926e+06  14.030562
# 274     SORT         0         0.0          0.0  1.382500e+02   4.929064
# 283     SORT         0         0.0          0.0  1.600000e+02   5.075174
# 298     SORT         0         0.0          0.0  6.199790e+05  13.337441
# 299     SORT         0         0.0          0.0  7.760000e+01   4.351567
# 314     SORT         0         0.0          0.0  8.100000e+01   4.394449
# 322     SORT         0         0.0          0.0  0.000000e+00       -inf
# 344     SORT         0         0.0          0.0  1.239926e+06  14.030562
# 357     SORT         0         0.0          0.0  8.100000e+01   4.394449
# 364     SORT         0         0.0          0.0  9.300000e+01   4.532599
# 388     SORT         0         0.0          0.0  6.195500e+05  13.336749
# 404     SORT         0         0.0          0.0  1.229258e+04   9.416751
# 413     SORT         0         0.0          0.0  2.212280e+03   7.701779
# 424     SORT         0         0.0          0.0  7.600000e+01   4.330733
# 441     SORT         0         0.0          0.0  0.000000e+00       -inf
# 449     SORT         0         0.0          0.0  8.100000e+01   4.394449
# 457     SORT         0         0.0          0.0  0.000000e+00       -inf
# 477     SORT         0         0.0          0.0  1.239926e+06  14.030562
# 490     SORT         0         0.0          0.0  1.080000e+02   4.682131
# 503     SORT         0         0.0          0.0  6.282222e+01   4.140309
# 510     SORT         0         0.0          0.0  1.252450e+05  11.738027
# 525     SORT         0         0.0          0.0  7.760000e+01   4.351567
# 540     SORT         0         0.0          0.0  1.382500e+02   4.929064
# 554     SORT         0         0.0          0.0  7.900000e+01   4.369448
# 560     SORT         0         0.0          0.0  7.480000e+01   4.314818
# 565     SORT         0         0.0          0.0  9.300000e+01   4.532599
# 589     SORT         0         0.0          0.0  6.199880e+05  13.337455
# 605     SORT         0         0.0          0.0  1.230544e+04   9.417797
# 614     SORT         0         0.0          0.0  3.499485e+03   8.160371
# ...      ...       ...         ...          ...           ...        ...
# 1524    SORT         0         0.0          0.0  6.669640e+03   8.805321
# 1535    SORT         0         0.0          0.0  1.392500e+02   4.936271
# 1539    SORT         0         0.0          0.0  1.238059e+04   9.423885
# 1555    SORT         0         0.0          0.0  6.198140e+05  13.337175
# 1556    SORT         0         0.0          0.0  7.760000e+01   4.351567
# 1571    SORT         0         0.0          0.0  1.252450e+05  11.738027
# 1587    SORT         0         0.0          0.0  7.480000e+01   4.314818
# 1593    SORT         0         0.0          0.0  7.600000e+01   4.330733
# 1611    SORT         0         0.0          0.0  0.000000e+00       -inf
# 1621    SORT         0         0.0          0.0  1.670000e+02   5.117994
# 1629    SORT         0         0.0          0.0  1.382500e+02   4.929064
# 1633    SORT         0         0.0          0.0  6.282222e+01   4.140309
# 1651    SORT         0         0.0          0.0  9.298286e+01   4.532415
# 1670    SORT         0         0.0          0.0  8.100000e+01   4.394449
# 1678    SORT         0         0.0          0.0  1.229223e+04   9.416723
# 1687    SORT         0         0.0          0.0  1.080000e+02   4.682131
# 1705    SORT         0         0.0          0.0  1.239926e+06  14.030562
# 1725    SORT         0         0.0          0.0  6.195520e+05  13.336752
# 1727    SORT         0         0.0          0.0  7.900000e+01   4.369448
# 1747    SORT         0         0.0          0.0  2.212280e+03   7.701779
# 1757    SORT         0         0.0          0.0  7.760000e+01   4.351567
# 1772    SORT         0         0.0          0.0  1.807060e+05  12.104627
# 1788    SORT         0         0.0          0.0  7.500000e+01   4.317488
# 1794    SORT         0         0.0          0.0  7.600000e+01   4.330733
# 1812    SORT         0         0.0          0.0  0.000000e+00       -inf
# 1822    SORT         0         0.0          0.0  1.600000e+02   5.075174
# 1830    SORT         0         0.0          0.0  1.390000e+02   4.934474
# 1834    SORT         0         0.0          0.0  6.282609e+01   4.140370
# 1852    SORT         0         0.0          0.0  9.300000e+01   4.532599
# 1871    SORT         0         0.0          0.0  8.100000e+01   4.394449
# 1879    SORT         0         0.0          0.0  1.230614e+04   9.417853
# 1888    SORT         0         0.0          0.0  1.080000e+02   4.682131
# 1906    SORT         0         0.0          0.0  1.912936e+06  14.464150
# 1926    SORT         0         0.0          0.0  6.199790e+05  13.337441
# 1928    SORT         0         0.0          0.0  8.000000e+01   4.382027
# 1948    SORT         0         0.0          0.0  3.499485e+03   8.160371
# 1958    SORT         0         0.0          0.0  7.760000e+01   4.351567
# 1973    SORT         0         0.0          0.0  2.586750e+05  12.463328
# 1989    SORT         0         0.0          0.0  7.600000e+01   4.330733
# 2007    SORT         0         0.0          0.0  0.000000e+00       -inf
# 2017    SORT         0         0.0          0.0  0.000000e+00       -inf
# 2025    SORT         0         0.0          0.0  1.392500e+02   4.936271
# 2029    SORT         0         0.0          0.0  6.282222e+01   4.140309
# 2047    SORT         0         0.0          0.0  9.296571e+01   4.532231
# 2066    SORT         0         0.0          0.0  8.100000e+01   4.394449
# 2074    SORT         0         0.0          0.0  1.237829e+04   9.423699
# 2083    SORT         0         0.0          0.0  1.080000e+02   4.682131
# 2101    SORT         0         0.0          0.0  2.510299e+06  14.735912
# 2121    SORT         0         0.0          0.0  6.198520e+05  13.337236
# 2137    SORT         0         0.0          0.0  6.669640e+03   8.805321
#
#               sort  shuffle  runtime
# 0     4.213421e+02      175      1.0
# 21    3.559504e+02        7      1.0
# 29    2.601034e+02       45      1.0
# 36             NaN        1      0.0
# 47    3.227484e+02        5      0.0
# 59    1.703849e+04      200      2.0
# 70    1.157611e+05      200      1.0
# 84    8.547050e+02        1      0.0
# 99    8.262453e+06        1      1.0
# 100   3.376816e+02        5      0.0
# 115   3.559504e+02        7      1.0
# 123            NaN        1      0.0
# 134   5.056702e+02        4      1.0
# 147   2.601034e+02       45      1.0
# 153   4.214369e+02      175      1.0
# 174   1.157675e+05      200      2.0
# 183   1.470129e+06        1      0.0
# 199   3.291357e+02        2      1.0
# 217   3.227484e+02        5      1.0
# 231   1.703849e+04      200      2.0
# 246   3.451864e+02        2      0.0
# 261   1.739686e+07        1      1.0
# 274   6.814430e+02        4      1.0
# 283   8.120278e+02        1      1.0
# 298   8.268933e+06        1      0.0
# 299   3.376816e+02        5      0.0
# 314   3.559504e+02        7      1.0
# 322            NaN        1      0.0
# 344   1.739686e+07        1      1.0
# 357   3.559504e+02        7      1.0
# 364   4.215318e+02      175      1.0
# 388   8.262783e+06        1      0.0
# 404   1.157561e+05      200      1.0
# 413   1.703849e+04      200      2.0
# 424   3.291357e+02        2      0.0
# 441            NaN        1      1.0
# 449   3.559504e+02        7      0.0
# 457            NaN        1      0.0
# 477   1.739686e+07        1      1.0
# 490   5.056702e+02        4      0.0
# 503   2.601034e+02       45      1.0
# 510   1.470129e+06        1      0.0
# 525   3.376816e+02        5      1.0
# 540   6.814430e+02        4      2.0
# 554   3.451864e+02        2      1.0
# 560   3.227484e+02        5      0.0
# 565   4.215318e+02      175      1.0
# 589   8.269062e+06        1      0.0
# 605   1.158901e+05      200      2.0
# 614   2.855710e+04      200      2.0
# ...            ...      ...      ...
# 1524  5.872832e+04      200      2.0
# 1535  6.873757e+02        4      1.0
# 1539  1.166733e+05      200      1.0
# 1555  8.266568e+06        1      0.0
# 1556  3.376816e+02        5      0.0
# 1571  1.470129e+06        1      0.0
# 1587  3.227484e+02        5      1.0
# 1593  3.291357e+02        2      1.0
# 1611           NaN        1      0.0
# 1621  8.547050e+02        1      0.0
# 1629  6.814430e+02        4      1.0
# 1633  2.601034e+02       45      1.0
# 1651  4.214369e+02      175      1.0
# 1670  3.559504e+02        7      1.0
# 1678  1.157525e+05      200      2.0
# 1687  5.056702e+02        4      0.0
# 1705  1.739686e+07        1      0.0
# 1725  8.262811e+06        1      1.0
# 1727  3.451864e+02        2      1.0
# 1747  1.703849e+04      200      1.0
# 1757  3.376816e+02        5      1.0
# 1772  2.187379e+06        1      0.0
# 1788  3.238116e+02        5      0.0
# 1794  3.291357e+02        2      1.0
# 1812           NaN        1      1.0
# 1822  8.120278e+02        1      0.0
# 1830  6.858919e+02        4      1.0
# 1834  2.601233e+02       46      1.0
# 1852  4.215318e+02      175      1.0
# 1871  3.559504e+02        7      0.0
# 1879  1.158974e+05      200      2.0
# 1888  5.056702e+02        4      0.0
# 1906  2.766899e+07        1      1.0
# 1926  8.268933e+06        1      0.0
# 1928  3.505621e+02        2      0.0
# 1948  2.855710e+04      200      2.0
# 1958  3.376816e+02        5      1.0
# 1973  3.223951e+06        1      1.0
# 1989  3.291357e+02        2      0.0
# 2007           NaN        1      1.0
# 2017           NaN        1      1.0
# 2025  6.873757e+02        4      1.0
# 2029  2.601034e+02       45      1.0
# 2047  4.213421e+02      175      1.0
# 2066  3.559504e+02        7      1.0
# 2074  1.166493e+05      200      1.0
# 2083  5.056702e+02        4      0.0
# 2101  3.699155e+07        1      1.0
# 2121  8.267112e+06        1      1.0
# 2137  5.872832e+04      200      1.0
#
# [171 rows x 9 columns]
# SORT:SORTMERGEJOIN
# False
# SORT:SORTMERGEJOIN:HASHAGGREGATE
# False
# SORT:SORTMERGEJOIN:HASHAGGREGATE:FILTER
# False
# SORT:SORTMERGEJOIN:HASHAGGREGATE:FILTER:BROADCASTHASHJOIN
# False
# WRITE
# False
# skipped
# False

# %%
def predict_runtime(row):
    logd = (row['stage_input_bytes'] + row['stage_shuffle_read_bytes'])/row['numTasks']
    feature = row['feature']
    regressor = regressors[feature];
    input_sz = row['stage_input_bytes']
    cache_read =  row['prefetched_bytes']/bw_cache
    remote_read = np.abs(8*(row['stage_input_bytes'] - row['prefetched_bytes'])/(row['bw_i']*(10**9)))
    #sequential = (row['stage_input_bytes'] + row['stage_shuffle_read_bytes'])/row['numTasks']
    #aggregate = np.log(row['numTasks'])
    shuffle = (row['numTasks'])#*dt['total_bytes']
    
    sequential = (row['stage_input_bytes'] + row['stage_shuffle_read_bytes'])/row['numTasks']
    aggregate = np.log(logd)
    sort = (logd)*np.log(logd)

    row['predict_runtime'] = round(regressor.predict([[remote_read, cache_read, sequential, sort, shuffle, aggregate]])[0]
                                   ,2)
    #print(row['predict_runtime'], row['stage_run_time'])
    return row

n_unique = df['app_id'].nunique()
n_test = int(n_unique*0.2)
print(n_unique, n_test)
test_apps_indexes = np.random.choice(df['app_id'].unique().shape[0], n_test, replace=False)



total=0
cp_err = 0
for app_index in test_apps_indexes:
    app_id = df['app_id'].unique()[app_index]
    app = df[df['app_id']==app_id].apply(predict_runtime, axis=1)
    
   # print(app_id, df[df['app_id']==app_id]['app_name'].values[0])
    
    query = df[df['app_id']==app_id]['name'].values[0].replace('tpch', '')
    query_dag = df[df['app_id']==app_id]['app_dag'].values[0]
    g_id = sq_df[(sq_df['query']==int(query)) & (sq_df['dag'] == query_dag)]['id'].values[0]
    g = graphs_pool[g_id].copy()
    
    predicted_runtime = g.new_edge_property("float")
    actual_runtime = g.new_edge_property("float")

    for e in g.edges():
        v = e.source()
        # print(g.vp.vids[v], g.vp.feature[v])
        if g.vp.feature[v] == 'skipped':
            actual_runtime[e] = 0
            predicted_runtime[e] = 0
        else:
            actual_runtime[e], predicted_runtime[e] = -1*(app[app['stage_id']==int(g.vp.vids[v])][[
                'stage_run_time', 'predict_runtime']].values[0])
    
    g.ep['n_predicted_runtime'] = predicted_runtime
    g.ep['n_actual_runtime'] = actual_runtime
    
    roots = [v for v in g.vertices() if v.in_degree() == 0]
    leaves = [v for v in g.vertices() if v.out_degree() == 0]
    #print(roots, leaves)
    
    #gt.graph_draw(g, vertex_text=g.vp.vids, vertex_color=g.vp.color, 
    #              vertex_fill_color=g.vp.color, size=(700, 700))
    predict_list= []
    for root in roots:
        for leaf in leaves:
            vlist, elist = gt.shortest_path(g, g.vertex(root), g.vertex(leaf), weights=g.ep.n_predicted_runtime, 
                                            negative_weights=True, pred_map=None)
            
            dist = gt.shortest_distance(g, g.vertex(root), g.vertex(leaf), weights=g.ep.n_predicted_runtime, 
                                            negative_weights=True, pred_map=None)
            
            vlist1, elist1 = gt.shortest_path(g, g.vertex(root), g.vertex(leaf), weights=g.ep.n_actual_runtime,
                                           negative_weights=True, pred_map=None)
            dist1 = gt.shortest_distance(g, g.vertex(root), g.vertex(leaf), weights=g.ep.n_actual_runtime, 
                                            negative_weights=True, pred_map=None)
            
            
            #print('path from %d to %d: predicted lat %0.2f, actual lat %0.2f'%(root, leaf, 
            #                                                                 round(-1*dist, 2), -1*dist1))
            
            predict_list.append({'root': root, 'leaf': leaf, 'predicted':  round(-1*dist, 2), 'actual': -1*dist1})
     #       for v in vlist:
     #           print('predicted', v)
            
     #       for v in vlist1:
     #           print('actual', v)
    dcp = pd.DataFrame(predict_list)
    print(dcp['predicted'].idxmax(), dcp['actual'].idxmax()) 
    if dcp['predicted'].idxmax() != dcp['actual'].idxmax():
        cp_err += 1
        print(dcp)
    total += 1
   # print('************************************* NEXTTTTTTTTT *************************************')
# Out:
# 235 47
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-816-ae432c3abfbf> in <module>
#      30 for app_index in test_apps_indexes:
#      31     app_id = df['app_id'].unique()[app_index]
# ---> 32     app = df[df['app_id']==app_id].apply(predict_runtime, axis=1)
#      33
#      34    # print(app_id, df[df['app_id']==app_id]['app_name'].values[0])
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6494                          args=args,
#    6495                          kwds=kwds)
# -> 6496         return op.get_result()
#    6497
#    6498     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-816-ae432c3abfbf> in predict_runtime(row)
#       2     logd = (row['stage_input_bytes'] + row['stage_shuffle_read_bytes'])/row['numTasks']
#       3     feature = row['feature']
# ----> 4     regressor = regressors[feature];
#       5     input_sz = row['stage_input_bytes']
#       6     cache_read =  row['prefetched_bytes']/bw_cache
#
# KeyError: ('SORT:SORTMERGEJOIN:HASHAGGREGATE', 'occurred at index 747')

# %%
cp_err, total
# Out:
# (3, 47)

# %%
app[app['stage_id']==int(g.vp.vids[v])]
# Out:
# Empty DataFrame
# Columns: [app_completion_time, app_dag, app_id, app_name, app_start_time, bw, ds, framework, job_completion_time, job_id, job_stage_ids, job_submission_time, name, numTasks, outputBytes, random, stage_completion_time, stage_id, stage_input_bytes, stage_queue_time, stage_rdds, stage_run_time, stage_shuffle_read_bytes, stage_shuffle_write_bytes, stage_start_time, stage_submission_time, stride, app_runtime, feature, tables, prefetched_blocks, prefetched_bytes, bw_i, predict_runtime]
# Index: []
#
# [0 rows x 34 columns]

# %%
print(app_id, df[df['app_id']==app_id]['app_name'].values[0], g.gp.id)


print(sq_df[sq_df['id']==g.gp.id])


gt.graph_draw(g, vertex_text=g.vp.vids, vertex_color=g.vp.color, 
              vertex_fill_color=g.vp.color, size=(700, 700))



print(g.vp.vids[v], g.vp.feature[v])
# Out:
# app-20200905174956-0129 framework:spark-name:tpch15-bw:10Gbps-ds:32G-stride:50-random:fpfvygit 28
#                                                                                                                                             dag  \
# 27  j:0,e:->0\nj:0,e:0->1\nj:0,e:1->2\nj:1,e:3->5\nj:1,e:4->5\nj:1,e:->3\nj:1,e:->4\nj:2,e:8->9\nj:2,e:->6\nj:2,e:->7\nj:2,e:6->8\nj:2,e:7->8\n
#
#     id  index  query
# 27  28      0     15
# /usr/lib/python3/dist-packages/graph_tool/draw/cairo_draw.py:637: UserWarning: Unknown parameter: size
#   warnings.warn("Unknown parameter: " + k, UserWarning)
# 4 SCAN

# %%
app['stage_id']
# Out:
# 642    9
# 643    8
# 644    5
# 645    3
# 646    0
# 647    1
# 648    2
# Name: stage_id, dtype: int64

# %%
for app_index in test_apps_indexes:
    app_id = df['app_id'].unique()[app_index]
    app = df[df['app_id']==app_id].apply(predict_runtime, axis=1)
    
    app[app['feature']== 'SCAN:FILTER:HASHAGGREGATE']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-812-9530b15ee2af> in <module>
#       2 for app_index in test_apps_indexes:
#       3     app_id = df['app_id'].unique()[app_index]
# ----> 4     app = df[df['app_id']==app_id].apply(predict_runtime, axis=1)
#       5
#       6     app[app['feature']== 'SCAN:FILTER:HASHAGGREGATE']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6494                          args=args,
#    6495                          kwds=kwds)
# -> 6496         return op.get_result()
#    6497
#    6498     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-794-3ac251f5d036> in predict_runtime(row)
#       8     aggregate = np.log(row['numTasks'])
#       9     shuffle = (row['numTasks'])#*dt['total_bytes']
# ---> 10     row['predict_runtime'] = round(regressor.predict([[remote_read, cache_read, sequential, shuffle, aggregate]])[0]
#      11                                    ,2)
#      12     #print(row['predict_runtime'], row['stage_run_time'])
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py in _decision_function(self, X)
#     884                                    dense_output=True) + self.intercept_
#     885         else:
# --> 886             return super()._decision_function(X)
#     887
#     888
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
# --> 220                                dense_output=True) + self.intercept_
#     221
#     222     def predict(self, X):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# ValueError: ('matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 6 is different from 5)', 'occurred at index 604')
